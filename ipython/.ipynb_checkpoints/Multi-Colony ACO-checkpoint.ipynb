# %% [markdown]
# TO DO:
# Ants have colony - Done using dict to convert colony to list id
# Global solution pool for front (per generation) - Done

# %%
'''
IMPORTS
'''

# %matplotlib inline

# Standard imports
import copy
import itertools

# Scientific computing imports
import numpy
import matplotlib.pyplot as plt
import networkx as nx
import pandas
import collections
from bisect import bisect
from networkx.algorithms.flow import edmonds_karp

import seaborn; seaborn.set()

# Import widget methods
from IPython.html.widgets import *
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
class Ant(object):
    """
    Ant class, which encapsulates the entire behavior of an ant.
    """
    def __init__(self,model,ant_id,colony_id):
    
        # Set model link and ID
        self.model = model
        self.ant_id = (ant_id,colony_id)
        
    def random_walk(self,source,sink):
        #Random Walk
        #initialize method
        self.source=source
        self.sink=sink
        self.g=nx.DiGraph()
        
        #initialize start of random walk
        self.last_nodes=self.source

        #Create path for an ant
        terminate=0
        while not terminate:
            terminate=1
            for i in xrange(len(self.last_nodes)):
                '''
                Ant step is encompassed below
                '''
                #track next nodes
                self.last_nodes_next=[]
                #get neighbors
                self.base_node=self.last_nodes[i]
                #self.base_node=self.last_nodes.pop()
                self.p_neighbors=self.get_neighbors(self.base_node)
                
                #get pheromone of each edge to neighbor
                self.edge_pheromone_list=[]
                for self.potential_node in self.p_neighbors:
                    self.edge_pheromone_list.append(self.get_pheromone_edge((self.base_node,self.potential_node)))
                
                #get next node
                self.next_node=self.p_neighbors[self.make_decision(self.edge_pheromone_list)]
                self.last_nodes_next.append(self.next_node)
                
                #add edge
                self.g.add_edge(self.base_node,self.next_node)
                #print(self.g.nodes())
                
                #get capacity pheromones
                self.capacity_pheromone_list=self.get_pheromone_capacity((self.base_node,self.next_node))
                
                #decide capacity
                self.capacity_to_add=self.model.capacities[self.make_decision(self.capacity_pheromone_list)]
                
                #add capacity
                self.g[self.base_node][self.next_node]['capacity']=self.capacity_to_add
                
                #Check termination criteria - are all sinks in the graph
                for sink_node in self.sink:
                    if sink_node not in self.g:
                        terminate=0
                        
            self.last_nodes=self.last_nodes_next   

        return (self.g)
    
    def get_neighbors(self,node):
        """
        Return neighbors, calling through model.
        """
        return self.model.get_ant_neighbors(node)
    
    def make_decision(self,pheromone_list):
        """
        Return decision index, based on pheromone list.
        """
        #convert pheromones to percentage
        self.percent_list = [float(i)/sum(pheromone_list) for i in pheromone_list]   
        self.cumulative_percent=numpy.cumsum(self.percent_list)

        #Choose decision index
        self.select_index=bisect(self.cumulative_percent,numpy.random.uniform(0,1,1))
  
        return self.select_index
    
    
    #def get_pheromone_node(self,node):
        """
        Return node pheromone, calling through model.
        """    
    
    
    def get_pheromone_edge(self,edge):
        """
        Return edge pheromone, calling through model.
        """
        return self.model.get_edge_pheromone(edge,self.ant_id)

    def get_pheromone_capacity(self,edge):
        """
        Return edge pheromone, calling through model.
        """
        return self.model.get_capacity_pheromone(edge,self.ant_id)
    

    def __repr__(self):
        '''
        Return string representation.
        '''
        skip_none = True
        repr_string = type(self).__name__ + " ["
        except_list = "model"

        elements = [e for e in dir(self) if str(e) not in except_list]
        for e in elements:
            # Make sure we only display "public" fields; skip anything private (_*), that is a method/function, or that is a module.
            if not e.startswith("_") and eval('type(self.{0}).__name__'.format(e)) not in ['DataFrame', 'function', 'method', 'builtin_function_or_method', 'module', 'instancemethod']:
                    value = eval("self." + e)
                    if value != None and skip_none == True:
                        repr_string += "{0}={1}, ".format(e, value)

        # Clean up trailing space and comma.
        return repr_string.strip(" ").strip(",") + "]"

# %%
class Space(object):
    """
    Space class, which encapsulates the entire behavior of a single "run" ACO.
    """
    def __init__(self, size,num_ants=1,num_colonies=2,source=[[(0,0)],[10]],sink=[[(2,2)],[5]],dissipation=.2,initial_pheromone=.1,capacities=[1,5,10]):
        """
        Class constructor.
        """
        # Set our model parameters
        self.size = size
        self.sink = sink[0]
        self.sink_magnitude = sink[1]
        self.source=source[0]
        self.source_magnitude = source[1]        
        self.num_ants=num_ants
        self.num_colonies=num_colonies
        self.dissipation=dissipation
        self.initial_pheromone=initial_pheromone
        self.capacities=capacities
        
        # Set our state variables
        self.t = 0
        self.ants = []
        #self.ant_graphs=[]
        #self.global_scores=[]

        
        # Call our setup methods to initialize space, people, and institution.
        self.setup_space()
        self.setup_ants()
        

    def setup_space(self):
        """
        Method to setup our space.
        """
        # Initialize a space with a grid network
        self.g = nx.grid_graph(dim=self.size)
        self.g=self.g.to_directed()
        
        #Set Pheromones
        print('Setting up network')
        for e in self.g.edges_iter():
            self.g.add_edge(e[0],e[1],capacity=0)
            self.g.add_edge(e[0],e[1],edge_pheromone=[self.initial_pheromone]*2)
            self.g.add_edge(e[0],e[1],capacity_pheromone=[[self.initial_pheromone]*len(self.capacities)]*2)

        self.g_layout = nx.spectral_layout(self.g)
 
        
    def setup_ants(self):
        """
        Method to setup our space.
        """       
        # First, begin by creating all ants.
        int_id=0 #set up list ID of ants
        self.ant_id_dict={} #set up dict converting ant id to list id
        for c in xrange(self.num_colonies):
            for i in xrange(self.num_ants):
                self.ants.append(Ant(model=self,ant_id=i,colony_id=c))
                self.ant_id_dict[(i,c)]=int_id                
                int_id+=1
        print self.ant_id_dict
            
    def get_edge_pheromone(self,edge,ant_id):
        """
        Get edge decision pheromone for ant call
        """        
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        pheromone_1=self.g[edge[0]][edge[1]]['edge_pheromone'][0]
        pheromone_2=self.g[edge[0]][edge[1]]['edge_pheromone'][1]
                
        return (pheromone_1**ant_weight)*(pheromone_2**(1-ant_weight))
    
    def get_capacity_pheromone(self,edge,ant_id):
        """
        Get edge decision pheromone for ant call
        """  
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        pheromone_1=self.g[edge[0]][edge[1]]['capacity_pheromone'][0]
        pheromone_2=self.g[edge[0]][edge[1]]['capacity_pheromone'][1]
        
        weighted_pheromone_1=[i**ant_weight for i in pheromone_1]
        weighted_pheromone_2=[i**(1-ant_weight) for i in pheromone_2]
        composite_pheromone=[weighted_pheromone_1[i]*weighted_pheromone_2[i] for i in xrange(len(weighted_pheromone_1))]

        
        return composite_pheromone
        
        
    def get_ant_neighbors(self,node):
        """
        Get node neighbors for ant call
        """
        return self.g.neighbors(node)
            
    def get_path(self, ant_id):
        """
        Get the path of an ant based on their ID.
        """
        ant_list_id=self.ant_id_dict[ant_id]
        return self.ants[ant_list_id].random_walk(self.source,self.sink)
    
    def evaluate_graph(self, ant_graph):
        """
        Score graphs based on criteria.
        """
        #Score 1 - Length
        length_score=ant_graph.number_of_edges()
        
        #Score 2 - Flow
        #add aggregate sink
        flow_graph=ant_graph.copy()
        for i in xrange(len(self.sink)):
            flow_graph.add_edge(self.sink[i],'sink',capacity=self.sink_magnitude[i])
        
        #add aggregate source
        for i in xrange(len(self.source)):
            flow_graph.add_edge('source',self.source[i],capacity=self.source_magnitude[i])
        
        flow_value, flow_dict = nx.maximum_flow(flow_graph, 'source', 'sink')
        
        #flow is judged by the amount of flow that gets to the aggregate sink based on the total sink magnitude 
        flow_score=float(flow_value)/sum(self.sink_magnitude)       
        return (flow_score,length_score)
    
    def dominates(self, point_1, point_2, equality_sequence):
        '''
        Calculates if a point is dominated by another point, used in simple_cull_front
        equality_sequence:= 1 is '>=',0 is '<='
        '''
        score=0
        for i in range(len(point_1)):
            if equality_sequence[i]==1 and point_1[i]>=point_2[i]:
                score+=1
            elif equality_sequence[i]==0 and point_1[i]<=point_2[i]:
                score+=1
        dom=score==len(point_1)    
        return dom    
   
    def simple_cull_front(self, inputPoints, dominates, equality_sequence):
        '''
        Basic algorithm to find the pareto front of a set of points
        min or max is determined based on equality_sequence:= 0 is min, 1 is max
        '''
        paretoPoints = set()
        candidateRowNr = 0
        dominatedPoints = set()
        while True:
            candidateRow = inputPoints[candidateRowNr]
            inputPoints.remove(candidateRow)
            rowNr = 0
            nonDominated = True
            while len(inputPoints) != 0 and rowNr < len(inputPoints):
                row = inputPoints[rowNr]
                if self.dominates(candidateRow, row,equality_sequence):
                    # If it is worse on all features remove the row from the array
                    inputPoints.remove(row)
                    dominatedPoints.add(tuple(row))
                elif self.dominates(row, candidateRow, equality_sequence):
                    nonDominated = False
                    dominatedPoints.add(tuple(candidateRow))
                    rowNr += 1
                else:
                    rowNr += 1

            if nonDominated:
                # add the non-dominated point to the Pareto frontier
                paretoPoints.add(tuple(candidateRow))

            if len(inputPoints) == 0:
                break
        return paretoPoints, dominatedPoints

    
    def ant_ranking(self, ant_graphs):
        """
        Find best Ants based on scores from evaluate_graph.
        """
        score_list=[]
        [score_list.append(graph[1]) for graph in ant_graphs]
        #self.global_scores.extend(score_list) # include for getting p.f. form all past solutions
        #cull_scores=self.global_scores[:] # include for getting p.f. form all past solutions
        cull_scores=score_list[:]
        #print cull_scores,'cull_scores'
        #print self.global_scores,'before'
        equality_sequence=[1,0] #[>=,<=]
        paretoPoints, dominatedPoints=self.simple_cull_front(cull_scores,self.dominates,equality_sequence)
        paretoPoints=list(paretoPoints)
        #print 'pareto front',paretoPoints
        #print self.global_scores,'after'
        #get the best ants based on pareto front
        best_ants_index=[]
        
        #match the score_list indices to the pareto front values
        for i in xrange(len(score_list)):
            if score_list[i] in paretoPoints:
                best_ants_index.append(i)
                print 'pareto score @',i,':',score_list[i]
                
        return best_ants_index, score_list
    
    
    def step(self):
        """
        Model step function.
        """
        #Ants make paths
        self.ant_graphs=[] #exclude for initialized in setup for global pareto front
        
        #Step for each ant
        for c in xrange(self.num_colonies):
            for i in xrange(self.num_ants):
                self.ant_graph=self.get_path((i,c))

                #Evaluate Paths
                self.graph_score=self.evaluate_graph(self.ant_graph) 

                #List <graph,score>
                self.ant_graphs.append((self.ant_graph,self.graph_score))
            
        #Get best score
        self.opt_ant,self.score_list=self.ant_ranking(self.ant_graphs)
        
        #Update Institutions - Edges and capacities for this walk
        #Get pheromones
        self.edge_pheromone_dict=nx.get_edge_attributes(self.g,'edge_pheromone')
        self.capacity_pheromone_dict=nx.get_edge_attributes(self.g,'capacity_pheromone')
        
        #Reduce edge pheromones by input amount
        for key in self.edge_pheromone_dict:    
            self.edge_pheromone_dict[key][0]*=(1-self.dissipation)      
            self.edge_pheromone_dict[key][1]*=(1-self.dissipation)
        
        #for key in self.capacity_pheromone_dict: #Update capacities of all paths
            #for i in xrange(len(self.capacity_pheromone_dict[key][0])):
                #self.capacity_pheromone_dict[key][0][i]*=(1-self.dissipation)
                #self.capacity_pheromone_dict[key][1][i]*=(1-self.dissipation)
                
        #Increment through best paths to update
        for ph_index in xrange(2):
            for ant in self.opt_ant:
                for e in self.ant_graphs[ant][0].edges():
                    #increase the pheromone amount of edges traveled by best ants
                    if ph_index == 0: #flow
                        pheromone_increment=self.score_list[ant][ph_index] #increment for flow
                    else:
                        pheromone_increment=1.0/self.score_list[ant][ph_index] #increment for length
                        
                    self.edge_pheromone_dict[e][ph_index]+=pheromone_increment #1.0/(len(self.opt_ant)) #1/(self.score_list[ant][ph_index])

                    #get capacity chosen and update pheromones
                    self.capacity_chosen=self.ant_graphs[ant][0][e[0]][e[1]]['capacity']
                    self.capacity_index=self.capacities.index(self.capacity_chosen)
                    for i in xrange(len(self.capacity_pheromone_dict[e])):
                        self.capacity_pheromone_dict[e][ph_index][i]*=(1-self.dissipation) #Update capacities of only travelled paths
                        #add pheromone if one chosen
                        if i == self.capacity_index:
                            self.capacity_pheromone_dict[e][ph_index][i]+=pheromone_increment #1.0/(len(self.opt_ant)) #1/(self.score_list[ant][ph_index])                                   
           
        
        #Set new edge pheromones
        nx.set_edge_attributes(self.g, 'edge_pheromone', self.edge_pheromone_dict)
        
        #Set new capacity pheromones
        nx.set_edge_attributes(self.g, 'capacity_pheromone', self.capacity_pheromone_dict)

# %%
'''
Run Example
'''

space=Space(size=[4,4],num_ants=10,num_colonies=10,source=[[(0,0)],[10]],sink=[[(3,3)],[10]],initial_pheromone=1)
converged=0
i=1
while not converged:
    print(i)
    space.step()
    i+=1
    
    print len(space.score_list)
    
    if i>50:
        converged=1
        

print('Ant Path')

    

# Remove the nonpath from path nodes
nonpath_nodes = [node for node in space.g.nodes() if node not in space.ant_graphs[space.opt_ant[0]][0]]

# Now we can visualize the infected node's position
f = plt.figure()
nx.draw_networkx_nodes(space.ant_graphs[space.opt_ant[0]][0], space.g_layout,
                       node_color='red',edge_color='red')

nx.draw_networkx_nodes(space.g, space.g_layout,
                       nodelist=nonpath_nodes,
                       node_color='#dddddd')

nx.draw_networkx_edges(space.g, space.g_layout, 
                       width=1.0, 
                       alpha=0.5,
                       edge_color='#111111')

nx.draw_networkx_edges(space.ant_graphs[space.opt_ant[0]][0], space.g_layout,
                      edgelist=space.ant_graphs[space.opt_ant[0]][0].edges(),
                      width=1.0, 
                      alpha=0.5,
                      edge_color='red')


_ = nx.draw_networkx_labels(space.g, space.g_layout,
                        dict(zip(space.g.nodes(), space.g.nodes())),
                        font_size=10)
_ = nx.draw_networkx_labels(space.g, space.g_layout,
                        dict(zip(space.g.nodes(), space.g.nodes())),
                        font_size=10)
# Out:
# Setting up network
# {(7, 3): 37, (6, 9): 96, (0, 7): 70, (1, 6): 61, (3, 7): 73, (2, 5): 52, (8, 5): 58, (5, 8): 85, (4, 0): 4, (9, 0): 9, (6, 7): 76, (5, 5): 55, (7, 6): 67, (0, 4): 40, (1, 1): 11, (3, 2): 23, (2, 6): 62, (8, 2): 28, (4, 5): 54, (9, 3): 39, (6, 0): 6, (7, 5): 57, (0, 1): 10, (3, 1): 13, (9, 9): 99, (7, 8): 87, (2, 1): 12, (8, 9): 98, (9, 4): 49, (5, 1): 15, (7, 2): 27, (1, 5): 51, (3, 6): 63, (2, 2): 22, (8, 6): 68, (4, 1): 14, (9, 7): 79, (6, 4): 46, (5, 4): 45, (7, 1): 17, (0, 5): 50, (1, 0): 1, (0, 8): 80, (3, 5): 53, (2, 7): 72, (8, 3): 38, (4, 6): 64, (9, 2): 29, (6, 1): 16, (5, 7): 75, (7, 4): 47, (0, 2): 20, (1, 3): 31, (4, 8): 84, (3, 0): 3, (2, 8): 82, (9, 8): 89, (8, 0): 8, (6, 2): 26, (5, 0): 5, (1, 4): 41, (3, 9): 93, (2, 3): 32, (1, 9): 91, (8, 7): 78, (4, 2): 24, (9, 6): 69, (6, 5): 56, (5, 3): 35, (7, 0): 7, (6, 8): 86, (0, 6): 60, (1, 7): 71, (0, 9): 90, (3, 4): 43, (2, 4): 42, (8, 4): 48, (5, 9): 95, (4, 7): 74, (9, 1): 19, (6, 6): 66, (5, 6): 65, (7, 7): 77, (0, 3): 30, (1, 2): 21, (4, 9): 94, (3, 3): 33, (2, 9): 92, (8, 1): 18, (4, 4): 44, (6, 3): 36, (0, 0): 0, (7, 9): 97, (3, 8): 83, (2, 0): 2, (1, 8): 81, (8, 8): 88, (4, 3): 34, (9, 5): 59, (5, 2): 25}
# 1
# pareto score @ 12 : (0.5, 7)
# pareto score @ 70 : (0.6, 21)
# pareto score @ 87 : (1.0, 36)
# 100
# 2
# pareto score @ 21 : (0.1, 6)
# pareto score @ 23 : (0.5, 8)
# pareto score @ 33 : (1.0, 19)
# pareto score @ 68 : (0.1, 6)
# pareto score @ 99 : (0.1, 6)
# 100
# 3
# pareto score @ 0 : (0.5, 6)
# pareto score @ 45 : (1.0, 8)
# pareto score @ 51 : (0.5, 6)
# 100
# 4
# pareto score @ 7 : (0.5, 6)
# pareto score @ 19 : (1.0, 11)
# pareto score @ 44 : (0.5, 6)
# 100
# 5
# pareto score @ 77 : (1.0, 6)
# 100
# 6
# pareto score @ 28 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# 100
# 7
# pareto score @ 17 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# 100
# 8
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 9
# pareto score @ 0 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 10
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 11
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 12
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 13
# pareto score @ 0 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 14
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 15
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 16
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 17
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 18
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 19
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 20
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 21
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 22
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 23
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 24
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 25
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# ...
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 46
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 47
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 48
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 49
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# 50
# pareto score @ 0 : (1.0, 6)
# pareto score @ 1 : (1.0, 6)
# pareto score @ 2 : (1.0, 6)
# pareto score @ 3 : (1.0, 6)
# pareto score @ 4 : (1.0, 6)
# pareto score @ 5 : (1.0, 6)
# pareto score @ 6 : (1.0, 6)
# pareto score @ 7 : (1.0, 6)
# pareto score @ 8 : (1.0, 6)
# pareto score @ 9 : (1.0, 6)
# pareto score @ 10 : (1.0, 6)
# pareto score @ 11 : (1.0, 6)
# pareto score @ 12 : (1.0, 6)
# pareto score @ 13 : (1.0, 6)
# pareto score @ 14 : (1.0, 6)
# pareto score @ 15 : (1.0, 6)
# pareto score @ 16 : (1.0, 6)
# pareto score @ 17 : (1.0, 6)
# pareto score @ 18 : (1.0, 6)
# pareto score @ 19 : (1.0, 6)
# pareto score @ 20 : (1.0, 6)
# pareto score @ 21 : (1.0, 6)
# pareto score @ 22 : (1.0, 6)
# pareto score @ 23 : (1.0, 6)
# pareto score @ 24 : (1.0, 6)
# pareto score @ 25 : (1.0, 6)
# pareto score @ 26 : (1.0, 6)
# pareto score @ 27 : (1.0, 6)
# pareto score @ 28 : (1.0, 6)
# pareto score @ 29 : (1.0, 6)
# pareto score @ 30 : (1.0, 6)
# pareto score @ 31 : (1.0, 6)
# pareto score @ 32 : (1.0, 6)
# pareto score @ 33 : (1.0, 6)
# pareto score @ 34 : (1.0, 6)
# pareto score @ 35 : (1.0, 6)
# pareto score @ 36 : (1.0, 6)
# pareto score @ 37 : (1.0, 6)
# pareto score @ 38 : (1.0, 6)
# pareto score @ 39 : (1.0, 6)
# pareto score @ 40 : (1.0, 6)
# pareto score @ 41 : (1.0, 6)
# pareto score @ 42 : (1.0, 6)
# pareto score @ 43 : (1.0, 6)
# pareto score @ 44 : (1.0, 6)
# pareto score @ 45 : (1.0, 6)
# pareto score @ 46 : (1.0, 6)
# pareto score @ 47 : (1.0, 6)
# pareto score @ 48 : (1.0, 6)
# pareto score @ 49 : (1.0, 6)
# pareto score @ 50 : (1.0, 6)
# pareto score @ 51 : (1.0, 6)
# pareto score @ 52 : (1.0, 6)
# pareto score @ 53 : (1.0, 6)
# pareto score @ 54 : (1.0, 6)
# pareto score @ 55 : (1.0, 6)
# pareto score @ 56 : (1.0, 6)
# pareto score @ 57 : (1.0, 6)
# pareto score @ 58 : (1.0, 6)
# pareto score @ 59 : (1.0, 6)
# pareto score @ 60 : (1.0, 6)
# pareto score @ 61 : (1.0, 6)
# pareto score @ 62 : (1.0, 6)
# pareto score @ 63 : (1.0, 6)
# pareto score @ 64 : (1.0, 6)
# pareto score @ 65 : (1.0, 6)
# pareto score @ 66 : (1.0, 6)
# pareto score @ 67 : (1.0, 6)
# pareto score @ 68 : (1.0, 6)
# pareto score @ 69 : (1.0, 6)
# pareto score @ 70 : (1.0, 6)
# pareto score @ 71 : (1.0, 6)
# pareto score @ 72 : (1.0, 6)
# pareto score @ 73 : (1.0, 6)
# pareto score @ 74 : (1.0, 6)
# pareto score @ 75 : (1.0, 6)
# pareto score @ 76 : (1.0, 6)
# pareto score @ 77 : (1.0, 6)
# pareto score @ 78 : (1.0, 6)
# pareto score @ 79 : (1.0, 6)
# pareto score @ 80 : (1.0, 6)
# pareto score @ 81 : (1.0, 6)
# pareto score @ 82 : (1.0, 6)
# pareto score @ 83 : (1.0, 6)
# pareto score @ 84 : (1.0, 6)
# pareto score @ 85 : (1.0, 6)
# pareto score @ 86 : (1.0, 6)
# pareto score @ 87 : (1.0, 6)
# pareto score @ 88 : (1.0, 6)
# pareto score @ 89 : (1.0, 6)
# pareto score @ 90 : (1.0, 6)
# pareto score @ 91 : (1.0, 6)
# pareto score @ 92 : (1.0, 6)
# pareto score @ 93 : (1.0, 6)
# pareto score @ 94 : (1.0, 6)
# pareto score @ 95 : (1.0, 6)
# pareto score @ 96 : (1.0, 6)
# pareto score @ 97 : (1.0, 6)
# pareto score @ 98 : (1.0, 6)
# pareto score @ 99 : (1.0, 6)
# 100
# Ant Path

# %%
print space.ants
space.ants[0]
# Out:
# [Ant [ant_id=(0, 0), base_node=(2, 1, 2), capacity_pheromone_list=[0.0, 0.0, 1.0], capacity_to_add=10, cumulative_percent=[ 0.  0.  1.], edge_pheromone_list=[68.26832059159733, 1.6279976085368206e-05, 1.603924933292966e-05, 1.784059615882453e-05, 2.1097440197222947e-05, 1.6076725063721516e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[0.0, 0.0, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(1, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[83.30680095916786, 1.9285958673734868e-05, 2.0073520422917203e-05, 1.784059615882454e-05, 2.6713426822835295e-05, 1.90859244414524e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[1e-323, 1e-323, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(2, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[101.65803151314975, 2.2846974713881884e-05, 2.512251127251936e-05, 1.784059615882455e-05, 3.3824348638888816e-05, 2.2658377893569978e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[1e-323, 1e-323, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(3, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[124.05176110644138, 2.706550721212717e-05, 3.144144919977822e-05, 1.7840596158824545e-05, 4.282814662576743e-05, 2.689951384554215e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[1e-323, 1e-323, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(4, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[151.37849124708862, 3.206296193800282e-05, 3.9349757556426714e-05, 1.784059615882453e-05, 5.422869078665255e-05, 3.1934494539957924e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[1e-323, 1e-323, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(5, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[184.72488748130317, 3.798316137881912e-05, 4.9247202630866186e-05, 1.784059615882454e-05, 6.866397769043512e-05, 3.7911909760837895e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[1e-323, 1e-323, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]], Ant [ant_id=(6, 0), base_node=(2, 1, 2), capacity_pheromone_list=[1e-323, 1e-323, 1.0], capacity_to_add=10, cumulative_percent=[  9.88131292e-324   1.97626258e-323   1.00000000e+000], edge_pheromone_list=[225.41699136954762, 4.4996483828258606e-05, 6.163410189980921e-05, 1.784059615882454e-05, 8.694183399745696e-05, 4.500816193960679e-05], g=,  ...
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:119: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# Ant [ant_id=(0, 0), base_node=(2, 1, 2), capacity_pheromone_list=[0.0, 0.0, 1.0], capacity_to_add=10, cumulative_percent=[ 0.  0.  1.], edge_pheromone_list=[68.26832059159733, 1.6279976085368206e-05, 1.603924933292966e-05, 1.784059615882453e-05, 2.1097440197222947e-05, 1.6076725063721516e-05], g=, last_nodes=[(2, 2, 2)], last_nodes_next=[(2, 2, 2)], next_node=(2, 2, 2), p_neighbors=[(2, 2, 2), (2, 1, 1), (2, 0, 2), (3, 1, 2), (1, 1, 2), (2, 1, 3)], percent_list=[0.0, 0.0, 1.0], potential_node=(2, 1, 3), select_index=2, sink=[(2, 2, 2)], source=[(0, 0, 0)]]

# %%
space.ants
# Out:
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:119: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# [Ant [ant_id=(0, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680233e-163, 2.4265998838869765e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[1.7796322376194008e-05, 2.068690521437352e-05, 2.306238490245656e-05, 21.42739133307464], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680233e-163, 2.4265998838869765e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(1, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[1.895563341875108e-05, 2.3311247715339097e-05, 2.609884086515543e-05, 24.99567264906925], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(2, 0), base_node=(1, 2), capacity_pheromone_list=[4.4433358306804176e-163, 2.4265998838870774e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.0190465800210874e-05, 2.626851452233325e-05, 2.953508483123757e-05, 29.158176161884544], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.4433358306804176e-163, 2.4265998838870774e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(3, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.150573922927992e-05, 2.960094044026569e-05, 3.342375397035486e-05, 34.013857079343325], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(4, 0), base_node=(1, 2), capacity_pheromone_list=[4.4433358306802326e-163, 2.4265998838869762e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.290669390069043e-05, 3.3356118184878934e-05, 3.782441580425967e-05, 39.678149517676104], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.4433358306802326e-163, 2.4265998838869762e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(5, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.4398911372715372e-05, 3.758767808775827e-05, 4.2804480675703734e-05, 46.285710717093856], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(6, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.598833680471349e-05, 4.23560540287752e-05, 4.844023435545973e-05, 53.99362224874172], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(7, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.768130264330152e-05, 4.772934653478403e-05, 5.481800660517612e-05, 62.98512431533558], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(8, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.9484553851521463e-05, 5.3784295371090215e-05, 6.20354935963772e-05, 73.47397192102126], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(9, 0), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[3.140527478151886e-05, 6.0607375515952376e-05, 7.020325444272495e-05, 85.70951646969465], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(0, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680233e-163, 2.4265998838869765e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[1.7796322376194008e-05, 2.068690521437352e-05, 2.306238490245656e-05, 21.42739133307464], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680233e-163, 2.4265998838869765e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(1, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[1.895563341875108e-05, 2.3311247715339097e-05, 2.609884086515543e-05, 24.99567264906925], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(2, 1), base_node=(1, 2), capacity_pheromone_list=[4.4433358306804176e-163, 2.4265998838870774e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.0190465800210874e-05, 2.626851452233325e-05, 2.953508483123757e-05, 29.158176161884544], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.4433358306804176e-163, 2.4265998838870774e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(3, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.150573922927992e-05, 2.960094044026569e-05, 3.342375397035486e-05, 34.013857079343325], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(4, 1), base_node=(1, 2), capacity_pheromone_list=[4.4433358306802326e-163, 2.4265998838869762e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.290669390069043e-05, 3.3356118184878934e-05, 3.782441580425967e-05, 39.678149517676104], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.4433358306802326e-163, 2.4265998838869762e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(5, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.4398911372715372e-05, 3.758767808775827e-05, 4.2804480675703734e-05, 46.285710717093856], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(6, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.598833680471349e-05, 4.23560540287752e-05, 4.844023435545973e-05, 53.99362224874172], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680325e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(7, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.768130264330152e-05, 4.772934653478403e-05, 5.481800660517612e-05, 62.98512431533558], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(8, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[2.9484553851521463e-05, 5.3784295371090215e-05, 6.20354935963772e-05, 73.47397192102126], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870265e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]],
#  Ant [ant_id=(9, 1), base_node=(1, 2), capacity_pheromone_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], capacity_to_add=10, cumulative_percent=[  4.44333583e-163   6.86993571e-163   1.00000000e+000], edge_pheromone_list=[3.140527478151886e-05, 6.0607375515952376e-05, 7.020325444272495e-05, 85.70951646969465], g=, last_nodes=[(2, 2)], last_nodes_next=[(2, 2)], next_node=(2, 2), p_neighbors=[(1, 3), (0, 2), (1, 1), (2, 2)], percent_list=[4.443335830680326e-163, 2.4265998838870268e-163, 1.0], potential_node=(2, 2), select_index=2, sink=[(2, 2)], source=[(0, 0)]]]

# %%
id_dict={}
id_dict[0]=(0,0)
id_dict[(0,0)]=0
print id_dict
# Out:
# {0: (0, 0), (0, 0): 0}

# %%
id_dict[(0,0)]
# Out:
# 0

# %%
space.ant_id_dict
# Out:
# {(0, 0): 0,
#  (0, 1): 10,
#  (1, 0): 1,
#  (1, 1): 11,
#  (2, 0): 2,
#  (2, 1): 12,
#  (3, 0): 3,
#  (3, 1): 13,
#  (4, 0): 4,
#  (4, 1): 14,
#  (5, 0): 5,
#  (5, 1): 15,
#  (6, 0): 6,
#  (6, 1): 16,
#  (7, 0): 7,
#  (7, 1): 17,
#  (8, 0): 8,
#  (8, 1): 18,
#  (9, 0): 9,
#  (9, 1): 19}
