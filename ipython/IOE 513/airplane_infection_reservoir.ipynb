# %%
# Imports
import copy
import networkx as nx
import numpy as np
import scipy as sc
import pandas
import seaborn; seaborn.set()

# %%
class Model(object):
    def __init__(self,graph,initial_infected=1000,reservoir=0,reproduction_number=.65,effective_contacts=15,prob_of_flying_day=.0005,passengers_per_flight=150,screening_effectiveness=0,throttle=0):
        #set pararms
        self.g=graph
        self.initial_infected=initial_infected
        self.reproduction_number=reproduction_number
        self.prob_of_flying_day=prob_of_flying_day
        self.prob_of_flying=1-(1-self.prob_of_flying_day)**30
        self.effective_contacts=effective_contacts
        self.transmission_rate=self.reproduction_number/self.effective_contacts
        self.passengers_per_flight=passengers_per_flight
        self.reservoir=reservoir
        self.screening_effectiveness=screening_effectiveness
        self.throttle=throttle
        
        #set state variables
        self.t=0
        self.history_infected=[]
        self.history_cities_infected=[]
        self.history_infected_interactions=[]
        self.history_space=[]
        self.history_infected_interactions=[]
        self.num_interactions=0
        self.history_num_interactions=[]
        self.time_series_data=[]
        #self call setup
        self.setup_space()
        
    def setup_space(self):
        self.num_infected=0
        self.num_hosts_infected=0
        for node_id in self.g.nodes():
            if node_id == 366: #366 is Jeddah, Saudi Arabia where many MERS infections are
                self.g.node[node_id]['infected']=self.initial_infected
                self.g.node[node_id]["state"] = "I"
                self.num_hosts_infected+=1
                self.num_infected+=self.g.node[node_id]['infected']
                neighbors = self.g.neighbors(node_id)
                for neighbor_id in neighbors: #set throttling for routes
                    print 'before throttle',self.g.edge[node_id][neighbor_id]['weight']
                    self.g.edge[node_id][neighbor_id]['weight']=int(np.ceil(self.g.edge[node_id][neighbor_id]['weight']*(1-self.throttle)))
                    print 'after throttle',self.g.edge[node_id][neighbor_id]['weight']
            else:
                self.g.node[node_id]['infected']=0
                self.g.node[node_id]["state"] = "S"
        
        
        # Track the latest step
        self.history_space.append(copy.deepcopy(self.g))
        self.history_infected.append(self.num_infected)
        self.history_cities_infected.append(self.num_hosts_infected)
        self.num_interactions=0
        self.time_series_data.append((self.num_infected,self.num_hosts_infected,self.num_interactions))
        
        
    def step(self):
        #self.g_step=self.history_space[-1]
        self.g_step=self.g
        self.num_interactions=0
        # Iterate over I and infect any S neighbors
        for self.node_id in self.g.nodes():
            if self.g.node[self.node_id]["state"] == "I":

                # Decide how many infected are traveling
                prob_flying=self.prob_of_flying
                if self.node_id == 366:
                    prob_flying=self.prob_of_flying*(1-self.screening_effectiveness)*(1-self.throttle)
                    
                self.infected_traveling=np.random.binomial(self.g.node[self.node_id]['infected'],prob_flying)

                #check
                if self.infected_traveling>self.g.node[self.node_id]['infected']:
                    self.infected_traveling=self.g.node[self.node_id]['infected']
                    
                # Get travel options
                self.neighbors = self.g.neighbors(self.node_id)
                #print('neighbors',neighbors)
                self.passenger_list=[] #list of passengers on each route
                self.plane_list=[] #list of planes on each route
                for self.neighbor_id in self.neighbors:
                    route_passengers=self.g.edge[self.node_id][self.neighbor_id]['weight']
                    self.passenger_list.append(route_passengers)
                    num_planes=int(np.ceil(float(route_passengers)/self.passengers_per_flight))
                    self.plane_list.append([1.0/float(num_planes)]*num_planes) #probablity of taking a plane
                    #print self.plane_list[-1], 'initialize planes'
                                  

                #print('passenger_list',passenger_list)
                # Create passenger distribution
                self.percent_list = [float(i)/sum(self.passenger_list) for i in self.passenger_list]

                #passenger_dist=np.cumsum(percent_list)
                #print('passenger_dist',percent_list)

                # Create travel distribution
                self.travel_dist=np.random.multinomial(self.infected_traveling, self.percent_list)
                #print('travel_dist',travel_dist)

                # Convert number of travelers to infection
                self.infected_travelers=[]
                for i in xrange(len(self.travel_dist)):
                    self.moving_passengers=self.travel_dist[i]
                    #print self.plane_list[i], 'plane percentage list' 
                    passenger_dist=np.random.multinomial(self.moving_passengers,self.plane_list[i]) #number of infected passengers per plane
                    arriving_infected_total=0
                    #print passenger_dist
                    for j in xrange(len(passenger_dist)):
                         
                        num_infected_plane=passenger_dist[j]
                        p_infect=1-(1-self.transmission_rate)**num_infected_plane #probability a single uninfected passenger gets infected based number of infected on plane
                        arriving_infected_plane=num_infected_plane+np.random.binomial((self.passengers_per_flight-num_infected_plane),
                                                                                      p_infect)
                        #print arriving_infected_plane
                        arriving_infected_total+=arriving_infected_plane
                    
                    self.infected_travelers.append(arriving_infected_total)
                        
                
                    #self.max_passengers=self.g.edge[self.node_id][self.neighbors[i]]['weight']
                    #self.moving_passengers*=self.transmission_rate*self.passengers_per_flight*np.random.normal(1,.15,1)
                    #self.moving_passengers=int(self.moving_passengers)
                    #if self.moving_passengers>self.max_passengers:
                        #self.moving_passengers=self.max_passengers
                        
                    #self.infected_travelers.append(self.moving_passengers)    
                #print self.infected_travelers
                
                # Node update
                # Calculate in host spread
                #print self.node_id,'initial',self.g.node[self.node_id]['infected']
                self.new_infected=int(self.g.node[self.node_id]['infected']*self.reproduction_number)
                #print self.node_id,'spread',self.new_infected
                # Calculate in host death
                self.removed_infected=self.g.node[self.node_id]['infected']
                #print self.node_id,'removed',self.removed_infected
                #print self.node_id,'flying',sum(self.infected_travelers)
                # Spread to neighbors
                for i in xrange(len(self.neighbors)):
                    self.neighbor_id=self.neighbors[i]

                    # Move Infected
                    self.num_infected_at_neighbor=self.g.node[self.neighbor_id]['infected']
                    self.g_step.node[self.neighbor_id]['infected']=self.num_infected_at_neighbor+self.infected_travelers[i]
                    if self.infected_travelers[i]>0:
                        self.history_infected_interactions.append((self.t,self.node_id,self.neighbor_id,self.travel_dist[i],self.infected_travelers[i]))
                        self.num_interactions+=1
                    #self.g_step.node[self.node_id]['infected']=self.g.node[self.node_id]['infected']-self.infected_travelers[i]

                # Sum new infection change
                self.new_infected_total=int(max(self.g.node[self.node_id]['infected']+self.new_infected-self.removed_infected,0))
                
                #maintain reservoir of infection in Jeddah              
                if self.node_id == 366 and self.new_infected_total<self.initial_infected and self.reservoir==1:
                    self.new_infected_total=self.initial_infected
                    #print 'reservoir maintenance'
                    
                self.g_step.node[self.node_id]['infected']=int(self.new_infected_total)
                #print self.node_id,'new infected total',self.new_infected_total
                #print self.node_id,'new infected total graph',self.g_step.node[self.node_id]['infected']
                
        # Update graph
        self.num_infected=0
        self.num_hosts_infected=0
        for self.node_id in self.g_step.nodes():
            if self.g_step.node[self.node_id]['infected']>0:
                #print g.node[self.node_id]['old_label'],'number infected',self.g_step.node[self.node_id]['infected']
                self.g_step.node[self.node_id]["state"] = "I"
                self.num_hosts_infected+=1
                self.num_infected+=int(self.g_step.node[self.node_id]['infected'])
                #print self.node_id,'number infected',self.g_step.node[self.node_id]['infected']
            else:
                self.g_step.node[self.node_id]["state"] = "S"

        # Resolve g_step to g ***Not Resolving***
        self.g=self.g_step

        # Track the latest step
        self.history_space.append(copy.deepcopy(self.g))
        self.t+=1
        self.history_infected.append(self.num_infected)
        self.history_cities_infected.append(self.num_hosts_infected)
        self.history_num_interactions.append(self.num_interactions)
        self.time_series_data.append((self.num_infected,self.num_hosts_infected,self.num_interactions))

# %%
#TEST
# Initialize Space
g=nx.read_weighted_edgelist("2010citytocity_monthly.csv",nodetype=str,delimiter=',')
g=nx.convert_node_labels_to_integers(g,label_attribute='old_label')
g=g.to_directed()

m=Model(g,reproduction_number=.6,reservoir=0,screening_effectiveness=0,throttle=.7)
loop=0
while m.history_infected[-1]>0 and loop<36:
    print 'time step',m.t,'has',m.history_infected[-1], 'infected in',m.history_cities_infected[-1], 'city'
    print 'number of interactions',m.num_interactions
    m.step()
    loop+=1
print 'History:',m.history_infected
# Out:
# before throttle 1.0
# after throttle 1
# before throttle 1.0
# after throttle 1
# before throttle 1095.0
# after throttle 329
# before throttle 933.0
# after throttle 280
# before throttle 2.0
# after throttle 1
# time step 0 has 1000 infected in 1 city
# number of interactions 0
# time step 1 has 600 infected in 1 city
# number of interactions 0
# time step 2 has 369 infected in 3 city
# number of interactions 2
# time step 3 has 245 infected in 4 city
# number of interactions 3
# time step 4 has 151 infected in 4 city
# number of interactions 1
# time step 5 has 90 infected in 4 city
# number of interactions 0
# time step 6 has 54 infected in 4 city
# number of interactions 1
# time step 7 has 38 infected in 3 city
# number of interactions 1
# time step 8 has 22 infected in 2 city
# number of interactions 0
# time step 9 has 19 infected in 3 city
# number of interactions 1
# time step 10 has 32 infected in 4 city
# number of interactions 2
# time step 11 has 25 infected in 5 city
# number of interactions 1
# time step 12 has 13 infected in 5 city
# number of interactions 0
# time step 13 has 10 infected in 3 city
# number of interactions 1
# time step 14 has 5 infected in 2 city
# number of interactions 0
# time step 15 has 2 infected in 1 city
# number of interactions 0
# time step 16 has 1 infected in 1 city
# number of interactions 0
# History: [1000, 600, 369, 245, 151, 90, 54, 38, 22, 19, 32, 25, 13, 10, 5, 2, 1, 0]

# %%
[.1]*2
# Out:
# [0.1, 0.1]

# %%
print sc.misc.comb(149,0)
comb=sc.misc.comb(149,1)
print comb
print (.65/15)**2
# Out:
# 1.0
# 149.0
# 0.00187777777778

# %%
p_in_ex=0
n=3
r=.005
for k in xrange(n):
    uninfected=2-n
    print uninfected
    print k+1
    comb=sc.misc.comb(uninfected,k+1)
    p_n=r**(k+1)
    sign=(-1)**(k)
    p_in_ex+=comb*p_n*sign
    print comb
    print p_n
    print sign
    print p_in_ex
# Out:
# -1
# 1
# 0.0
# 0.005
# 1
# 0.0
# -1
# 2
# 0.0
# 2.5e-05
# -1
# 0.0
# -1
# 3
# 0.0
# 1.25e-07
# 1
# 0.0

# %%
p_in_ex=0
n=149
r=.005
rc=1-r
p=150
p_uninfected=rc**n
p_infect=1-p_uninfected
arriving_infected=n+np.random.binomial((p-n),p_infect)
print arriving_infected
# Out:
# 0.473847977308
# 150

# %%
150*.005
# Out:
# 0.75

# %%
g.node[0]['old_label']
# Out:
# 'Morelia:Mexico'

# %%
g.node
# Out:
# {0: {'infected': 0, 'old_label': 'Morelia:Mexico', 'state': 'S'},
#  1: {'infected': 0, 'old_label': 'Bucaramanga:Colombia', 'state': 'S'},
#  2: {'infected': 0, 'old_label': 'Indianapolis:IN', 'state': 'S'},
#  3: {'infected': 0, 'old_label': 'Cardiff:United Kingdom', 'state': 'S'},
#  4: {'infected': 0, 'old_label': 'Maracaibo:Venezuela', 'state': 'S'},
#  5: {'infected': 0, 'old_label': 'Ezeiza:Argentina', 'state': 'S'},
#  6: {'infected': 0, 'old_label': 'Newport News/Hampton:VA', 'state': 'S'},
#  7: {'infected': 0, 'old_label': 'Reno:NV', 'state': 'S'},
#  8: {'infected': 0, 'old_label': 'Istanbul:Turkey', 'state': 'S'},
#  9: {'infected': 0, 'old_label': 'Brize Norton:United Kingdom', 'state': 'S'},
#  10: {'infected': 0, 'old_label': 'Augusta:GA', 'state': 'S'},
#  11: {'infected': 0, 'old_label': 'Charleston/Dunbar:WV', 'state': 'S'},
#  12: {'infected': 0, 'old_label': 'Delhi:India', 'state': 'S'},
#  13: {'infected': 0, 'old_label': 'Chicago:IL', 'state': 'S'},
#  14: {'infected': 0,
#   'old_label': 'Port of Spain:Trinidad and Tobago',
#   'state': 'S'},
#  15: {'infected': 0, 'old_label': 'Battle Creek:MI', 'state': 'S'},
#  16: {'infected': 0, 'old_label': 'Venice:Italy', 'state': 'S'},
#  17: {'infected': 0, 'old_label': 'Fukuoka:Japan', 'state': 'S'},
#  18: {'infected': 0, 'old_label': 'Hamburg:Germany', 'state': 'S'},
#  19: {'infected': 0, 'old_label': 'Clifton:AZ', 'state': 'S'},
#  20: {'infected': 0, 'old_label': 'San Pedro Sula:Honduras', 'state': 'S'},
#  21: {'infected': 0, 'old_label': 'Rota:TT', 'state': 'S'},
#  22: {'infected': 0, 'old_label': 'Chihuahua:Mexico', 'state': 'S'},
#  23: {'infected': 0, 'old_label': 'San Luis Potosi:Mexico', 'state': 'S'},
#  24: {'infected': 0, 'old_label': 'Mexico City:Mexico', 'state': 'S'},
#  25: {'infected': 0, 'old_label': 'Prague:Czech Republic', 'state': 'S'},
#  26: {'infected': 0, 'old_label': 'Mazatlan:Mexico', 'state': 'S'},
#  27: {'infected': 0, 'old_label': 'Jackson/Vicksburg:MS', 'state': 'S'},
#  28: {'infected': 0, 'old_label': 'Cape Town:South Africa', 'state': 'S'},
#  29: {'infected': 0,
#   'old_label': 'St. Pierre:Saint Pierre and Miquelon',
#   'state': 'S'},
#  30: {'infected': 0, 'old_label': 'Varadero:Cuba', 'state': 'S'},
#  31: {'infected': 0,
#   'old_label': 'Yap:Federated States of Micronesia',
#   'state': 'S'},
#  32: {'infected': 0, 'old_label': 'Westhampton:NY', 'state': 'S'},
#  33: {'infected': 0, 'old_label': 'Manama:Bahrain', 'state': 'S'},
#  34: {'infected': 0, 'old_label': 'Fort Yukon:AK', 'state': 'S'},
#  35: {'infected': 0, 'old_label': 'Nuremberg:Germany', 'state': 'S'},
#  36: {'infected': 0, 'old_label': 'Lihue:HI', 'state': 'S'},
#  37: {'infected': 0, 'old_label': 'Sal Island:Cape Verde', 'state': 'S'},
#  38: {'infected': 0, 'old_label': 'Copenhagen:Denmark', 'state': 'S'},
#  39: {'infected': 0, 'old_label': 'Cucuta:Colombia', 'state': 'S'},
#  40: {'infected': 0, 'old_label': 'Athens:Greece', 'state': 'S'},
#  41: {'infected': 0, 'old_label': 'Krakow:Poland', 'state': 'S'},
#  42: {'infected': 0, 'old_label': 'Shanghai:China', 'state': 'S'},
#  43: {'infected': 0, 'old_label': 'Atlantic City:NJ', 'state': 'S'},
#  44: {'infected': 0, 'old_label': 'Monticello:NY', 'state': 'S'},
#  45: {'infected': 0, 'old_label': 'Iqaluit:Canada', 'state': 'S'},
#  46: {'infected': 0, 'old_label': 'Gorge Harbor:Canada', 'state': 'S'},
#  47: {'infected': 0, 'old_label': 'Roanoke:VA', 'state': 'S'},
#  48: {'infected': 0, 'old_label': 'Big Bay Marina:Canada', 'state': 'S'},
#  49: {'infected': 0, 'old_label': 'Helena:MT', 'state': 'S'},
#  50: {'infected': 0, 'old_label': 'Anacortes:WA', 'state': 'S'},
#  51: {'infected': 0, 'old_label': 'Santiago:Chile', 'state': 'S'},
#  52: {'infected': 0, 'old_label': 'Manaus:Brazil', 'state': 'S'},
#  53: {'infected': 0, 'old_label': 'Columbia:SC', 'state': 'S'},
#  54: {'infected': 0, 'old_label': 'Houston:TX', 'state': 'S'},
#  55: {'infected': 0, 'old_label': "St. John's:Canada", 'state': 'S'},
#  56: {'infected': 0, 'old_label': 'Rapid City:SD', 'state': 'S'},
#  57: {'infected': 0, 'old_label': 'Ho Chi Minh City:Vietnam', 'state': 'S'},
#  58: {'infected': 0,
#   'old_label': 'Bonaire:Bonaire:Sint Eustatius:and Saba',
#   'state': 'S'},
#  59: {'infected': 0, 'old_label': 'Whitehorse:Canada', 'state': 'S'},
#  60: {'infected': 0, 'old_label': 'Nootka Sound:Canada', 'state': 'S'},
#  61: {'infected': 0, 'old_label': 'Stephenville:Canada', 'state': 'S'},
#  62: {'infected': 0, 'old_label': 'Bristol:United Kingdom', 'state': 'S'},
#  63: {'infected': 0, 'old_label': 'Montego Bay:Jamaica', 'state': 'S'},
#  64: {'infected': 0, 'old_label': 'Valparaiso:FL', 'state': 'S'},
#  65: {'infected': 0, 'old_label': 'Monrovia:Liberia', 'state': 'S'},
#  66: {'infected': 0, 'old_label': 'Eagle River:WI', 'state': 'S'},
#  67: {'infected': 0, 'old_label': 'Trondheim:Norway', 'state': 'S'},
#  68: {'infected': 0, 'old_label': 'Denver:CO', 'state': 'S'},
#  69: {'infected': 0, 'old_label': 'Kalispell:MT', 'state': 'S'},
#  70: {'infected': 0, 'old_label': 'Atlanta:GA', 'state': 'S'},
#  71: {'infected': 0, 'old_label': 'Pueblo:CO', 'state': 'S'},
#  72: {'infected': 0, 'old_label': 'Mayport:FL', 'state': 'S'},
#  73: {'infected': 0, 'old_label': 'Grand Cayman:Cayman Islands', 'state': 'S'},
#  74: {'infected': 0, 'old_label': 'Salisbury:MD', 'state': 'S'},
#  75: {'infected': 0, 'old_label': 'Salt Lake City:UT', 'state': 'S'},
#  76: {'infected': 0, 'old_label': 'Georgetown:Guyana', 'state': 'S'},
#  77: {'infected': 0, 'old_label': 'Palm Springs:CA', 'state': 'S'},
#  78: {'infected': 0, 'old_label': 'Westsound:WA', 'state': 'S'},
#  79: {'infected': 0, 'old_label': 'Leipzig:Germany', 'state': 'S'},
#  80: {'infected': 0, 'old_label': 'Santiago:Cuba', 'state': 'S'},
#  81: {'infected': 0, 'old_label': 'Leon/Guanajuato:Mexico', 'state': 'S'},
#  82: {'infected': 0, 'old_label': 'Lagos:Nigeria', 'state': 'S'},
#  83: {'infected': 0, 'old_label': 'Charlottesville:VA', 'state': 'S'},
#  84: {'infected': 0, 'old_label': 'Manila:Philippines', 'state': 'S'},
#  85: {'infected': 0, 'old_label': 'Sendai:Japan', 'state': 'S'},
#  86: {'infected': 0, 'old_label': 'Abuja:Nigeria', 'state': 'S'},
#  87: {'infected': 0, 'old_label': 'Christiansted:VI', 'state': 'S'},
#  88: {'infected': 0, 'old_label': 'Tampa:FL', 'state': 'S'},
#  89: {'infected': 0, 'old_label': 'Riga:Latvia', 'state': 'S'},
#  90: {'infected': 0, 'old_label': 'Kenmore:WA', 'state': 'S'},
#  91: {'infected': 0, 'old_label': 'Moultrie:GA', 'state': 'S'},
#  92: {'infected': 0, 'old_label': 'Loreto:Mexico', 'state': 'S'},
#  93: {'infected': 0, 'old_label': 'Nassau:The Bahamas', 'state': 'S'},
#  94: {'infected': 0, 'old_label': 'Kona:HI', 'state': 'S'},
#  95: {'infected': 0, 'old_label': 'Tuscaloosa:AL', 'state': 'S'},
#  96: {'infected': 0, 'old_label': 'Apia:Samoa', 'state': 'S'},
#  97: {'infected': 0, 'old_label': 'Okayama:Japan', 'state': 'S'},
#  98: {'infected': 0, 'old_label': 'Cayman Brac:Cayman Islands', 'state': 'S'},
#  99: {'infected': 0, 'old_label': 'Albany:GA', 'state': 'S'},
#  100: {'infected': 0, 'old_label': 'Newquay:United Kingdom', 'state': 'S'},
#  101: {'infected': 0, 'old_label': 'Natal:Brazil', 'state': 'S'},
#  102: {'infected': 0, 'old_label': 'Hahn:Germany', 'state': 'S'},
#  103: {'infected': 0, 'old_label': 'Johannesburg:South Africa', 'state': 'S'},
#  104: {'infected': 0, 'old_label': 'Derby:United Kingdom', 'state': 'S'},
#  105: {'infected': 0, 'old_label': 'Brunswick:GA', 'state': 'S'},
#  106: {'infected': 0, 'old_label': 'Salvador:Brazil', 'state': 'S'},
#  107: {'infected': 0, 'old_label': 'Van Nuys:CA', 'state': 'S'},
#  108: {'infected': 0, 'old_label': 'St. Petersburg:FL', 'state': 'S'},
#  109: {'infected': 0, 'old_label': 'Andros Town:The Bahamas', 'state': 'S'},
#  110: {'infected': 0, 'old_label': 'Anadyr:Russia', 'state': 'S'},
#  111: {'infected': 0, 'old_label': 'Kolkata:India', 'state': 'S'},
#  112: {'infected': 0, 'old_label': 'Auckland:New Zealand', 'state': 'S'},
#  113: {'infected': 0, 'old_label': 'Neiva:Colombia', 'state': 'S'},
#  114: {'infected': 0, 'old_label': 'Cartagena:Colombia', 'state': 'S'},
#  115: {'infected': 0, 'old_label': 'Pittsburgh:PA', 'state': 'S'},
#  116: {'infected': 0, 'old_label': 'Pau:France', 'state': 'S'},
#  117: {'infected': 0, 'old_label': 'Shannon:Ireland', 'state': 'S'},
#  118: {'infected': 0, 'old_label': 'Greer:SC', 'state': 'S'},
#  119: {'infected': 0, 'old_label': 'Dallas:TX', 'state': 'S'},
#  120: {'infected': 0, 'old_label': 'Monterey:CA', 'state': 'S'},
#  121: {'infected': 0, 'old_label': 'Fargo:ND', 'state': 'S'},
#  122: {'infected': 0, 'old_label': 'East Hampton:NY', 'state': 'S'},
#  123: {'infected': 0, 'old_label': 'Singapore:Singapore', 'state': 'S'},
#  124: {'infected': 0,
#   'old_label': 'Punta Cana:Dominican Republic',
#   'state': 'S'},
#  125: {'infected': 0, 'old_label': 'Papeete:French Polynesia', 'state': 'S'},
#  126: {'infected': 0,
#   'old_label': 'Tarbes/Lourdes/Pyrenees:France',
#   'state': 'S'},
#  127: {'infected': 0, 'old_label': 'Kahului:HI', 'state': 'S'},
#  128: {'infected': 0, 'old_label': 'San Jose:Costa Rica', 'state': 'S'},
#  129: {'infected': 0,
#   'old_label': 'Nevis:Saint Kitts and Nevis',
#   'state': 'S'},
#  130: {'infected': 0, 'old_label': 'Regina:Canada', 'state': 'S'},
#  131: {'infected': 0, 'old_label': 'Komatsu:Japan', 'state': 'S'},
#  132: {'infected': 0,
#   'old_label': 'Bonaire:Netherlands Antilles',
#   'state': 'S'},
#  133: {'infected': 0, 'old_label': 'Birmingham:United Kingdom', 'state': 'S'},
#  134: {'infected': 0, 'old_label': 'Monteria:Colombia', 'state': 'S'},
#  135: {'infected': 0, 'old_label': 'Syracuse:NY', 'state': 'S'},
#  136: {'infected': 0, 'old_label': 'Omaha:NE', 'state': 'S'},
#  137: {'infected': 0, 'old_label': 'Dalton:GA', 'state': 'S'},
#  138: {'infected': 0, 'old_label': 'Bimini:The Bahamas', 'state': 'S'},
#  139: {'infected': 0, 'old_label': 'Iwoto:Japan', 'state': 'S'},
#  140: {'infected': 0, 'old_label': 'Marrakech:Morocco', 'state': 'S'},
#  141: {'infected': 0, 'old_label': 'Seattle:WA', 'state': 'S'},
#  142: {'infected': 0, 'old_label': 'Rabat:Morocco', 'state': 'S'},
#  143: {'infected': 0, 'old_label': 'Nantucket:MA', 'state': 'S'},
#  144: {'infected': 0, 'old_label': 'Tampico:Mexico', 'state': 'S'},
#  145: {'infected': 0, 'old_label': 'Amsterdam:Netherlands', 'state': 'S'},
#  146: {'infected': 0, 'old_label': 'Takamatsu:Japan', 'state': 'S'},
#  147: {'infected': 0, 'old_label': 'Christmas Island:Kiribati', 'state': 'S'},
#  148: {'infected': 0, 'old_label': 'Little Rock:AR', 'state': 'S'},
#  149: {'infected': 0, 'old_label': 'Aguadilla:PR', 'state': 'S'},
#  150: {'infected': 0, 'old_label': 'Scranton/Wilkes-Barre:PA', 'state': 'S'},
#  151: {'infected': 0, 'old_label': 'Pasto:Colombia', 'state': 'S'},
#  152: {'infected': 0, 'old_label': 'Bogota:Colombia', 'state': 'S'},
#  153: {'infected': 0, 'old_label': 'Knoxville:TN', 'state': 'S'},
#  154: {'infected': 0, 'old_label': 'Corpus Christi:TX', 'state': 'S'},
#  155: {'infected': 0, 'old_label': 'Provideniya:Russia', 'state': 'S'},
#  156: {'infected': 0, 'old_label': 'Victorville:CA', 'state': 'S'},
#  157: {'infected': 0, 'old_label': 'Toluca:Mexico', 'state': 'S'},
#  158: {'infected': 0, 'old_label': 'San Salvador:El Salvador', 'state': 'S'},
#  159: {'infected': 0, 'old_label': 'Tucson:AZ', 'state': 'S'},
#  160: {'infected': 0, 'old_label': 'Geneva:Switzerland', 'state': 'S'},
#  161: {'infected': 0, 'old_label': 'Albuquerque:NM', 'state': 'S'},
#  162: {'infected': 0, 'old_label': 'Sechelt:Canada', 'state': 'S'},
#  163: {'infected': 0,
#   'old_label': 'Abu Dhabi:United Arab Emirates',
#   'state': 'S'},
#  164: {'infected': 0, 'old_label': 'Detroit:MI', 'state': 'S'},
#  165: {'infected': 0, 'old_label': 'Riohacha:Colombia', 'state': 'S'},
#  166: {'infected': 0, 'old_label': 'Portland:ME', 'state': 'S'},
#  167: {'infected': 0, 'old_label': 'Mobile:AL', 'state': 'S'},
#  168: {'infected': 0, 'old_label': 'Laredo:TX', 'state': 'S'},
#  169: {'infected': 0, 'old_label': 'Liberia:Costa Rica', 'state': 'S'},
#  170: {'infected': 0, 'old_label': 'Daytona Beach:FL', 'state': 'S'},
#  171: {'infected': 0,
#   'old_label': 'La Romana:Dominican Republic',
#   'state': 'S'},
#  172: {'infected': 0, 'old_label': 'Bismarck/Mandan:ND', 'state': 'S'},
#  173: {'infected': 0, 'old_label': 'Keflavik/Reykjavik:Iceland', 'state': 'S'},
#  174: {'infected': 0, 'old_label': 'Guantanamo:Cuba', 'state': 'S'},
#  175: {'infected': 0, 'old_label': 'Hermosillo:Mexico', 'state': 'S'},
#  176: {'infected': 0, 'old_label': 'Northway:AK', 'state': 'S'},
#  177: {'infected': 0, 'old_label': 'Jackson:WY', 'state': 'S'},
#  178: {'infected': 0, 'old_label': 'Dubai:United Arab Emirates', 'state': 'S'},
#  179: {'infected': 0, 'old_label': 'North Bend/Coos Bay:OR', 'state': 'S'},
#  180: {'infected': 0, 'old_label': 'Monterrey:Mexico', 'state': 'S'},
#  181: {'infected': 0, 'old_label': 'Popayan:Colombia', 'state': 'S'},
#  182: {'infected': 0, 'old_label': 'Saltillo:Mexico', 'state': 'S'},
#  183: {'infected': 0, 'old_label': 'Des Moines:IA', 'state': 'S'},
#  184: {'infected': 0, 'old_label': 'Santa Marta:Colombia', 'state': 'S'},
#  185: {'infected': 0, 'old_label': 'Majuro:Marshall Islands', 'state': 'S'},
#  186: {'infected': 0, 'old_label': 'Fresno:CA', 'state': 'S'},
#  187: {'infected': 0, 'old_label': 'Marigot:Dominica', 'state': 'S'},
#  188: {'infected': 0, 'old_label': 'Cairns:Australia', 'state': 'S'},
#  189: {'infected': 0, 'old_label': 'Great Falls:MT', 'state': 'S'},
#  190: {'infected': 0, 'old_label': 'Mulhouse:France', 'state': 'S'},
#  191: {'infected': 0, 'old_label': 'Lisbon:Portugal', 'state': 'S'},
#  192: {'infected': 0, 'old_label': 'Chattanooga:TN', 'state': 'S'},
#  193: {'infected': 0, 'old_label': 'Obihiro:Japan', 'state': 'S'},
#  194: {'infected': 0, 'old_label': 'Roche Harbor:WA', 'state': 'S'},
#  195: {'infected': 0, 'old_label': 'Dusseldorf:Germany', 'state': 'S'},
#  196: {'infected': 0, 'old_label': 'Winnipeg:Canada', 'state': 'S'},
#  197: {'infected': 0, 'old_label': 'Tashkent:Uzbekistan', 'state': 'S'},
#  198: {'infected': 0, 'old_label': 'Teterboro:NJ', 'state': 'S'},
#  199: {'infected': 0, 'old_label': 'Busan:South Korea', 'state': 'S'},
#  200: {'infected': 0, 'old_label': 'Cali:Colombia', 'state': 'S'},
#  201: {'infected': 0, 'old_label': 'Easton:MD', 'state': 'S'},
#  202: {'infected': 0, 'old_label': 'Melbourne:FL', 'state': 'S'},
#  203: {'infected': 0, 'old_label': 'Akureyri:Iceland', 'state': 'S'},
#  204: {'infected': 0, 'old_label': 'Santa Monica:CA', 'state': 'S'},
#  205: {'infected': 0, 'old_label': 'Palermo:Italy', 'state': 'S'},
#  206: {'infected': 0, 'old_label': 'Springfield:MO', 'state': 'S'},
#  207: {'infected': 0, 'old_label': 'San Diego:CA', 'state': 'S'},
#  208: {'infected': 0, 'old_label': 'Savannah:GA', 'state': 'S'},
#  209: {'infected': 0, 'old_label': 'Fortaleza:Brazil', 'state': 'S'},
#  210: {'infected': 0,
#   'old_label': 'Allentown/Bethlehem/Easton:PA',
#   'state': 'S'},
#  211: {'infected': 0, 'old_label': 'Barrancabermeja:Colombia', 'state': 'S'},
#  212: {'infected': 0, 'old_label': 'New York:NY', 'state': 'S'},
#  213: {'infected': 0, 'old_label': 'Islamabad:Pakistan', 'state': 'S'},
#  214: {'infected': 0, 'old_label': 'Madrid:Spain', 'state': 'S'},
#  215: {'infected': 0, 'old_label': 'Manchester:United Kingdom', 'state': 'S'},
#  216: {'infected': 0, 'old_label': 'Cleveland:OH', 'state': 'S'},
#  217: {'infected': 0, 'old_label': 'Columbus:GA', 'state': 'S'},
#  218: {'infected': 0, 'old_label': 'Sydney:Canada', 'state': 'S'},
#  219: {'infected': 0, 'old_label': 'Pago Pago:TT', 'state': 'S'},
#  220: {'infected': 0, 'old_label': 'Nanaimo:Canada', 'state': 'S'},
#  221: {'infected': 0, 'old_label': 'Mumbai:India', 'state': 'S'},
#  222: {'infected': 0, 'old_label': 'Burlington:VT', 'state': 'S'},
#  223: {'infected': 0, 'old_label': 'Toledo:OH', 'state': 'S'},
#  224: {'infected': 0, 'old_label': 'Gander:Canada', 'state': 'S'},
#  225: {'infected': 0, 'old_label': 'Melbourne:Australia', 'state': 'S'},
#  226: {'infected': 0, 'old_label': 'Wichita:KS', 'state': 'S'},
#  227: {'infected': 0, 'old_label': 'Hyderabad:India', 'state': 'S'},
#  228: {'infected': 0, 'old_label': 'Friday Harbor:WA', 'state': 'S'},
#  229: {'infected': 0, 'old_label': 'Cozumel:Mexico', 'state': 'S'},
#  230: {'infected': 0, 'old_label': 'Alexandria:LA', 'state': 'S'},
#  231: {'infected': 0, 'old_label': 'Budapest:Hungary', 'state': 'S'},
#  232: {'infected': 0, 'old_label': 'Milan:Italy', 'state': 'S'},
#  233: {'infected': 0, 'old_label': 'Cunnamulla:Australia', 'state': 'S'},
#  234: {'infected': 0,
#   'old_label': 'Willemstad:Netherlands Antilles',
#   'state': 'S'},
#  235: {'infected': 0,
#   'old_label': 'Chuuk:Federated States of Micronesia',
#   'state': 'S'},
#  236: {'infected': 0, 'old_label': 'Stuttgart:Germany', 'state': 'S'},
#  237: {'infected': 0, 'old_label': 'Marseille:France', 'state': 'S'},
#  238: {'infected': 0, 'old_label': 'Toronto:Canada', 'state': 'S'},
#  239: {'infected': 0, 'old_label': 'San Jose del Cabo:Mexico', 'state': 'S'},
#  240: {'infected': 0, 'old_label': 'Kwajalein:Marshall Islands', 'state': 'S'},
#  241: {'infected': 0, 'old_label': 'Windsor:Canada', 'state': 'S'},
#  242: {'infected': 0, 'old_label': 'Porto:Portugal', 'state': 'S'},
#  243: {'infected': 0, 'old_label': 'Toulouse:France', 'state': 'S'},
#  244: {'infected': 0, 'old_label': 'Tobago:Trinidad and Tobago', 'state': 'S'},
#  245: {'infected': 0, 'old_label': 'El Paso:TX', 'state': 'S'},
#  246: {'infected': 0, 'old_label': 'Cedar Rapids/Iowa City:IA', 'state': 'S'},
#  247: {'infected': 0, 'old_label': 'Pontiac:MI', 'state': 'S'},
#  248: {'infected': 0, 'old_label': 'Galena:AK', 'state': 'S'},
#  249: {'infected': 0, 'old_label': 'Moncton:Canada', 'state': 'S'},
#  250: {'infected': 0, 'old_label': 'Fort Wayne:IN', 'state': 'S'},
#  251: {'infected': 0, 'old_label': 'Riverside:CA', 'state': 'S'},
#  252: {'infected': 0, 'old_label': "Coeur d'Alene:ID", 'state': 'S'},
#  253: {'infected': 0, 'old_label': 'San Andres Island:Colombia', 'state': 'S'},
#  254: {'infected': 0, 'old_label': 'Charlotte:NC', 'state': 'S'},
#  255: {'infected': 0, 'old_label': 'London:United Kingdom', 'state': 'S'},
#  256: {'infected': 0, 'old_label': 'Hiroshima:Japan', 'state': 'S'},
#  257: {'infected': 0, 'old_label': 'Porlamar:Venezuela', 'state': 'S'},
#  258: {'infected': 0,
#   'old_label': 'Pohnpei:Federated States of Micronesia',
#   'state': 'S'},
#  259: {'infected': 0, 'old_label': 'Ontario:CA', 'state': 'S'},
#  260: {'infected': 0,
#   'old_label': 'Glasgow/Prestwick:United Kingdom',
#   'state': 'S'},
#  261: {'infected': 0, 'old_label': 'Oklahoma City:OK', 'state': 'S'},
#  262: {'infected': 0, 'old_label': 'London:Canada', 'state': 'S'},
#  263: {'infected': 0, 'old_label': 'Recife:Brazil', 'state': 'S'},
#  264: {'infected': 0, 'old_label': 'Baton Rouge:LA', 'state': 'S'},
#  265: {'infected': 0, 'old_label': 'Tampere:Finland', 'state': 'S'},
#  266: {'infected': 0, 'old_label': 'Harrisburg:PA', 'state': 'S'},
#  267: {'infected': 0, 'old_label': 'Columbus:OH', 'state': 'S'},
#  268: {'infected': 0, 'old_label': 'Santa Ana:CA', 'state': 'S'},
#  269: {'infected': 0, 'old_label': 'La Crosse:WI', 'state': 'S'},
#  270: {'infected': 0, 'old_label': 'Montrose/Delta:CO', 'state': 'S'},
#  271: {'infected': 0, 'old_label': 'Greenway Sound:Canada', 'state': 'S'},
#  272: {'infected': 0, 'old_label': 'Roatan Island:Honduras', 'state': 'S'},
#  273: {'infected': 0, 'old_label': 'Zurich:Switzerland', 'state': 'S'},
#  274: {'infected': 0, 'old_label': 'Tuxtla Gutierrez:Mexico', 'state': 'S'},
#  275: {'infected': 0,
#   'old_label': 'Providenciales:Turks and Caicos Islands',
#   'state': 'S'},
#  276: {'infected': 0, 'old_label': 'Frankfurt:Germany', 'state': 'S'},
#  277: {'infected': 0, 'old_label': 'Missoula:MT', 'state': 'S'},
#  278: {'infected': 0, 'old_label': 'Los Angeles:CA', 'state': 'S'},
#  279: {'infected': 0, 'old_label': 'Berlin:Germany', 'state': 'S'},
#  280: {'infected': 0, 'old_label': 'Lyon:France', 'state': 'S'},
#  281: {'infected': 0, 'old_label': 'Burbank:CA', 'state': 'S'},
#  282: {'infected': 0, 'old_label': 'Iquitos:Peru', 'state': 'S'},
#  283: {'infected': 0, 'old_label': 'Ixtapa/Zihuatanejo:Mexico', 'state': 'S'},
#  284: {'infected': 0, 'old_label': 'Zacatecas:Mexico', 'state': 'S'},
#  285: {'infected': 0, 'old_label': 'San Juan:PR', 'state': 'S'},
#  286: {'infected': 0, 'old_label': 'Philadelphia:PA', 'state': 'S'},
#  287: {'infected': 0, 'old_label': 'Lansing:MI', 'state': 'S'},
#  288: {'infected': 0, 'old_label': 'Quebec:Canada', 'state': 'S'},
#  289: {'infected': 0, 'old_label': 'Victoria:Canada', 'state': 'S'},
#  290: {'infected': 0, 'old_label': 'Villahermosa:Mexico', 'state': 'S'},
#  291: {'infected': 0, 'old_label': 'Grand Forks:ND', 'state': 'S'},
#  292: {'infected': 0, 'old_label': 'Lake Simcoe:Canada', 'state': 'S'},
#  293: {'infected': 0, 'old_label': 'Turin:Italy', 'state': 'S'},
#  294: {'infected': 0, 'old_label': 'Fort Drum:NY', 'state': 'S'},
#  295: {'infected': 0, 'old_label': 'Ciudad Victoria:Mexico', 'state': 'S'},
#  296: {'infected': 0, 'old_label': 'Peterborough:Canada', 'state': 'S'},
#  297: {'infected': 0, 'old_label': 'Malaga:Spain', 'state': 'S'},
#  298: {'infected': 0,
#   'old_label': 'Leeds/Bradford:United Kingdom',
#   'state': 'S'},
#  299: {'infected': 0, 'old_label': 'Matsumoto:Japan', 'state': 'S'},
#  300: {'infected': 0, 'old_label': 'Oaxaca:Mexico', 'state': 'S'},
#  301: {'infected': 0, 'old_label': 'Calgary:Canada', 'state': 'S'},
#  302: {'infected': 0, 'old_label': 'Seoul:South Korea', 'state': 'S'},
#  303: {'infected': 0, 'old_label': 'Port Hardy:Canada', 'state': 'S'},
#  304: {'infected': 0, 'old_label': 'Fredericton:Canada', 'state': 'S'},
#  305: {'infected': 0, 'old_label': 'Santa Cruz/Huatulco:Mexico', 'state': 'S'},
#  306: {'infected': 0, 'old_label': 'Traverse City:MI', 'state': 'S'},
#  307: {'infected': 0, 'old_label': 'Asheville:NC', 'state': 'S'},
#  308: {'infected': 0, 'old_label': 'Ottawa:Canada', 'state': 'S'},
#  309: {'infected': 0,
#   'old_label': 'Saginaw/Bay City/Midland:MI',
#   'state': 'S'},
#  310: {'infected': 0, 'old_label': 'Rockford:IL', 'state': 'S'},
#  311: {'infected': 0, 'old_label': 'Bedford:MA', 'state': 'S'},
#  312: {'infected': 0, 'old_label': 'Latrobe:PA', 'state': 'S'},
#  313: {'infected': 0, 'old_label': 'Cincinnati:OH', 'state': 'S'},
#  314: {'infected': 0, 'old_label': 'Manizales:Colombia', 'state': 'S'},
#  315: {'infected': 0, 'old_label': 'Spokane:WA', 'state': 'S'},
#  316: {'infected': 0, 'old_label': 'Cheyenne:WY', 'state': 'S'},
#  317: {'infected': 0, 'old_label': 'East Farmingdale:NY', 'state': 'S'},
#  318: {'infected': 0, 'old_label': 'Guadalajara:Mexico', 'state': 'S'},
#  319: {'infected': 0, 'old_label': 'Thunder Bay:Canada', 'state': 'S'},
#  320: {'infected': 0, 'old_label': 'Flores:Guatemala', 'state': 'S'},
#  321: {'infected': 0, 'old_label': 'Luxembourg:Luxembourg', 'state': 'S'},
#  322: {'infected': 0, 'old_label': 'Belo Horizonte:Brazil', 'state': 'S'},
#  323: {'infected': 0, 'old_label': 'Port-au-Prince:Haiti', 'state': 'S'},
#  324: {'infected': 0, 'old_label': 'Naples:Italy', 'state': 'S'},
#  325: {'infected': 0, 'old_label': 'Willemstad:Curacao', 'state': 'S'},
#  326: {'infected': 0, 'old_label': 'Orlando:FL', 'state': 'S'},
#  327: {'infected': 0, 'old_label': 'San Salvador:The Bahamas', 'state': 'S'},
#  328: {'infected': 0, 'old_label': 'Erie:PA', 'state': 'S'},
#  329: {'infected': 0,
#   'old_label': 'Mission/McAllen/Edinburg:TX',
#   'state': 'S'},
#  330: {'infected': 0, 'old_label': 'Vancouver:Canada', 'state': 'S'},
#  331: {'infected': 0, 'old_label': 'Fort de France:Martinique', 'state': 'S'},
#  332: {'infected': 0, 'old_label': 'Elmira/Corning:NY', 'state': 'S'},
#  333: {'infected': 0, 'old_label': 'Grande Prairie:Canada', 'state': 'S'},
#  334: {'infected': 0, 'old_label': 'Ponce:PR', 'state': 'S'},
#  335: {'infected': 0, 'old_label': 'Honolulu:HI', 'state': 'S'},
#  336: {'infected': 0, 'old_label': 'Bullhead City:AZ', 'state': 'S'},
#  337: {'infected': 0, 'old_label': 'Norfolk:VA', 'state': 'S'},
#  338: {'infected': 0, 'old_label': 'Avarua:Cook Islands', 'state': 'S'},
#  339: {'infected': 0, 'old_label': 'Wilmington:NC', 'state': 'S'},
#  340: {'infected': 0, 'old_label': 'Luanda:Angola', 'state': 'S'},
#  341: {'infected': 0, 'old_label': 'Grenada:Grenada', 'state': 'S'},
#  342: {'infected': 0, 'old_label': 'Dawson City:Canada', 'state': 'S'},
#  343: {'infected': 0, 'old_label': 'Eagle:CO', 'state': 'S'},
#  344: {'infected': 0, 'old_label': 'White Plains:NY', 'state': 'S'},
#  345: {'infected': 0, 'old_label': 'Aruba:Aruba', 'state': 'S'},
#  346: {'infected': 0, 'old_label': 'Bangor:ME', 'state': 'S'},
#  347: {'infected': 0, 'old_label': 'Matsuyama:Japan', 'state': 'S'},
#  348: {'infected': 0, 'old_label': 'Rifle:CO', 'state': 'S'},
#  349: {'infected': 0, 'old_label': 'Dublin:Ireland', 'state': 'S'},
#  350: {'infected': 0, 'old_label': 'Katowice:Poland', 'state': 'S'},
#  351: {'infected': 0, 'old_label': 'Panama City:FL', 'state': 'S'},
#  352: {'infected': 0, 'old_label': 'Kitchener:Canada', 'state': 'S'},
#  353: {'infected': 0, 'old_label': 'Lima:Peru', 'state': 'S'},
#  354: {'infected': 0, 'old_label': 'Brasilia:Brazil', 'state': 'S'},
#  355: {'infected': 0, 'old_label': 'Kansas City:MO', 'state': 'S'},
#  356: {'infected': 0, 'old_label': 'Toyama:Japan', 'state': 'S'},
#  357: {'infected': 0, 'old_label': 'Myrtle Beach:SC', 'state': 'S'},
#  358: {'infected': 0, 'old_label': 'Kagoshima:Japan', 'state': 'S'},
#  359: {'infected': 0, 'old_label': 'Havana:Cuba', 'state': 'S'},
#  360: {'infected': 0, 'old_label': 'Ibague:Colombia', 'state': 'S'},
#  361: {'infected': 0, 'old_label': 'Caracas:Venezuela', 'state': 'S'},
#  362: {'infected': 0, 'old_label': 'Saskatoon:Canada', 'state': 'S'},
#  363: {'infected': 0, 'old_label': 'Valledupar:Colombia', 'state': 'S'},
#  364: {'infected': 0, 'old_label': 'Aguascalientes:Mexico', 'state': 'S'},
#  365: {'infected': 0, 'old_label': 'Genoa:Italy', 'state': 'S'},
#  366: {'infected': 0, 'old_label': 'Jeddah:Saudi Arabia', 'state': 'S'},
#  367: {'infected': 0, 'old_label': 'El Palomar:Argentina', 'state': 'S'},
#  368: {'infected': 0, 'old_label': 'San Antonio:TX', 'state': 'S'},
#  369: {'infected': 0, 'old_label': 'Iquique:Chile', 'state': 'S'},
#  370: {'infected': 0, 'old_label': 'Rome:Italy', 'state': 'S'},
#  371: {'infected': 0, 'old_label': 'Guatemala City:Guatemala', 'state': 'S'},
#  372: {'infected': 0, 'old_label': 'Cienfuegos:Cuba', 'state': 'S'},
#  373: {'infected': 0, 'old_label': 'Morristown:NJ', 'state': 'S'},
#  374: {'infected': 0, 'old_label': 'Rio de Janeiro:Brazil', 'state': 'S'},
#  375: {'infected': 0, 'old_label': 'Gulfport/Biloxi:MS', 'state': 'S'},
#  376: {'infected': 0,
#   'old_label': 'St. Kitts:Saint Kitts and Nevis',
#   'state': 'S'},
#  377: {'infected': 0, 'old_label': 'Tenerife:Spain', 'state': 'S'},
#  378: {'infected': 0, 'old_label': 'Kiev:Ukraine', 'state': 'S'},
#  379: {'infected': 0,
#   'old_label': 'Karlsruhe/Baden-Baden:Germany',
#   'state': 'S'},
#  380: {'infected': 0, 'old_label': 'Valencia:Spain', 'state': 'S'},
#  381: {'infected': 0, 'old_label': 'Minneapolis:MN', 'state': 'S'},
#  382: {'infected': 0, 'old_label': 'Dallas/Fort Worth:TX', 'state': 'S'},
#  383: {'infected': 0, 'old_label': 'Acapulco:Mexico', 'state': 'S'},
#  384: {'infected': 0, 'old_label': 'Boston:MA', 'state': 'S'},
#  385: {'infected': 0, 'old_label': 'Halifax:Canada', 'state': 'S'},
#  386: {'infected': 0, 'old_label': 'Jeju:South Korea', 'state': 'S'},
#  387: {'infected': 0, 'old_label': 'St. Petersburg:Russia', 'state': 'S'},
#  388: {'infected': 0, 'old_label': 'Casablanca:Morocco', 'state': 'S'},
#  389: {'infected': 0, 'old_label': 'Jakarta:Indonesia', 'state': 'S'},
#  390: {'infected': 0, 'old_label': 'Glasgow:United Kingdom', 'state': 'S'},
#  391: {'infected': 0, 'old_label': 'St. Lucia:Saint Lucia', 'state': 'S'},
#  392: {'infected': 0, 'old_label': 'Fairbanks:AK', 'state': 'S'},
#  393: {'infected': 0, 'old_label': 'Charlottetown:Canada', 'state': 'S'},
#  394: {'infected': 0, 'old_label': 'Helsinki:Finland', 'state': 'S'},
#  395: {'infected': 0,
#   'old_label': 'Barbados/Bridgetown:Barbados',
#   'state': 'S'},
#  396: {'infected': 0, 'old_label': 'Washington:DC', 'state': 'S'},
#  397: {'infected': 0, 'old_label': 'Edmonton:Canada', 'state': 'S'},
#  398: {'infected': 0, 'old_label': 'Tulsa:OK', 'state': 'S'},
#  399: {'infected': 0, 'old_label': 'Finningley:United Kingdom', 'state': 'S'},
#  400: {'infected': 0, 'old_label': 'Cordoba:Argentina', 'state': 'S'},
#  401: {'infected': 0, 'old_label': 'Guaymas:Mexico', 'state': 'S'},
#  402: {'infected': 0, 'old_label': 'Sioux Falls:SD', 'state': 'S'},
#  403: {'infected': 0, 'old_label': 'Charlotte Amalie:VI', 'state': 'S'},
#  404: {'infected': 0,
#   'old_label': 'West Palm Beach/Palm Beach:FL',
#   'state': 'S'},
#  405: {'infected': 0, 'old_label': 'Tel Aviv:Israel', 'state': 'S'},
#  406: {'infected': 0, 'old_label': 'Baltimore:MD', 'state': 'S'},
#  407: {'infected': 0, 'old_label': 'Guayaquil:Ecuador', 'state': 'S'},
#  408: {'infected': 0, 'old_label': 'Praia:Cape Verde', 'state': 'S'},
#  409: {'infected': 0, 'old_label': 'Camaguey:Cuba', 'state': 'S'},
#  410: {'infected': 0, 'old_label': 'Greensboro/High Point:NC', 'state': 'S'},
#  411: {'infected': 0, 'old_label': 'The Valley:Anguilla', 'state': 'S'},
#  412: {'infected': 0, 'old_label': 'Hong Kong:Hong Kong', 'state': 'S'},
#  413: {'infected': 0, 'old_label': 'Sullivan Bay:Canada', 'state': 'S'},
#  414: {'infected': 0, 'old_label': 'Vienna:Austria', 'state': 'S'},
#  415: {'infected': 0, 'old_label': 'Chennai:India', 'state': 'S'},
#  416: {'infected': 0, 'old_label': 'Gdansk:Poland', 'state': 'S'},
#  417: {'infected': 0, 'old_label': 'Milwaukee:WI', 'state': 'S'},
#  418: {'infected': 0, 'old_label': 'Ahmedabad:India', 'state': 'S'},
#  419: {'infected': 0, 'old_label': 'Ciudad del Carmen:Mexico', 'state': 'S'},
#  420: {'infected': 0, 'old_label': 'Grand Rapids:MI', 'state': 'S'},
#  421: {'infected': 0, 'old_label': 'Danang:Vietnam', 'state': 'S'},
#  422: {'infected': 0, 'old_label': 'Port McNeill:Canada', 'state': 'S'},
#  423: {'infected': 0, 'old_label': 'Kodiak:AK', 'state': 'S'},
#  424: {'infected': 0, 'old_label': 'Memphis:TN', 'state': 'S'},
#  425: {'infected': 0, 'old_label': 'Fort Lauderdale:FL', 'state': 'S'},
#  426: {'infected': 0, 'old_label': 'Rochester:NY', 'state': 'S'},
#  427: {'infected': 0, 'old_label': 'Desolation Sound:Canada', 'state': 'S'},
#  428: {'infected': 0, 'old_label': 'Jersey:United Kingdom', 'state': 'S'},
#  429: {'infected': 0, 'old_label': 'Hakodate:Japan', 'state': 'S'},
#  430: {'infected': 0, 'old_label': 'Newcastle:United Kingdom', 'state': 'S'},
#  431: {'infected': 0, 'old_label': 'Osan:South Korea', 'state': 'S'},
#  432: {'infected': 0, 'old_label': 'Pullman:WA', 'state': 'S'},
#  433: {'infected': 0, 'old_label': 'Colorado Springs:CO', 'state': 'S'},
#  434: {'infected': 0, 'old_label': 'Belize City:Belize', 'state': 'S'},
#  435: {'infected': 0, 'old_label': 'Kotzebue:AK', 'state': 'S'},
#  436: {'infected': 0, 'old_label': 'Lajes:Portugal', 'state': 'S'},
#  437: {'infected': 0,
#   'old_label': 'Petropavlovsk-Kamchatsky:Russia',
#   'state': 'S'},
#  438: {'infected': 0, 'old_label': 'Marsh Harbour:The Bahamas', 'state': 'S'},
#  439: {'infected': 0, 'old_label': 'Huntsville:AL', 'state': 'S'},
#  440: {'infected': 0, 'old_label': 'Santa Cruz:Bolivia', 'state': 'S'},
#  441: {'infected': 0, 'old_label': 'Khabarovsk:Russia', 'state': 'S'},
#  442: {'infected': 0, 'old_label': 'Pisa:Italy', 'state': 'S'},
#  443: {'infected': 0, 'old_label': 'Nashville:TN', 'state': 'S'},
#  444: {'infected': 0, 'old_label': 'Seville:Spain', 'state': 'S'},
#  445: {'infected': 0, 'old_label': 'Treasure Cay:The Bahamas', 'state': 'S'},
#  446: {'infected': 0,
#   'old_label': 'Bristol/Johnson City/Kingsport:TN',
#   'state': 'S'},
#  447: {'infected': 0, 'old_label': 'Sydney:Australia', 'state': 'S'},
#  448: {'infected': 0, 'old_label': 'Anchorage:AK', 'state': 'S'},
#  449: {'infected': 0, 'old_label': 'Warsaw:Poland', 'state': 'S'},
#  450: {'infected': 0, 'old_label': 'Newburgh/Poughkeepsie:NY', 'state': 'S'},
#  451: {'infected': 0, 'old_label': 'Fort Myers:FL', 'state': 'S'},
#  452: {'infected': 0, 'old_label': 'Philipsburg:Sint Maarten', 'state': 'S'},
#  453: {'infected': 0, 'old_label': 'Sao Paulo:Brazil', 'state': 'S'},
#  454: {'infected': 0, 'old_label': 'Belleville:IL', 'state': 'S'},
#  455: {'infected': 0, 'old_label': 'Brisbane:Australia', 'state': 'S'},
#  456: {'infected': 0, 'old_label': 'Pointe A Pitre:Guadeloupe', 'state': 'S'},
#  457: {'infected': 0, 'old_label': 'Kosipe:Papua New Guinea', 'state': 'S'},
#  458: {'infected': 0, 'old_label': 'Yinchuan:China', 'state': 'S'},
#  459: {'infected': 0, 'old_label': 'Bloomington/Normal:IL', 'state': 'S'},
#  460: {'infected': 0, 'old_label': 'Napa:CA', 'state': 'S'},
#  461: {'infected': 0, 'old_label': 'Jacksonville:FL', 'state': 'S'},
#  462: {'infected': 0, 'old_label': 'Inuvik:Canada', 'state': 'S'},
#  463: {'infected': 0, 'old_label': 'Savoonga:AK', 'state': 'S'},
#  464: {'infected': 0, 'old_label': 'Providence:RI', 'state': 'S'},
#  465: {'infected': 0, 'old_label': 'Sarasota/Bradenton:FL', 'state': 'S'},
#  466: {'infected': 0, 'old_label': 'Bournemouth:United Kingdom', 'state': 'S'},
#  467: {'infected': 0, 'old_label': 'Rock Sound:The Bahamas', 'state': 'S'},
#  468: {'infected': 0, 'old_label': 'Brownsville:TX', 'state': 'S'},
#  469: {'infected': 0, 'old_label': 'Richmond:VA', 'state': 'S'},
#  470: {'infected': 0, 'old_label': 'Okinawa:Japan', 'state': 'S'},
#  471: {'infected': 0, 'old_label': 'Managua:Nicaragua', 'state': 'S'},
#  472: {'infected': 0, 'old_label': 'Nice:France', 'state': 'S'},
#  473: {'infected': 0, 'old_label': 'Koror:Palau', 'state': 'S'},
#  474: {'infected': 0, 'old_label': 'Gothenburg:Sweden', 'state': 'S'},
#  475: {'infected': 0, 'old_label': 'Sacramento:CA', 'state': 'S'},
#  476: {'infected': 0, 'old_label': 'Flint:MI', 'state': 'S'},
#  477: {'infected': 0, 'old_label': 'Raleigh/Durham:NC', 'state': 'S'},
#  478: {'infected': 0, 'old_label': 'Abbotsford:Canada', 'state': 'S'},
#  479: {'infected': 0, 'old_label': 'Lexington:KY', 'state': 'S'},
#  480: {'infected': 0, 'old_label': 'Manchester:NH', 'state': 'S'},
#  481: {'infected': 0, 'old_label': 'Bordeaux:France', 'state': 'S'},
#  482: {'infected': 0,
#   'old_label': 'Governors Harbour:The Bahamas',
#   'state': 'S'},
#  483: {'infected': 0, 'old_label': 'Akron:OH', 'state': 'S'},
#  484: {'infected': 0, 'old_label': 'Taipei:Taiwan', 'state': 'S'},
#  485: {'infected': 0, 'old_label': 'Buffalo:NY', 'state': 'S'},
#  486: {'infected': 0, 'old_label': 'Waco:TX', 'state': 'S'},
#  487: {'infected': 0, 'old_label': 'Cairo:Egypt', 'state': 'S'},
#  488: {'infected': 0, 'old_label': 'Tegucigalpa:Honduras', 'state': 'S'},
#  489: {'infected': 0, 'old_label': 'Accra:Ghana', 'state': 'S'},
#  490: {'infected': 0, 'old_label': 'Bangkok:Thailand', 'state': 'S'},
#  491: {'infected': 0, 'old_label': 'Freeport:The Bahamas', 'state': 'S'},
#  492: {'infected': 0, 'old_label': 'Osaka:Japan', 'state': 'S'},
#  493: {'infected': 0, 'old_label': 'Duluth:MN', 'state': 'S'},
#  494: {'infected': 0, 'old_label': 'Quito:Ecuador', 'state': 'S'},
#  495: {'infected': 0, 'old_label': 'Tokyo:Japan', 'state': 'S'},
#  496: {'infected': 0, 'old_label': 'Samana:Dominican Republic', 'state': 'S'},
#  497: {'infected': 0, 'old_label': 'Farnborough:United Kingdom', 'state': 'S'},
#  498: {'infected': 0, 'old_label': 'Fayetteville:AR', 'state': 'S'},
#  499: {'infected': 0, 'old_label': 'Long Beach:CA', 'state': 'S'},
#  500: {'infected': 0, 'old_label': 'Karachi:Pakistan', 'state': 'S'},
#  501: {'infected': 0, 'old_label': 'Newark:NJ', 'state': 'S'},
#  502: {'infected': 0, 'old_label': 'Niagara Falls:NY', 'state': 'S'},
#  503: {'infected': 0, 'old_label': 'Moss Town:The Bahamas', 'state': 'S'},
#  504: {'infected': 0, 'old_label': 'Appleton:WI', 'state': 'S'},
#  505: {'infected': 0, 'old_label': 'Barcelona:Spain', 'state': 'S'},
#  506: {'infected': 0, 'old_label': 'Oslo:Norway', 'state': 'S'},
#  507: {'infected': 0, 'old_label': 'Berne:Switzerland', 'state': 'S'},
#  508: {'infected': 0, 'old_label': 'Kelowna:Canada', 'state': 'S'},
#  509: {'infected': 0, 'old_label': 'Moline:IL', 'state': 'S'},
#  510: {'infected': 0, 'old_label': 'Puebla:Mexico', 'state': 'S'},
#  511: {'infected': 0, 'old_label': 'Armenia:Colombia', 'state': 'S'},
#  512: {'infected': 0, 'old_label': 'Beijing:China', 'state': 'S'},
#  513: {'infected': 0, 'old_label': 'South Bend:IN', 'state': 'S'},
#  514: {'infected': 0, 'old_label': 'Goose Bay:Canada', 'state': 'S'},
#  515: {'infected': 0, 'old_label': 'Albany:NY', 'state': 'S'},
#  516: {'infected': 0, 'old_label': 'Addis Ababa:Ethiopia', 'state': 'S'},
#  517: {'infected': 0, 'old_label': 'Hamilton:Canada', 'state': 'S'},
#  518: {'infected': 0, 'old_label': 'New Orleans:LA', 'state': 'S'},
#  519: {'infected': 0, 'old_label': 'Munich:Germany', 'state': 'S'},
#  520: {'infected': 0, 'old_label': 'Hickory:NC', 'state': 'S'},
#  521: {'infected': 0, 'old_label': 'Santa Barbara:CA', 'state': 'S'},
#  522: {'infected': 0, 'old_label': 'Barranquilla:Colombia', 'state': 'S'},
#  523: {'infected': 0, 'old_label': 'Culiacan:Mexico', 'state': 'S'},
#  524: {'infected': 0, 'old_label': 'Veracruz:Mexico', 'state': 'S'},
#  525: {'infected': 0, 'old_label': 'Mayo:Canada', 'state': 'S'},
#  526: {'infected': 0, 'old_label': 'Durango:Mexico', 'state': 'S'},
#  527: {'infected': 0, 'old_label': 'Demopolis:AL', 'state': 'S'},
#  528: {'infected': 0, 'old_label': 'Panama City:Panama', 'state': 'S'},
#  529: {'infected': 0, 'old_label': 'Camp Springs:MD', 'state': 'S'},
#  530: {'infected': 0, 'old_label': 'Youngstown/Warren:OH', 'state': 'S'},
#  531: {'infected': 0, 'old_label': 'Dakar:Senegal', 'state': 'S'},
#  532: {'infected': 0, 'old_label': 'Charleston:SC', 'state': 'S'},
#  533: {'infected': 0, 'old_label': 'Juneau:AK', 'state': 'S'},
#  534: {'infected': 0,
#   'old_label': 'St. Johns:Antigua and Barbuda',
#   'state': 'S'},
#  535: {'infected': 0, 'old_label': 'San Jose:CA', 'state': 'S'},
#  536: {'infected': 0, 'old_label': 'Penticton:Canada', 'state': 'S'},
#  537: {'infected': 0, 'old_label': 'New Bight:The Bahamas', 'state': 'S'},
#  538: {'infected': 0, 'old_label': 'Dayton:OH', 'state': 'S'},
#  539: {'infected': 0,
#   'old_label': 'North Eleuthera:The Bahamas',
#   'state': 'S'},
#  540: {'infected': 0, 'old_label': 'Santa Rosa:CA', 'state': 'S'},
#  541: {'infected': 0, 'old_label': 'Tuktoyaktuk:Canada', 'state': 'S'},
#  542: {'infected': 0, 'old_label': 'Grand Junction:CO', 'state': 'S'},
#  543: {'infected': 0, 'old_label': 'Medellin:Colombia', 'state': 'S'},
#  544: {'infected': 0, 'old_label': 'Montreal:Canada', 'state': 'S'},
#  545: {'infected': 0,
#   'old_label': 'Santo Domingo:Dominican Republic',
#   'state': 'S'},
#  546: {'infected': 0,
#   'old_label': 'Kosrae:Federated States of Micronesia',
#   'state': 'S'},
#  547: {'infected': 0,
#   'old_label': 'Saint Barthelemy:Saint Barthelemy',
#   'state': 'S'},
#  548: {'infected': 0, 'old_label': 'Portland:OR', 'state': 'S'},
#  549: {'infected': 0, 'old_label': 'Kochi:Japan', 'state': 'S'},
#  550: {'infected': 0, 'old_label': 'Sapporo:Japan', 'state': 'S'},
#  551: {'infected': 0, 'old_label': 'Portland:TN', 'state': 'S'},
#  552: {'infected': 0, 'old_label': 'Niigata:Japan', 'state': 'S'},
#  553: {'infected': 0, 'old_label': 'Cranbrook:Canada', 'state': 'S'},
#  554: {'infected': 0,
#   'old_label': 'Santiago de Compostela:Spain',
#   'state': 'S'},
#  555: {'infected': 0, 'old_label': 'Las Vegas:NV', 'state': 'S'},
#  556: {'infected': 0, 'old_label': 'Puerto Vallarta:Mexico', 'state': 'S'},
#  557: {'infected': 0, 'old_label': 'Fort Pierce:FL', 'state': 'S'},
#  558: {'infected': 0, 'old_label': 'Brussels:Belgium', 'state': 'S'},
#  559: {'infected': 0, 'old_label': 'Guam:TT', 'state': 'S'},
#  560: {'infected': 0, 'old_label': 'San Francisco:CA', 'state': 'S'},
#  561: {'infected': 0, 'old_label': 'Ponta Delgada:Portugal', 'state': 'S'},
#  562: {'infected': 0, 'old_label': 'Kuala Lumpur:Malaysia', 'state': 'S'},
#  563: {'infected': 0, 'old_label': 'Doha:Qatar', 'state': 'S'},
#  564: {'infected': 0, 'old_label': 'Tallahassee:FL', 'state': 'S'},
#  565: {'infected': 0, 'old_label': 'Kingston:Jamaica', 'state': 'S'},
#  566: {'infected': 0, 'old_label': 'Luzon Island:Philippines', 'state': 'S'},
#  567: {'infected': 0, 'old_label': 'Lagos de Moreno:Mexico', 'state': 'S'},
#  568: {'infected': 0, 'old_label': 'Turku:Finland', 'state': 'S'},
#  569: {'infected': 0, 'old_label': 'Madison:WI', 'state': 'S'},
#  570: {'infected': 0, 'old_label': 'Cologne:Germany', 'state': 'S'},
#  571: {'infected': 0, 'old_label': 'Birmingham:AL', 'state': 'S'},
#  572: {'infected': 0, 'old_label': 'Queretaro:Mexico', 'state': 'S'},
#  573: {'infected': 0,
#   'old_label': 'Sun Valley/Hailey/Ketchum:ID',
#   'state': 'S'},
#  574: {'infected': 0, 'old_label': 'Pereira:Colombia', 'state': 'S'},
#  575: {'infected': 0, 'old_label': 'Rochester:MN', 'state': 'S'},
#  576: {'infected': 0, 'old_label': 'Tacoma:WA', 'state': 'S'},
#  577: {'infected': 0, 'old_label': 'Harlingen/San Benito:TX', 'state': 'S'},
#  578: {'infected': 0, 'old_label': 'Rogers:AR', 'state': 'S'},
#  579: {'infected': 0, 'old_label': 'Torreon:Mexico', 'state': 'S'},
#  580: {'infected': 0, 'old_label': 'Stockholm:Sweden', 'state': 'S'},
#  581: {'infected': 0, 'old_label': 'Old Crow:Canada', 'state': 'S'},
#  582: {'infected': 0,
#   'old_label': 'Puerto Plata:Dominican Republic',
#   'state': 'S'},
#  583: {'infected': 0, 'old_label': 'Edinburgh:United Kingdom', 'state': 'S'},
#  584: {'infected': 0, 'old_label': 'Kalamazoo:MI', 'state': 'S'},
#  585: {'infected': 0,
#   'old_label': 'Santiago:Dominican Republic',
#   'state': 'S'},
#  586: {'infected': 0, 'old_label': 'Nadi:Fiji', 'state': 'S'},
#  587: {'infected': 0, 'old_label': 'Lahore:Pakistan', 'state': 'S'},
#  588: {'infected': 0, 'old_label': 'Lille:France', 'state': 'S'},
#  589: {'infected': 0, 'old_label': 'Guangzhou:China', 'state': 'S'},
#  590: {'infected': 0, 'old_label': 'Louisville:KY', 'state': 'S'},
#  591: {'infected': 0, 'old_label': 'Nome:AK', 'state': 'S'},
#  592: {'infected': 0, 'old_label': 'Dry Bay:AK', 'state': 'S'},
#  593: {'infected': 0, 'old_label': 'Boca Raton:FL', 'state': 'S'},
#  594: {'infected': 0, 'old_label': 'Belfast:United Kingdom', 'state': 'S'},
#  595: {'infected': 0, 'old_label': 'Sanford:FL', 'state': 'S'},
#  596: {'infected': 0, 'old_label': 'Peoria:IL', 'state': 'S'},
#  597: {'infected': 0, 'old_label': 'Tofino:Canada', 'state': 'S'},
#  598: {'infected': 0, 'old_label': 'Moscow:Russia', 'state': 'S'},
#  599: {'infected': 0, 'old_label': 'Rzeszow:Poland', 'state': 'S'},
#  600: {'infected': 0,
#   'old_label': 'Pinehurst/Southern Pines:NC',
#   'state': 'S'},
#  601: {'infected': 0, 'old_label': 'Manzanillo:Mexico', 'state': 'S'},
#  602: {'infected': 0, 'old_label': 'Oakland:CA', 'state': 'S'},
#  603: {'infected': 0, 'old_label': 'Portsmouth:NH', 'state': 'S'},
#  604: {'infected': 0, 'old_label': 'Kazan:Russia', 'state': 'S'},
#  605: {'infected': 0, 'old_label': 'Boise:ID', 'state': 'S'},
#  606: {'infected': 0, 'old_label': 'Hamilton:Bermuda', 'state': 'S'},
#  607: {'infected': 0, 'old_label': 'Montevideo:Uruguay', 'state': 'S'},
#  608: {'infected': 0, 'old_label': 'Austin:TX', 'state': 'S'},
#  609: {'infected': 0, 'old_label': 'Phoenix:AZ', 'state': 'S'},
#  610: {'infected': 0, 'old_label': 'Green Bay:WI', 'state': 'S'},
#  611: {'infected': 0, 'old_label': 'Holguin:Cuba', 'state': 'S'},
#  612: {'infected': 0, 'old_label': 'Flagstaff:AZ', 'state': 'S'},
#  613: {'infected': 0, 'old_label': 'Hartford:CT', 'state': 'S'},
#  614: {'infected': 0, 'old_label': 'Kuwait:Kuwait', 'state': 'S'},
#  615: {'infected': 0, 'old_label': 'Riyadh:Saudi Arabia', 'state': 'S'},
#  616: {'infected': 0,
#   'old_label': 'Philipsburg:Netherlands Antilles',
#   'state': 'S'},
#  617: {'infected': 0, 'old_label': 'Evansville:IN', 'state': 'S'},
#  618: {'infected': 0, 'old_label': 'Kumamoto:Japan', 'state': 'S'},
#  619: {'infected': 0, 'old_label': 'Cancun:Mexico', 'state': 'S'},
#  620: {'infected': 0, 'old_label': 'Campbell River:Canada', 'state': 'S'},
#  621: {'infected': 0, 'old_label': 'Nagoya:Japan', 'state': 'S'},
#  622: {'infected': 0, 'old_label': 'Amman:Jordan', 'state': 'S'},
#  623: {'infected': 0, 'old_label': 'Miami:FL', 'state': 'S'},
#  624: {'infected': 0, 'old_label': 'Merida:Mexico', 'state': 'S'},
#  625: {'infected': 0, 'old_label': 'Cherry Point:NC', 'state': 'S'},
#  626: {'infected': 0, 'old_label': 'Saipan:TT', 'state': 'S'},
#  627: {'infected': 0, 'old_label': 'Paris:France', 'state': 'S'},
#  628: {'infected': 0, 'old_label': 'Powell River:Canada', 'state': 'S'},
#  629: {'infected': 0, 'old_label': 'Tijuana:Mexico', 'state': 'S'},
#  630: {'infected': 0, 'old_label': 'La Paz:Mexico', 'state': 'S'},
#  631: {'infected': 0, 'old_label': 'Montpellier:France', 'state': 'S'},
#  632: {'infected': 0,
#   'old_label': 'Road Town:British Virgin Islands',
#   'state': 'S'},
#  633: {'infected': 0, 'old_label': 'Cortes Bay:Canada', 'state': 'S'},
#  634: {'infected': 0, 'old_label': 'St. Louis:MO', 'state': 'S'},
#  635: {'infected': 0, 'old_label': 'La Paz:Bolivia', 'state': 'S'},
#  636: {'infected': 0, 'old_label': 'La Macaza:Canada', 'state': 'S'},
#  637: {'infected': 0, 'old_label': 'Fayetteville:NC', 'state': 'S'}}

# %%
ini_w=g.edge[366][212]['weight']
print ini_w, 'before'
g.edge[366][212]['weight']=int(g.edge[366][212]['weight']*.5)
print g.edge[366][212]['weight'], 'after'
g.edge[366][212]['weight']=int(g.edge[366][212]['weight']*2)
print g.edge[366][212]['weight'], 'returned'
g.edge[366][212]['weight']=933
# Out:
# 932 before
# 466 after
# 932 returned
