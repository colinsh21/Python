# %%
'''
IMPORTS
'''

# %matplotlib inline

# Standard imports
import copy
import itertools

# Scientific computing imports
import numpy
import matplotlib.pyplot as plt
import networkx as nx
import pandas
import collections
from collections import Iterable
from bisect import bisect
from networkx.algorithms.flow import edmonds_karp
from random import choice
import matplotlib.cm as cm

import seaborn; seaborn.set()

# Import widget methods
from IPython.html.widgets import *
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
class Ant(object):
    """
    Ant class, which encapsulates the entire behavior of an ant.
    """
    def __init__(self,model,ant_id,colony_id):
    
        # Set model link and ID
        self.model = model
        self.ant_id = (ant_id,colony_id)
        
    def random_walk(self,source,sink,alpha=1.0,beta=1.0,system=0):
        #Random Walk
        #initialize method
        self.alpha=alpha
        self.beta=beta
        self.source=source
        self.sink=sink
        self.system=system
        self.g=nx.DiGraph()
        
        #initialize needed global data for heuristic
        self.capacity_list=self.get_capacity_list(self.system)
        
        #initialize start of random walk
        self.last_nodes={}
        for s in self.source:
            self.last_nodes[s]=[s]
        
        for key in self.last_nodes:
            self.g.add_node(key)
        
        #Create path for an ant
        terminate=0
        steps=0
        consecutive_no_additions=0
        while not terminate:
            #terminate=0
            new=0 #did this step add new nodes?
            
            sinks_included=1
            for sink_node in self.sink:
                if sink_node not in self.g.nodes():
                    sinks_included=0
            
            cycling=0        
            #if consecutive_no_additions>100:
                #cycling=1
                #if sinks_included==0: #sinks not in graph
                    #for node in self.last_nodes:
                        #self.last_nodes[node].append(self.g.neighbors(node)) #if cycling encourage ants to explore    
                #else: # sinks in graph
                #self.last_nodes={} #end search 
                    #print 'cut list' 
                                  
            for key in self.last_nodes:
                '''
                Ant step is encompassed below
                '''
                steps+=1

                #track next nodes
                self.last_nodes_next={}
                
                #print 'start of step',self.last_nodes
                #Check for sink inclusion
                #sinks_included=1
                #for sink_node in self.sink:
                    #if sink_node not in self.g:
                        #sinks_included=0  
                
                #Set to only branch first time node is visited.
                    #After that can only go along existing paths.
                #Get number of branches     
                self.branch_pheromone_list=self.get_pheromone_branch(key,self.system)
                #print self.base_node,self.g.out_degree(self.base_node)
                if self.g.out_degree(key):
                    existing=1
                    if cycling==0: #if not cycling try to follow previous path
                        self.branches=self.g.out_degree(key)
                    else:
                        self.branches=1 #if cycling try and create new branch
                else:
                    existing=0
                    self.branches=self.make_decision(self.branch_pheromone_list)+1 #index of decision +1 is the number of branches chosen
                self.neighbors_chosen=[] #list other branches taken out of that node
                #print existing
                
                #if (key in self.sink) and sinks_included==1:
                if sinks_included==1:
                    terminate_ant=self.make_decision(self.get_pheromone_termination(key,self.system))
                    #print 'do not terminate ant'
                    if terminate_ant==1: #0 is do not terminate
                        #print 'terminate ant:', (len(self.last_nodes)-1),'left'
                        self.branches=0 #continue
                        
                for branch in xrange(self.branches):
                    #get neighbors
                    #self.base_node=self.last_nodes[i]
                    
                    #self.base_node=self.last_nodes.pop()
                    self.all_p_neighbors=self.get_neighbors(key)
                   
                    #if existing==1 and consecutive_no_additions<200: #if already visited can only take existing branches
                        #self.all_p_neighbors=self.g.neighbors(key)
                        #self.p_neighbors=list(set(self.all_p_neighbors)-set(self.neighbors_chosen))
                    #else:#prevent ants taking same branch
                        #self.p_neighbors=list(set(self.all_p_neighbors)-set(self.neighbors_chosen)) 
                    self.p_neighbors=list(set(self.all_p_neighbors)) #-set(self.neighbors_chosen))
                    #get pheromone of each edge to neighbor
                    self.edge_pheromone_list=[]
                    #print 'last_nodes',self.last_nodes, 'base',key
                    #print 'previous',self.last_nodes[key]
                    for self.potential_node in self.p_neighbors:
                        edge_pheromone=self.get_pheromone_edge((key,self.potential_node),self.system)
                        #if self.potential_node in self.g.neighbors(key):
                        if self.potential_node in self.g.neighbors(key) and sinks_included==1: #current best
                            edge_pheromone*=3
                        #print 'potential',self.potential_node
                        #print self.potential_node in self.last_nodes[key]
                        if self.potential_node in self.last_nodes[key]:
                            #print 'pred'
                            edge_pheromone*=.001
                        self.edge_pheromone_list.append(edge_pheromone)

                    #get next node
                    self.next_node=self.p_neighbors[self.make_decision(self.edge_pheromone_list)]
                    self.neighbors_chosen.append(self.next_node) #record branch taken
                    

                    #add edge
                    if self.next_node not in self.g.nodes():
                        new=1 #consecutive_no_additions=0
                    else: 
                        new=0 #consecutive_no_additions+=1
                        
                    self.g.add_edge(key,self.next_node)
                    #self.g.add_edge(self.next_node,self.base_node) #create undirected
                    #print(self.g.nodes())

                    #get capacity pheromones
                    capacity_pheromone_list=self.get_pheromone_capacity((key,self.next_node),self.system)
                    
                    #get capacity heuristic
                    cap_in=0
                    for node_key in space.g.pred[key]:
                        cap_in+=space.g.pred[key][node_key]['capacity']
                    
                    heuristic_list=[]
                    for cap in self.capacity_list:
                        #heuristic_list.append((1.0/(1.0+abs(cap_in-cap)))**self.beta)
                        if (cap_in-cap)>0:
                            heuristic_value=1.0/(1.0+abs(cap_in-cap))
                        else:
                            heuristic_value=2.0
                            
                        heuristic_list.append(heuristic_value**self.beta)
                    
                    #apply heuristic to capacity pheromones
                    self.adjusted_pheromone_list=[]
                    #print self.capacity_list
                    #print capacity_pheromone_list
                    #print heuristic_list
                    for j in xrange(len(capacity_pheromone_list)):
                        self.adjusted_pheromone_list.append((capacity_pheromone_list[j]**self.alpha)*heuristic_list[j]**self.beta)

                    #decide capacity
                    self.capacity_to_add=self.model.capacities[self.system][self.make_decision(self.adjusted_pheromone_list)]

                    #add capacity
                    self.g[key][self.next_node]['capacity']=self.capacity_to_add
                    #self.g[self.next_node][self.base_node]['capacity']=self.capacity_to_add
                    
                    #add node
                    if self.next_node in self.last_nodes_next:
                        self.last_nodes_next[self.next_node].append(key)
                    else:
                        self.last_nodes_next[self.next_node]=[key]

                #Check termination criteria - are all sinks in the graph
                #for sink_node in self.sink:
                    #if sink_node not in self.g:
                        #terminate=0 
            #print 'all next nodes',self.last_nodes_next
            
            #Clear list if cycling
            if new==0:
                consecutive_no_additions+=1
            else:
                consecutive_no_additions=0
            
            #print (new,consecutive_no_additions,consecutive_no
            
            if consecutive_no_additions>100:
                self.last_nodes_next=[]
                #print 'cut list'
            
            #Check Termination Criteria
            if not self.last_nodes_next:
                #print self.last_nodes_next
                terminate=1
                #print 'no ants left'
                #check branches
                #for n in self.g:
                    #if (self.g.out_degree(n)==0) and (n not in self.sink):
                        #self.last_nodes_next.append(n)
                        #print 'found branch'
                        #terminate=0
                    

            self.last_nodes=self.last_nodes_next
            #print self.ant_id, 'all next nodes again',self.last_nodes
        out_graph=self.prune_graph(self.g,self.sink,self.source)
        #print (self.ant_id,float(self.ant_id[0]-1)/(space.num_ants-1)), steps
        return  (out_graph) #(self.g) 
    
    def prune_graph(self,graph,sinks,sources):
        """
        Removes nodes that only go out and back.
        """
        done=0
        while not done:
            done=1
            for n in graph:
                #if graph.out_degree(n)==0 and graph.in_degree(n)==0: #disconnected nodes
                    #print 'removed disconnected node', n
                    #done=0
                    #break
                    
                if graph.out_degree(n)==0 and (n not in sinks): #dead end, non-sink nodes graph.in_degree(n)>0 and 
                    #print 'removed dead end node', n
                    done=0
                    break
                
                
                if (graph.out_degree(n)==1) and (graph.in_degree(n)==1) and (n not in (sinks or sources)): #there and back non-critical nodes
                    neighbor=graph.neighbors(n)
                    if n in graph.neighbors(neighbor[0]):
                        #print 'removed cul de sac node', n
                        done=0
                        break
            if done==0:
                #print n
                #print graph.nodes()
                graph.remove_node(n)
        
        #print graph.nodes()
        #print graph.edges()
        return graph
                
    
    def get_neighbors(self,node):
        """
        Return neighbors, calling through model.
        """
        return self.model.get_ant_neighbors(node)
    
    def make_decision(self,pheromone_list):
        """
        Return decision index, based on pheromone list.
        """
        #convert pheromones to percentage
        self.percent_list = [float(i)/sum(pheromone_list) for i in pheromone_list]   
        self.cumulative_percent=numpy.cumsum(self.percent_list)

        #Choose decision index
        self.select_index=bisect(self.cumulative_percent,numpy.random.uniform(0,1,1))
  
        return self.select_index
    
    def get_capacity_list(self,system):
        """
        Returns the capacity list from the space
        """
        return self.model.capacities[system]
    
    def get_pheromone_branch(self,node,system):
        """
        Return node pheromone, calling through model.
        """    
        return self.model.get_branch_pheromone(node,self.ant_id,system)
    
    def get_pheromone_edge(self,edge,system):
        """
        Return edge pheromone, calling through model.
        """
        return self.model.get_edge_pheromone(edge,self.ant_id,system)

    def get_pheromone_capacity(self,edge,system):
        """
        Return edge pheromone, calling through model.
        """
        return self.model.get_capacity_pheromone(edge,self.ant_id,system)
    
    def get_pheromone_termination(self,node,system):
        """
        Return node pheromone, calling through model.
        """    
        return self.model.get_termination_pheromone(node,self.ant_id,system)        
    

    def __repr__(self):
        '''
        Return string representation.
        '''
        skip_none = True
        repr_string = type(self).__name__ + " ["
        except_list = "model"

        elements = [e for e in dir(self) if str(e) not in except_list]
        for e in elements:
            # Make sure we only display "public" fields; skip anything private (_*), that is a method/function, or that is a module.
            if not e.startswith("_") and eval('type(self.{0}).__name__'.format(e)) not in ['DataFrame', 'function', 'method', 'builtin_function_or_method', 'module', 'instancemethod']:
                    value = eval("self." + e)
                    if value != None and skip_none == True:
                        repr_string += "{0}={1}, ".format(e, value)

        # Clean up trailing space and comma.
        return repr_string.strip(" ").strip(",") + "]"

# %%
class Space(object):
    """
    Space class, which encapsulates the entire behavior of a single "run" ACO.
    """
    def __init__(self, size=[3,3],num_ants=2,num_colonies=1,
                 source=[[(0,0)],[(1,1)]],source_magnitude=[[5],[5]],
                 sink=[[(1,1)],[(2,0)]],sink_magnitude=[[5],[5]], sink_threshold=[[1.0],[1.0]],
                 links=[(1,0,(1,1))],capacities=[[5,10],[5,10]],edge_capacity=20, percent_removals=.5,
                 dissipation=.2,initial_pheromone=1.0,initial_termination=.5,
                 alpha=1.0,beta=1.0):
        """
        Class constructor.
        """
        # Set our model parameters
        self.size = size
        #System A
        self.sink = sink
        self.sink_magnitude = sink_magnitude
        self.sink_threshold= sink_threshold #at what point is the sink not functioning
        self.source=source
        self.source_magnitude = source_magnitude
        self.links=links #(recieving_system,sending_system,node)
        
        #Ants
        self.num_ants=num_ants
        self.num_colonies=num_colonies
        self.dissipation=dissipation
        self.initial_pheromone=initial_pheromone
        self.capacities=capacities
        self.alpha=alpha
        self.beta=beta
        self.percent_removals=percent_removals
        self.initial_termination=initial_termination
        self.edge_capacity=edge_capacity
        
        
        # Set our state variables
        self.t = 0
        self.ants = []
        self.ant_graphs=[]
        #self.global_scores=[]

        
        # Call our setup methods to initialize space, people, and institution.
        self.setup_space()
        self.setup_ants()
        

    def setup_space(self):
        """
        Method to setup our space.
        """
        # Initialize a space with a grid network
        self.g = nx.grid_graph(dim=self.size)
        self.g=self.g.to_directed()
        
        #Set Pheromones
        print 'Setting up network'
        capacity_pheromone_list=[self.initial_pheromone]*len(self.capacities[0])*2
        capacity_pheromone_list.extend([self.initial_pheromone]*len(self.capacities[1])*2)
        for e in self.g.edges_iter():
            self.g.add_edge(e[0],e[1],max_capacity=self.edge_capacity)
            self.g.add_edge(e[0],e[1],capacity=0) #initial capacity 
            self.g.add_edge(e[0],e[1],edge_pheromone=[self.initial_pheromone]*2*2) #pheromone per edge
            self.g.add_edge(e[0],e[1],capacity_pheromone=capacity_pheromone_list) #pheromone per capacity
            
        for n in self.g.nodes_iter():
            neighbors_n=self.g.neighbors(n)
            pheromone_list=[]
            for num in xrange(len(neighbors_n)):
                #pheromone_list.append((num+1)/10.0)
                pheromone_list.append(numpy.exp(-num*3))
                
            #pheromone_list.reverse()
            pheromone_list=[self.initial_pheromone]
            pheromone_list.extend([self.initial_pheromone*.5]*(len(neighbors_n)-1))
            #print pheromone_list*2*2
            self.g.add_node(n,branch_pheromone=pheromone_list*2*2)
            #print 'test',self.g.node[n]['branch_pheromone']

            ph_term=[self.initial_termination*0.25,self.initial_termination]*2*2 #self.initial_termination*0.1
            #ph_term=[[self.initial_termination*2]]*2
            #print ph_term
            self.g.add_node(n,termination_pheromone=ph_term)

            
        self.g_layout = nx.spectral_layout(self.g)
 
        
    def setup_ants(self):
        """
        Method to setup our space.
        """       
        # First, begin by creating all ants.
        int_id=0 #set up list ID of ants
        self.ant_id_dict={} #set up dict converting ant id to list id
        for c in xrange(self.num_colonies):
            for i in xrange(self.num_ants):
                self.ants.append(Ant(model=self,ant_id=(i+1),colony_id=(c+1)))
                self.ant_id_dict[(i,c)]=int_id                
                int_id+=1
        #print self.ant_id_dict
    
    def split_lists(self,input_list):
        half = len(input_list)/2
        return input_list[:half], input_list[half:]
    
    def flatten(self,lis):
         for item in lis:
            if isinstance(item, Iterable) and not isinstance(item, basestring):
                for x in self.flatten(item):
                    yield x
            else:        
                yield item
  
    def get_branch_pheromone(self,node,ant_id,system):     
        """
        Get branch decision pheromone for ant call
        """          
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        pheromone_full=self.g.node[node]['branch_pheromone']
        system_pheromones=[[],[]]
        system_pheromones[0],system_pheromones[1]=self.split_lists(pheromone_full)
        #print pheromone_full
        pheromone_1, pheromone_2=self.split_lists(system_pheromones[system])
        #print pheromone_1
        #print pheromone_2
    
        weighted_pheromone_1=[i**ant_weight for i in pheromone_1]
        weighted_pheromone_2=[i**(1-ant_weight) for i in pheromone_2]
        #print 'ph_1',weighted_pheromone_1
        #print 'ph_2',weighted_pheromone_2
        #print 'weight',ant_weight
        composite_pheromone=[weighted_pheromone_1[i]*weighted_pheromone_2[i] for i in xrange(len(weighted_pheromone_1))]
        #print 'comp',composite_pheromone
        return composite_pheromone
            
    def get_edge_pheromone(self,edge,ant_id,system):
        """
        Get edge decision pheromone for ant call
        """        
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        #print self.g[edge[0]][edge[1]]['edge_pheromone']
        if system==1:
            pheromone_1=self.g[edge[0]][edge[1]]['edge_pheromone'][0]
            pheromone_2=self.g[edge[0]][edge[1]]['edge_pheromone'][1]
        else:
            pheromone_1=self.g[edge[0]][edge[1]]['edge_pheromone'][2]
            pheromone_2=self.g[edge[0]][edge[1]]['edge_pheromone'][3]
                
        return (pheromone_1**ant_weight)*(pheromone_2**(1-ant_weight))
    
    def get_capacity_pheromone(self,edge,ant_id,system):
        """
        Get capacity decision pheromone for ant call
        """  
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        pheromone_full=self.g[edge[0]][edge[1]]['capacity_pheromone']
        system_pheromones=[[],[]]
        system_pheromones[0]=pheromone_full[:len(self.capacities[0])*2]
        system_pheromones[1]=pheromone_full[len(self.capacities[0])*2:]
        pheromone_1, pheromone_2=self.split_lists(system_pheromones[system])
        
        weighted_pheromone_1=[i**ant_weight for i in pheromone_1]
        weighted_pheromone_2=[i**(1-ant_weight) for i in pheromone_2]
        composite_pheromone=[weighted_pheromone_1[i]*weighted_pheromone_2[i] for i in xrange(len(weighted_pheromone_1))]
        
        return composite_pheromone
    
    def get_termination_pheromone(self,node,ant_id,system):
        """
        Get termination decision pheromone for ant call
        """        
        ant_weight=float(ant_id[0]-1)/(self.num_ants-1)
        pheromone_full=self.g.node[node]['termination_pheromone']
        system_pheromones=[[],[]]
        system_pheromones[0],system_pheromones[1]=self.split_lists(pheromone_full)
        pheromone_1, pheromone_2=self.split_lists(system_pheromones[system])
    
        weighted_pheromone_1=[i**ant_weight for i in pheromone_1]
        weighted_pheromone_2=[i**(1-ant_weight) for i in pheromone_2]
        composite_pheromone=[weighted_pheromone_1[i]*weighted_pheromone_2[i] for i in xrange(len(weighted_pheromone_1))]
        
        return composite_pheromone 
        
    def get_ant_neighbors(self,node):
        """
        Get node neighbors for ant call
        """
        return self.g.neighbors(node)
            
    def get_path(self, ant_id,system):
        """
        Get the path of an ant based on their ID.
        """
        ant_list_id=self.ant_id_dict[ant_id]
        return self.ants[ant_list_id].random_walk(self.source[system],self.sink[system],self.alpha,self.beta,system)
    
    def flow_test(self,graph):
        """
        Calculates the flow from sources to sinks in a graph.
        
        """
        flow_graph_1=copy.deepcopy(graph[0])
        flow_graph_2=copy.deepcopy(graph[1])
        
        #print self.sink[0]
        for i in xrange(len(self.sink[0])):
            #print self.sink[0][i]
            flow_graph_1.add_edge(self.sink[0][i],'sink',capacity=self.sink_magnitude[0][i])
            #print flow_graph[g][self.sink[g][i]]['sink']
        
        #print self.sink[1]
        for i in xrange(len(self.sink[1])):
            #print self.sink[1][i]
            flow_graph_2.add_edge(self.sink[1][i],'sink',capacity=self.sink_magnitude[1][i])
        
        #add aggregate source
        
        
        #print self.source[0]
        flow_graph_1.add_node('place_holder') #fixes indexing error in maximum_flow
        for i in xrange(len(self.source[0])):
            #print self.source[0][i]
            flow_graph_1.add_edge('source',self.source[0][i],capacity=self.source_magnitude[0][i])
            
        #print self.source[1]
        flow_graph_2.add_node('place_holder') #fixes indexing error in maximum_flow
        for i in xrange(len(self.source[1])):
            #print self.source[1][i]
            flow_graph_2.add_edge('source',self.source[1][i],capacity=self.source_magnitude[1][i])
        
        flow_graph=[flow_graph_1,flow_graph_2]
        flow=[]
        while True:
            #get flow values
            flow_value=[[],[]]
            flow_dict=[[],[]]
            flow_value[0], flow_dict[0] = nx.maximum_flow(flow_graph[0], 'source', 'sink')
            flow_value[1], flow_dict[1] = nx.maximum_flow(flow_graph[1], 'source', 'sink')
            flow.append(flow_value)
            #print flow
            #print flow_dict
            
            failure=0
            for link in self.links:
                receiving=link[0] #system recieving flow
                sending=link[1] #system sending flow
                node=link[2]
                sending_node_index=self.sink[sending].index(node)
                #print sending_node_index,self.sink[sending][sending_node_index],node
                sending_flow=flow_dict[sending][node]['sink']
                sending_threshold=float(self.sink_magnitude[sending][sending_node_index])*self.sink_threshold[sending][sending_node_index]
                
                failure=0
                if sending_flow < sending_threshold: #sink fails and linked source fails
                    #print 'cascading failure'
                    failure=1
                    flow_graph[receiving]['source'][node]['capacity']=0
                    #print flow_graph[receiving]['source'][node]['capacity']
            if failure==0 or (len(flow)>=2 and (flow[-1]==flow[-2])):
                #print 'cascade over'
                break
                                       
        
        return flow_value, flow_dict
    
    def graph_energy(self,graph):
        """
        Calculates the energy of a system graph.
        """
        e_val, e_vec=numpy.linalg.eig(nx.adjacency_matrix(graph.to_undirected()).todense())
    
        return sum(abs(e_val))
    
    
    def complexity_score(self,graph):
        """
        Calculates the complexity of two system graph.
        """
        #base_energy=[self.graph_energy(graph[0]),self.graph_energy(graph[1])]
        sys_complexity_edge=0
        for u,v in self.g.edges():
            temp_graph=copy.deepcopy(graph)
            edge_energy=[]
            #get max_cap from space (there and back are the same)
            edge_max=space.g[u][v]['max_capacity']
            #get cap from sys_1
            edge_cap=0
            num_sys_edge=0
            for g_index in xrange(2):
                #get capacity in edge
                sys_cap=0
                if temp_graph[g_index].has_edge(u,v):
                    sys_cap+=graph[g_index][u][v]['capacity']
                    temp_graph[g_index].remove_edge(u,v)
                    num_sys_edge+=1
                #if temp_graph[g_index].has_edge(v,u):
                    #sys_cap+=graph[g_index][v][u]['capacity']
                    #temp_graph[g_index].remove_edge(v,u)
                edge_cap+=sys_cap
                
                #calculate edge complexity
                #edge_energy.append(abs(base_energy[g_index]-self.graph_energy(temp_graph[g_index])))
            
            cap_difference=float(edge_cap)/edge_max
            if num_sys_edge>0:           
                edge_complexity=edge_cap*2**(cap_difference*num_sys_edge) #edge_energy[0]+edge_energy[1]
            else:
                edge_complexity=0
            #print (u,v,edge_complexity,edge_energy,cap_difference)    
            sys_complexity_edge+=edge_complexity
            
        sys_complexity_node=0
        for n in self.g:
            num_sys_node=0
            edge_in=0
            edge_out=0
            for g_index in xrange(2):
                if n in graph[g_index]:
                    num_sys_node+=1
                    edge_in+=graph[g_index].in_degree(n)
                    edge_out+=graph[g_index].out_degree(n)
            if num_sys_node>0:
                node_complexity=(edge_in+edge_out)*2**num_sys_node
            else:
                node_complexity=0
            sys_complexity_node+=node_complexity
            
        sys_complexity=sys_complexity_node+sys_complexity_edge
        #sys_complexity=graph[0].number_of_edges()+graph[1].number_of_edges()+(graph[0].number_of_nodes()+graph[1].number_of_nodes())
        
        
        return sys_complexity
    
    def evaluate_graph(self, ant_graph):
        """
        Score graphs based on criteria.
        """
                
        #Score 1 - Flow        
        #get initial flow values
        flow_value_ini,flow_dict_ini=self.flow_test(ant_graph)
        #print flow_value_ini
        #print sum(self.sink_magnitude[0]),sum(self.sink_magnitude[1])
        flow_score_ini=[]
        for g_index in xrange(2):
            flow_score_ini.append(float(flow_value_ini[g_index])/sum(self.sink_magnitude[g_index]))
            
        for g_index in xrange(2):
            all_sink=1
            for sink_index in xrange(len(self.sink[g_index])):
                sink_flow=flow_dict_ini[g_index][self.sink[g_index][sink_index]]['sink']
                #flow_score_ini[g_index]+=float(sink_flow)/self.sink_magnitude[g_index][sink_index]
                if sink_flow==0:
                    all_sink=0
            flow_score_ini[g_index]*=all_sink
                
        #print 'flow_score',flow_score_ini
        satisfy_flow=flow_score_ini
        #satisfy_flow=1
        #if (flow_score_ini[0]<1 or flow_score_ini[1]<1):
            #satisfy_flow=0
            #print 'flow failure'
            #return (0,0),satisfy_flow
        
        #percolate and test flow
        percolation_graph=copy.deepcopy(ant_graph)
        space_graph = nx.grid_graph(dim=self.size)
        space_graph=space_graph.to_directed()
        base_percolation_graph=[]
        for g in xrange(2):
            base_percolation_graph.append(nx.compose(space_graph,percolation_graph[g]))
        #num_removals=int(numpy.rint(self.percent_removals*ant_graph.number_of_edges()))
        num_removals=int(numpy.rint(base_percolation_graph[0].number_of_edges()*self.percent_removals))
        
        survivability_flow=0
        survivability_function=0
        num_trials=10
        for i in xrange(num_trials):
            percolation_graph=copy.deepcopy(base_percolation_graph)
            for j in xrange(num_removals):
                edge_removed=choice(percolation_graph[0].edges())
                for g_index in xrange(2):
                    percolation_graph[g_index].remove_edge(edge_removed[0],edge_removed[1])
                    percolation_graph[g_index].remove_edge(edge_removed[1],edge_removed[0])
                    
                #Check if there is a cascade and iterate.    
                flow_increment,flow_dict=self.flow_test(percolation_graph)
                function_increment=0
                for g_index in xrange(2):
                    for sink_index in xrange(len(self.sink[g_index])):
                        sink_flow=flow_dict[g_index][self.sink[g_index][sink_index]]['sink']
                        sink_threshold=self.sink_magnitude[g_index][sink_index]*self.sink_threshold[g_index][sink_index]                         
                        function_increment+=(sink_flow>=sink_threshold)
                    
                        #print survivability_function
                if function_increment==0:
                    #print 'Failed'
                    break
                else:
                    survivability_function+=function_increment

        #flow is judged by the amount of flow that gets to the aggregate sink based on the total sink magnitude
        num_sinks=len(self.sink_magnitude[0])+len(self.sink_magnitude[1])
        #print num_sinks,num_removals,num_trials
        if num_removals==0:
            survivability_score_function=1
        else:
            survivability_score_function=float(survivability_function)/(num_sinks*num_removals*num_trials)
        #survivability_score_flow=float(survivability_flow)/(sum(self.sink_magnitude)*num_removals*num_trials)
        #print survivability_score_function
        #Score 2 - Complexity
        survivability_score_function*=(flow_score_ini[0]*flow_score_ini[1])**2
        complexity_score=self.complexity_score(ant_graph)
        if flow_score_ini[0]*flow_score_ini[1]==0:
            complexity_score*=1000
        else:
            complexity_score*=1/(flow_score_ini[0]*flow_score_ini[1])**2
        
        return (survivability_score_function,complexity_score),satisfy_flow
    
    def dominates(self, point_1, point_2, equality_sequence):
        '''
        Calculates if a point is dominated by another point, used in simple_cull_front
        equality_sequence:= 1 is '>=',0 is '<='
        '''
        score=0
        for i in range(len(point_1)):
            if equality_sequence[i]==1 and point_1[i]>=point_2[i]:
                score+=1
            elif equality_sequence[i]==0 and point_1[i]<=point_2[i]:
                score+=1
        dom=score==len(point_1)    
        return dom    
   
    def simple_cull_front(self, inputPoints, dominates, equality_sequence):
        '''
        Basic algorithm to find the pareto front of a set of points
        min or max is determined based on equality_sequence:= 0 is min, 1 is max
        '''
        paretoPoints = set()
        candidateRowNr = 0
        dominatedPoints = set()
        while True:
            candidateRow = inputPoints[candidateRowNr]
            inputPoints.remove(candidateRow)
            rowNr = 0
            nonDominated = True
            while len(inputPoints) != 0 and rowNr < len(inputPoints):
                row = inputPoints[rowNr]
                if self.dominates(candidateRow, row,equality_sequence):
                    # If it is worse on all features remove the row from the array
                    inputPoints.remove(row)
                    dominatedPoints.add(tuple(row))
                elif self.dominates(row, candidateRow, equality_sequence):
                    nonDominated = False
                    dominatedPoints.add(tuple(candidateRow))
                    rowNr += 1
                else:
                    rowNr += 1

            if nonDominated:
                # add the non-dominated point to the Pareto frontier
                paretoPoints.add(tuple(candidateRow))

            if len(inputPoints) == 0:
                break
        return paretoPoints, dominatedPoints

    
    def ant_ranking(self, ant_graphs):
        """
        Find best Ants based on scores from evaluate_graph.
        """
        score_list=[]
        num_ants_generation=self.num_ants*self.num_colonies
        #[score_list.append(graph[1]) for graph in ant_graphs[-num_ants_generation:]] #Generation Pareto
        [score_list.append(graph[1]) for graph in ant_graphs] #Global Pareto
        cull_scores=score_list[:]
        equality_sequence=[1,0] #[>=,<=]
        self.paretoPoints, self.dominatedPoints=self.simple_cull_front(cull_scores,self.dominates,equality_sequence)
        self.paretoPoints=list(self.paretoPoints)

        best_ants_index=[]
        
        #match the score_list indices to the pareto front values
        for i in xrange(len(score_list)):
            if score_list[i] in self.paretoPoints:
                best_ants_index.append(i)
                #print 'pareto score @',i,':',score_list[i]
                
        return best_ants_index, score_list
    
    def pheromone_dissipation(self,pheromone_list,dissipation):
        """
        Updates a pheromone list with the proper increment based on system number.
        """
        return_list=[]
        for i in xrange(len(pheromone_list)):
            return_list.append(pheromone_list[i]*(1.0-dissipation))
        #print return_list
        return return_list
    
    def pheromone_update(self,pheromone_list,increment,system,index):
        """
        Updates a pheromone list with the proper increment based on system number.
        """
        sys_list=[[],[]]
        sys_list[0],sys_list[1]=self.split_lists(pheromone_list)
        objective_sys_list=[[[],[]],[[],[]]]
        for sys in xrange(2):
            objective_sys_list[sys][0],objective_sys_list[sys][1]=self.split_lists(sys_list[sys])
        for obj in xrange(2):
            objective_sys_list[system][obj][index]+=increment[obj]
        return_list=list(self.flatten(objective_sys_list))
        #print return_list
        return return_list
    
    def pheromone_update_capacity(self,pheromone_list,increment,system,index):
        """
        Updates a pheromone list with the proper increment based on system number.
        """
        sys_list=[[],[]]
        sys_list[0]=pheromone_list[:len(self.capacities[0])*2]
        sys_list[1]=pheromone_list[len(self.capacities[0])*2:]
        pheromone_1, pheromone_2=self.split_lists(sys_list[system])
        objective_sys_list=[[[],[]],[[],[]]]
        for sys in xrange(2):
            objective_sys_list[sys][0],objective_sys_list[sys][1]=self.split_lists(sys_list[sys])
        for obj in xrange(2):
            objective_sys_list[system][obj][index]+=increment[obj]
        return_list=list(self.flatten(objective_sys_list))
        #print return_list
        return return_list
        
    
    def step(self):
        """
        Model step function.
        """
        #Ants make paths
        #self.ant_graphs=[] #exclude for initialized in setup for global pareto front
        
        #Step for each ant
        failures=0
        for c in xrange(self.num_colonies):
            print 'colony:',c
            for i in xrange(self.num_ants):
                full_flow=0
                ant_failures=0
                while full_flow==0:
                    self.ant_graph=[[],[]]
                    for g in xrange(2):
                        self.ant_graph[g]=self.get_path((i,c),g)
                        #print 'Initial flow graph capacity', g
                        #print nx.get_edge_attributes(self.ant_graph[g],'capacity')

                    #Evaluate Paths
                    self.graph_score,sat_flow=self.evaluate_graph(self.ant_graph)
                    full_flow=1
                    #print sat_flow
                    if sat_flow[0]==0 or sat_flow[1]==0:
                        failures+=1
                        ant_failures+=1
                        full_flow=0
                    #print sat_flow

                #List <graph,score>
                self.ant_graphs.append((self.ant_graph,self.graph_score))
                print (i,c), 'flow=',sat_flow, 'failures=', ant_failures
                #print 'got one'
        
        print failures    
        #Get best score
        self.opt_ant,self.score_list=self.ant_ranking(self.ant_graphs)
        
        
        #Update Institutions - Edges and capacities for this walk
        #Get pheromones
        self.edge_pheromone_dict=nx.get_edge_attributes(self.g,'edge_pheromone')
        self.capacity_pheromone_dict=nx.get_edge_attributes(self.g,'capacity_pheromone')
        self.branch_pheromone_dict=nx.get_node_attributes(self.g,'branch_pheromone')
        self.termination_pheromone_dict=nx.get_node_attributes(self.g,'termination_pheromone')
        
        #print self.termination_pheromone_dict
        
        #Reduce edge pheromones by input amount
        
        for key in self.edge_pheromone_dict:
            self.edge_pheromone_dict[key]=self.pheromone_dissipation(self.edge_pheromone_dict[key],
                                                                     self.dissipation)
        for key in self.capacity_pheromone_dict:
            self.capacity_pheromone_dict[key]=self.pheromone_dissipation(self.capacity_pheromone_dict[key],
                                                                     self.dissipation)
        
        #Reduce edge pheromones by input amount
        for key in self.branch_pheromone_dict:
            self.branch_pheromone_dict[key]=self.pheromone_dissipation(self.branch_pheromone_dict[key],
                                                                             self.dissipation)
 
        for n in self.g.nodes():
            self.termination_pheromone_dict[n]=self.pheromone_dissipation(self.termination_pheromone_dict[n],
                                                                                  self.dissipation)
                
        #Increment through best paths to update
        #for ph_index in xrange(2):
        for ant in self.opt_ant:
            for sys in xrange(2):
                pheromone_increment=[self.score_list[ant][0],2.0/len(self.opt_ant)]#self.score_list[ant][1]
                #print pheromone_increment
                for e in self.ant_graphs[ant][0][sys].edges():
                    #self.capacity_pheromone_dict[e]=self.pheromone_dissipation(self.capacity_pheromone_dict[e],
                                                                               #self.dissipation)
                    self.edge_pheromone_dict[e]=self.pheromone_update(self.edge_pheromone_dict[e],
                                                                      pheromone_increment,sys,0)

                    #get capacity chosen and update pheromones
                    self.capacity_chosen=self.ant_graphs[ant][0][sys][e[0]][e[1]]['capacity']
                    self.capacity_index=self.capacities[sys].index(self.capacity_chosen)
                    self.capacity_pheromone_dict[e]=self.pheromone_update_capacity(self.capacity_pheromone_dict[e],
                                                                                   pheromone_increment,sys,
                                                                                   self.capacity_index)
                n_list=[]
                for n in self.ant_graphs[ant][0][sys].nodes():
                    n_list.append(n)
                    #self.branch_pheromone_dict[n]=self.pheromone_dissipation(self.branch_pheromone_dict[n],
                                                                             #self.dissipation)
                    self.branches_chosen=len(self.ant_graphs[ant][0][sys].neighbors(n))
                    self.branches_index=self.branches_chosen-1
                    #print self.branch_pheromone_dict[n],self.branches_index,pheromone_increment
                    self.branch_pheromone_dict[n]=self.pheromone_update(self.branch_pheromone_dict[n],
                                                                        pheromone_increment,sys,
                                                                        self.branches_index)
                    #print self.branch_pheromone_dict[n]

                    
                    #if self.ant_graphs[ant][0][sys].out_degree(n)==0: #if terminated
                        #self.termination_pheromone_dict[n]=self.pheromone_update(self.termination_pheromone_dict[n],
                                                                                 #pheromone_increment,sys,1)
                    #else:
                        #self.termination_pheromone_dict[n]=self.pheromone_update(self.termination_pheromone_dict[n],
                                                                                     #pheromone_increment,sys,0)
                    if n in self.sink[sys]: #index 0 is keep, index 1 is terminate
                    #self.termination_pheromone_dict[n]=self.pheromone_dissipation(self.termination_pheromone_dict[n],
                                                                                  #self.dissipation)
                        if self.ant_graphs[ant][0][sys].out_degree(n)==0: #if terminated
                            self.termination_pheromone_dict[n]=self.pheromone_update(self.termination_pheromone_dict[n],
                                                                                     pheromone_increment,sys,1)
                        else:
                            self.termination_pheromone_dict[n]=self.pheromone_update(self.termination_pheromone_dict[n],
                                                                                 pheromone_increment,sys,0)
                for n in self.g.nodes():
                    if n not in n_list:
                        self.termination_pheromone_dict[n]=self.pheromone_update(self.termination_pheromone_dict[n],
                                                                                 pheromone_increment,sys,1)

        #Remove all except for pareto front ants
        keep_ants=[]
        for i in range(len(self.ant_graphs)):
            if i in self.opt_ant:
                keep_ants.append(self.ant_graphs[i])
                
        self.ant_graphs=keep_ants
        #print len(self.ant_graphs), 'length of kept graphs'
        
        
        #Set new edge pheromones
        nx.set_edge_attributes(self.g, 'edge_pheromone', self.edge_pheromone_dict)

        
        #Set new capacity pheromones
        nx.set_edge_attributes(self.g, 'capacity_pheromone', self.capacity_pheromone_dict)

        
        #Set new branch pheromones
        nx.set_node_attributes(self.g, 'branch_pheromone', self.branch_pheromone_dict)

        
        #Set new termination pheromones
        nx.set_node_attributes(self.g, 'termination_pheromone', self.termination_pheromone_dict)

# %% [markdown]
# Current best: terminate on all nodes, prune, dissipate edges each gen, dissipate branch/term/cap each step it is used, follow paths on sinks included with ph*=3.
#
# Testing:
# 4/20 2000 - dissipate all pheromones only once per generation, dissipation rate 0.5.
#     Results - Ants don't learn and create extra failures
# 4/20 2030 - new cycling prevention by restarting list of last nodes with all neighbors to be avoided as well as predecessor if sinks are not included, if sinks are included, end the walk. Dissipate all pheromones only once per generation, dissipation rate 0.2. Also, adjustments to pruning function logic in ant class.
# 4/21 0930 - if cycling only allow one new branch for each node. added cycling tracker: cycling=[0,1]
#     Results - did not get to more sparse solutions
# 4/21 1130 - fixed pruning function (not correctly determining cul-de-sac)
#     Results - decent, did not get to lower complexity values
# 4/21 1600 - end walk if cycling.
#     Results - too many failures by cycling condition
# 4/21 1630 - Moved cycling count for all ant steps, not just single ants. Encourage branching if cycling
#     Results - converged early due to generation to meeting full initial flow requirements making their scores too high
# 4/22 0030 - end walk if cycling for cycling count over all ant steps
#     Results - good solutions and solving, poor speed in the end due to failures.

# %%
'''
Run Example
'''

#space=Space()

#space=Space(size=[4,4],num_ants=10,num_colonies=10,
            #source=[[(0,0)],[(3,3)]],source_magnitude=[[10],[5]],
            #sink=[[(3,3)],[(2,0)]],sink_magnitude=[[10],[5]], sink_threshold=[[1.0],[1.0]],
            #links=[],capacities=[[10],[10]],edge_capacity=20,percent_removals=.50,
            #dissipation=0.2,initial_pheromone=1.0,initial_termination=1.0,
            #alpha=1.0,beta=1.0)

space=Space(size=[4,4],num_ants=10,num_colonies=10,
            source=[[(0,0)],[(3,3)]],source_magnitude=[[20],[10]],
            sink=[[(3,3),(1,3)],[(0,0),(2,0)]],sink_magnitude=[[10,10],[5,5]], sink_threshold=[[.5,1.0],[1.0,1.0]],
            links=[(1,0,(3,3))],capacities=[[5,10],[5]],edge_capacity=20,percent_removals=1.0,
            dissipation=0.2,initial_pheromone=1.0,initial_termination=1.0,
            alpha=1.0,beta=1.0)

#space=Space(size=[5,5],num_ants=10,num_colonies=10,
            #source=[[(0,0)],[(4,4)]],source_magnitude=[[20],[20]],
            #sink=[[(4,4),(1,3),(4,0)],[(0,0),(2,0),(4,0),(4,1)]],sink_magnitude=[[5,10,5],[5,5,5,5]], 
            #sink_threshold=[[.5,1.0,.25,1.0],[.75,1.0,.5,1.0]],
            #links=[(1,0,(4,4))],capacities=[[5,10,20],[5,10,20]],edge_capacity=50,percent_removals=.50,
            #dissipation=0.2,initial_pheromone=1.0,initial_termination=1.0,
            #alpha=1.0,beta=1.0)

#space=Space(size=[5,5,3],num_ants=10,num_colonies=10,source=[[(0,3,0),(0,1,0)],[20,20]],
            #sink=[[(3,2,2),(1,4,2),(4,4,2),(3,4,0)],[10,10,15,5]],
            #initial_pheromone=1,beta=2.0,capacities=[5,10,15,20])
converged=0
i=1
pareto_history=[]
criteria=0
while not converged:
    space.step()
    
    pareto_history.append(space.paretoPoints)
    if i>5 and pareto_history[-1]==pareto_history[-2]:
        criteria+=1
    else:
        criteria=0
    #print criteria
    
    print 'Pareto front of generation',i,':',space.paretoPoints, criteria #'\r',
    if criteria>10:
        converged=1
    
    #print '\r',i,',',
    i+=1
    if i>50:
        converged=1
        print '\n'
        

print('Ant Path')

    

# Remove the nonpath from path nodes
#nonpath_nodes = [node for node in space.g.nodes() if node not in space.ant_graphs[space.opt_ant[0]][0]]

# Now we can visualize the infected node's position
#visualize_system(space.ant_graphs[space.opt_ant[-1]][0],space.g,space.paretoPoints[-1])

#Plot Solutions
#front_x=[i[0] for i in space.paretoPoints]
#front_y=[i[1] for i in space.paretoPoints]
#dominated_x=[i[0] for i in space.dominatedPoints]
#dominated_y=[i[1] for i in space.dominatedPoints]
f = plt.figure()
#plt.scatter(dominated_x,dominated_y,alpha=0.5)
#plt.scatter(front_x,front_y,color='red',alpha=1)

colors = cm.rainbow(numpy.linspace(0, 1, len(pareto_history)))
#print colors
for gen, c in zip(pareto_history, colors):
    x=[i[0] for i in gen]
    y=[i[1] for i in gen]
    #print c
    plt.scatter(x, y, color=c)

plt.xlabel("Survivability")
plt.ylabel("Complexity")
plt.title("Survivability vs. complexity")

for i in xrange(len(space.opt_ant)):
    score=space.paretoPoints[i]
    visualize_system_single(space.ant_graphs[space.opt_ant[i]][0],space.g,score)
# Out:
# Setting up network
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 1
# (1, 0) flow= [0.5, 1.0] failures= 60
# (2, 0) flow= [0.5, 1.0] failures= 18
# (3, 0) flow= [0.5, 1.0] failures= 1
# (4, 0) flow= [0.75, 1.0] failures= 7
# (5, 0) flow= [0.75, 1.0] failures= 7
# (6, 0) flow= [0.75, 1.0] failures= 23
# (7, 0) flow= [0.75, 1.0] failures= 21
# (8, 0) flow= [0.5, 1.0] failures= 3
# (9, 0) flow= [0.5, 1.0] failures= 12
# colony: 1
# (0, 1) flow= [0.5, 1.0] failures= 18
# (1, 1) flow= [0.5, 1.0] failures= 13
# (2, 1) flow= [0.75, 1.0] failures= 5
# (3, 1) flow= [0.5, 1.0] failures= 0
# (4, 1) flow= [0.5, 1.0] failures= 20
# (5, 1) flow= [0.75, 1.0] failures= 1
# (6, 1) flow= [0.5, 1.0] failures= 6
# (7, 1) flow= [0.75, 1.0] failures= 11
# (8, 1) flow= [0.5, 1.0] failures= 67
# (9, 1) flow= [0.75, 1.0] failures= 17
# colony: 2
# (0, 2) flow= [0.5, 1.0] failures= 7
# (1, 2) flow= [0.5, 1.0] failures= 5
# (2, 2) flow= [0.5, 1.0] failures= 12
# (3, 2) flow= [0.5, 1.0] failures= 34
# (4, 2) flow= [0.75, 1.0] failures= 21
# (5, 2) flow= [0.75, 1.0] failures= 32
# (6, 2) flow= [0.5, 1.0] failures= 22
# (7, 2) flow= [0.75, 1.0] failures= 2
# (8, 2) flow= [0.5, 1.0] failures= 11
# (9, 2) flow= [0.75, 1.0] failures= 14
# colony: 3
# (0, 3) flow= [0.5, 1.0] failures= 6
# (1, 3) flow= [0.75, 1.0] failures= 29
# (2, 3) flow= [0.75, 1.0] failures= 2
# (3, 3) flow= [0.5, 1.0] failures= 2
# (4, 3) flow= [0.75, 1.0] failures= 34
# (5, 3) flow= [0.5, 1.0] failures= 29
# (6, 3) flow= [0.75, 1.0] failures= 2
# (7, 3) flow= [0.5, 1.0] failures= 9
# (8, 3) flow= [0.5, 1.0] failures= 26
# (9, 3) flow= [0.75, 1.0] failures= 29
# colony: 4
# (0, 4) flow= [0.5, 1.0] failures= 11
# (1, 4) flow= [0.5, 1.0] failures= 13
# (2, 4) flow= [0.5, 1.0] failures= 58
# (3, 4) flow= [0.5, 1.0] failures= 0
# (4, 4) flow= [0.5, 1.0] failures= 22
# (5, 4) flow= [0.5, 1.0] failures= 58
# (6, 4) flow= [0.5, 1.0] failures= 9
# (7, 4) flow= [0.5, 1.0] failures= 13
# (8, 4) flow= [0.5, 1.0] failures= 52
# (9, 4) flow= [0.5, 1.0] failures= 20
# colony: 5
# (0, 5) flow= [0.5, 1.0] failures= 7
# (1, 5) flow= [0.75, 1.0] failures= 3
# (2, 5) flow= [0.5, 1.0] failures= 8
# (3, 5) flow= [0.75, 1.0] failures= 4
# (4, 5) flow= [0.5, 1.0] failures= 3
# (5, 5) flow= [0.75, 1.0] failures= 15
# (6, 5) flow= [0.5, 1.0] failures= 1
# (7, 5) flow= [0.5, 1.0] failures= 5
# (8, 5) flow= [0.5, 1.0] failures= 0
# (9, 5) flow= [0.75, 1.0] failures= 12
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 31
# (1, 6) flow= [0.75, 1.0] failures= 5
# (2, 6) flow= [0.5, 1.0] failures= 29
# (3, 6) flow= [0.5, 1.0] failures= 28
# (4, 6) flow= [0.5, 1.0] failures= 36
# (5, 6) flow= [0.5, 1.0] failures= 6
# (6, 6) flow= [0.5, 1.0] failures= 11
# (7, 6) flow= [0.5, 1.0] failures= 75
# (8, 6) flow= [0.75, 1.0] failures= 2
# (9, 6) flow= [0.5, 1.0] failures= 3
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 7
# (1, 7) flow= [0.75, 1.0] failures= 16
# (2, 7) flow= [0.5, 1.0] failures= 3
# (3, 7) flow= [0.5, 1.0] failures= 9
# (4, 7) flow= [0.5, 1.0] failures= 31
# (5, 7) flow= [0.5, 1.0] failures= 15
# (6, 7) flow= [0.75, 1.0] failures= 9
# (7, 7) flow= [0.75, 1.0] failures= 25
# (8, 7) flow= [0.75, 1.0] failures= 50
# (9, 7) flow= [0.75, 1.0] failures= 17
# colony: 8
# (0, 8) flow= [0.5, 1.0] failures= 1
# (1, 8) flow= [0.5, 1.0] failures= 8
# (2, 8) flow= [0.5, 1.0] failures= 5
# (3, 8) flow= [0.5, 1.0] failures= 50
# (4, 8) flow= [0.5, 1.0] failures= 0
# (5, 8) flow= [0.75, 1.0] failures= 1
# (6, 8) flow= [0.5, 1.0] failures= 12
# (7, 8) flow= [0.5, 1.0] failures= 3
# (8, 8) flow= [0.5, 1.0] failures= 11
# (9, 8) flow= [0.75, 1.0] failures= 34
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 73
# (1, 9) flow= [0.75, 1.0] failures= 6
# (2, 9) flow= [0.5, 1.0] failures= 7
# (3, 9) flow= [0.5, 1.0] failures= 60
# (4, 9) flow= [0.5, 1.0] failures= 14
# (5, 9) flow= [0.5, 1.0] failures= 4
# (6, 9) flow= [0.75, 1.0] failures= 1
# (7, 9) flow= [0.5, 1.0] failures= 26
# (8, 9) flow= [0.75, 1.0] failures= 42
# (9, 9) flow= [0.5, 1.0] failures= 10
# 1729
# Pareto front of generation 1 : [(0.07382812500000001, 1531.2221630460472), (0.06679687499999999, 1049.7402574802031), (0.078515625, 1867.4050576524285)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 13
# (1, 0) flow= [0.5, 1.0] failures= 21
# (2, 0) flow= [0.5, 1.0] failures= 3
# (3, 0) flow= [0.75, 1.0] failures= 5
# (4, 0) flow= [0.5, 1.0] failures= 3
# (5, 0) flow= [0.5, 1.0] failures= 17
# (6, 0) flow= [0.75, 1.0] failures= 7
# (7, 0) flow= [0.75, 1.0] failures= 17
# (8, 0) flow= [0.5, 1.0] failures= 5
# (9, 0) flow= [0.75, 1.0] failures= 17
# colony: 1
# (0, 1) flow= [0.75, 1.0] failures= 2
# (1, 1) flow= [0.5, 1.0] failures= 1
# (2, 1) flow= [0.5, 1.0] failures= 1
# (3, 1) flow= [0.75, 1.0] failures= 0
# (4, 1) flow= [0.75, 1.0] failures= 3
# (5, 1) flow= [1.0, 1.0] failures= 6
# (6, 1) flow= [1.0, 1.0] failures= 14
# (7, 1) flow= [0.75, 1.0] failures= 16
# (8, 1) flow= [0.5, 1.0] failures= 7
# (9, 1) flow= [0.75, 1.0] failures= 10
# colony: 2
# (0, 2) flow= [0.5, 1.0] failures= 11
# (1, 2) flow= [0.75, 1.0] failures= 7
# (2, 2) flow= [0.75, 1.0] failures= 2
# (3, 2) flow= [0.75, 1.0] failures= 5
# (4, 2) flow= [0.75, 1.0] failures= 5
# (5, 2) flow= [0.75, 1.0] failures= 6
# (6, 2) flow= [1.0, 1.0] failures= 5
# (7, 2) flow= [0.5, 1.0] failures= 0
# (8, 2) flow= [0.5, 1.0] failures= 19
# (9, 2) flow= [0.5, 1.0] failures= 11
# colony: 3
# (0, 3) flow= [0.5, 1.0] failures= 3
# (1, 3) flow= [0.75, 1.0] failures= 1
# (2, 3) flow= [0.5, 1.0] failures= 7
# (3, 3) flow= [1.0, 1.0] failures= 8
# (4, 3) flow= [0.5, 1.0] failures= 1
# (5, 3) flow= [0.5, 1.0] failures= 0
# (6, 3) flow= [0.5, 1.0] failures= 7
# (7, 3) flow= [0.75, 1.0] failures= 26
# (8, 3) flow= [0.75, 1.0] failures= 5
# (9, 3) flow= [0.5, 1.0] failures= 5
# colony: 4
# (0, 4) flow= [0.5, 1.0] failures= 4
# (1, 4) flow= [0.75, 1.0] failures= 19
# (2, 4) flow= [0.5, 1.0] failures= 11
# (3, 4) flow= [1.0, 1.0] failures= 9
# (4, 4) flow= [0.75, 1.0] failures= 7
# (5, 4) flow= [0.5, 1.0] failures= 4
# (6, 4) flow= [0.5, 1.0] failures= 3
# (7, 4) flow= [0.75, 1.0] failures= 4
# (8, 4) flow= [0.5, 1.0] failures= 8
# (9, 4) flow= [0.5, 1.0] failures= 4
# colony: 5
# (0, 5) flow= [0.5, 1.0] failures= 17
# (1, 5) flow= [0.75, 1.0] failures= 6
# (2, 5) flow= [0.5, 1.0] failures= 1
# (3, 5) flow= [0.5, 1.0] failures= 7
# (4, 5) flow= [0.5, 1.0] failures= 0
# (5, 5) flow= [0.75, 1.0] failures= 1
# (6, 5) flow= [0.5, 1.0] failures= 0
# (7, 5) flow= [0.75, 1.0] failures= 5
# (8, 5) flow= [0.75, 1.0] failures= 12
# (9, 5) flow= [0.5, 1.0] failures= 6
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 2
# (1, 6) flow= [0.5, 1.0] failures= 4
# (2, 6) flow= [0.5, 1.0] failures= 1
# (3, 6) flow= [0.75, 1.0] failures= 0
# (4, 6) flow= [0.5, 1.0] failures= 10
# (5, 6) flow= [0.75, 1.0] failures= 10
# (6, 6) flow= [0.5, 1.0] failures= 3
# (7, 6) flow= [0.75, 1.0] failures= 7
# (8, 6) flow= [0.5, 1.0] failures= 48
# (9, 6) flow= [0.5, 1.0] failures= 48
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 2
# (1, 7) flow= [0.5, 1.0] failures= 6
# (2, 7) flow= [0.75, 1.0] failures= 13
# (3, 7) flow= [0.5, 1.0] failures= 0
# (4, 7) flow= [0.5, 1.0] failures= 0
# (5, 7) flow= [0.5, 1.0] failures= 19
# (6, 7) flow= [0.5, 1.0] failures= 9
# (7, 7) flow= [0.75, 1.0] failures= 34
# (8, 7) flow= [0.5, 1.0] failures= 2
# (9, 7) flow= [0.75, 1.0] failures= 9
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 8
# (1, 8) flow= [0.75, 1.0] failures= 2
# (2, 8) flow= [0.5, 1.0] failures= 0
# (3, 8) flow= [0.75, 1.0] failures= 1
# (4, 8) flow= [0.5, 1.0] failures= 24
# (5, 8) flow= [0.5, 1.0] failures= 13
# (6, 8) flow= [0.75, 1.0] failures= 21
# (7, 8) flow= [0.75, 1.0] failures= 5
# (8, 8) flow= [0.5, 1.0] failures= 8
# (9, 8) flow= [0.75, 1.0] failures= 0
# colony: 9
# (0, 9) flow= [0.5, 1.0] failures= 16
# (1, 9) flow= [0.75, 1.0] failures= 4
# (2, 9) flow= [1.0, 1.0] failures= 9
# (3, 9) flow= [0.75, 1.0] failures= 13
# (4, 9) flow= [0.75, 1.0] failures= 6
# (5, 9) flow= [0.5, 1.0] failures= 6
# (6, 9) flow= [0.5, 1.0] failures= 31
# (7, 9) flow= [0.5, 1.0] failures= 0
# (8, 9) flow= [0.5, 1.0] failures= 23
# (9, 9) flow= [0.75, 1.0] failures= 15
# 862
# Pareto front of generation 2 : [(0.06064453125, 978.0021511780196), (0.115625, 1033.9152159820837), (0.12291666666666666, 1493.238299752882)] 0
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 6
# (1, 0) flow= [0.75, 1.0] failures= 7
# (2, 0) flow= [0.75, 1.0] failures= 5
# (3, 0) flow= [0.5, 1.0] failures= 11
# (4, 0) flow= [1.0, 1.0] failures= 1
# (5, 0) flow= [0.5, 1.0] failures= 0
# (6, 0) flow= [0.5, 1.0] failures= 10
# (7, 0) flow= [0.75, 1.0] failures= 5
# (8, 0) flow= [0.5, 1.0] failures= 5
# (9, 0) flow= [0.5, 1.0] failures= 9
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 11
# (1, 1) flow= [0.75, 1.0] failures= 39
# (2, 1) flow= [0.75, 1.0] failures= 6
# (3, 1) flow= [0.75, 1.0] failures= 2
# (4, 1) flow= [0.5, 1.0] failures= 2
# (5, 1) flow= [0.75, 1.0] failures= 5
# (6, 1) flow= [0.75, 1.0] failures= 10
# (7, 1) flow= [0.5, 1.0] failures= 30
# (8, 1) flow= [0.5, 1.0] failures= 7
# (9, 1) flow= [0.75, 1.0] failures= 1
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 3
# (1, 2) flow= [0.75, 1.0] failures= 7
# (2, 2) flow= [0.5, 1.0] failures= 13
# (3, 2) flow= [0.5, 1.0] failures= 0
# (4, 2) flow= [0.75, 1.0] failures= 11
# (5, 2) flow= [0.75, 1.0] failures= 2
# (6, 2) flow= [0.75, 1.0] failures= 15
# (7, 2) flow= [0.75, 1.0] failures= 10
# (8, 2) flow= [0.5, 1.0] failures= 3
# (9, 2) flow= [0.75, 1.0] failures= 18
# colony: 3
# (0, 3) flow= [0.75, 1.0] failures= 0
# (1, 3) flow= [0.75, 1.0] failures= 0
# (2, 3) flow= [0.5, 1.0] failures= 4
# (3, 3) flow= [0.5, 1.0] failures= 10
# (4, 3) flow= [0.5, 1.0] failures= 3
# (5, 3) flow= [0.75, 1.0] failures= 2
# (6, 3) flow= [0.75, 1.0] failures= 2
# (7, 3) flow= [0.5, 1.0] failures= 5
# (8, 3) flow= [1.0, 1.0] failures= 22
# (9, 3) flow= [0.5, 1.0] failures= 11
# colony: 4
# (0, 4) flow= [0.5, 1.0] failures= 0
# (1, 4) flow= [0.5, 1.0] failures= 4
# (2, 4) flow= [0.75, 1.0] failures= 14
# (3, 4) flow= [1.0, 1.0] failures= 3
# (4, 4) flow= [0.75, 1.0] failures= 4
# (5, 4) flow= [0.5, 1.0] failures= 21
# (6, 4) flow= [0.75, 1.0] failures= 0
# (7, 4) flow= [0.5, 1.0] failures= 6
# (8, 4) flow= [0.75, 1.0] failures= 2
# (9, 4) flow= [0.5, 1.0] failures= 8
# colony: 5
# (0, 5) flow= [0.5, 1.0] failures= 13
# (1, 5) flow= [0.75, 1.0] failures= 1
# (2, 5) flow= [1.0, 1.0] failures= 0
# (3, 5) flow= [0.5, 1.0] failures= 4
# (4, 5) flow= [0.75, 1.0] failures= 7
# (5, 5) flow= [0.5, 1.0] failures= 0
# (6, 5) flow= [1.0, 1.0] failures= 31
# (7, 5) flow= [0.75, 1.0] failures= 0
# (8, 5) flow= [0.5, 1.0] failures= 19
# (9, 5) flow= [0.5, 1.0] failures= 14
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 12
# (1, 6) flow= [0.75, 1.0] failures= 8
# (2, 6) flow= [0.75, 1.0] failures= 7
# (3, 6) flow= [0.75, 1.0] failures= 0
# (4, 6) flow= [0.5, 1.0] failures= 5
# (5, 6) flow= [0.75, 1.0] failures= 22
# (6, 6) flow= [0.75, 1.0] failures= 1
# (7, 6) flow= [0.75, 1.0] failures= 0
# (8, 6) flow= [1.0, 1.0] failures= 0
# (9, 6) flow= [1.0, 1.0] failures= 10
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 24
# (1, 7) flow= [0.75, 1.0] failures= 25
# (2, 7) flow= [0.5, 1.0] failures= 2
# (3, 7) flow= [0.75, 1.0] failures= 0
# (4, 7) flow= [0.75, 1.0] failures= 10
# (5, 7) flow= [0.5, 1.0] failures= 3
# (6, 7) flow= [0.5, 1.0] failures= 3
# (7, 7) flow= [0.5, 1.0] failures= 0
# (8, 7) flow= [0.75, 1.0] failures= 8
# (9, 7) flow= [0.75, 1.0] failures= 10
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 0
# (1, 8) flow= [1.0, 1.0] failures= 1
# (2, 8) flow= [0.5, 1.0] failures= 7
# (3, 8) flow= [0.75, 1.0] failures= 25
# (4, 8) flow= [0.75, 1.0] failures= 7
# (5, 8) flow= [0.75, 1.0] failures= 17
# (6, 8) flow= [0.75, 1.0] failures= 10
# (7, 8) flow= [1.0, 1.0] failures= 0
# (8, 8) flow= [0.75, 1.0] failures= 37
# (9, 8) flow= [0.5, 1.0] failures= 7
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 7
# (1, 9) flow= [0.75, 1.0] failures= 4
# (2, 9) flow= [0.75, 1.0] failures= 10
# (3, 9) flow= [0.5, 1.0] failures= 9
# (4, 9) flow= [0.5, 1.0] failures= 0
# (5, 9) flow= [0.75, 1.0] failures= 1
# (6, 9) flow= [0.75, 1.0] failures= 10
# (7, 9) flow= [0.75, 1.0] failures= 18
# (8, 9) flow= [0.5, 1.0] failures= 8
# (9, 9) flow= [0.5, 1.0] failures= 20
# 812
# Pareto front of generation 3 : [(0.06064453125, 978.0021511780196), (0.13020833333333334, 1028.2679007770619)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 7
# (1, 0) flow= [0.75, 1.0] failures= 6
# (2, 0) flow= [0.5, 1.0] failures= 1
# (3, 0) flow= [0.75, 1.0] failures= 0
# (4, 0) flow= [0.75, 1.0] failures= 10
# (5, 0) flow= [0.5, 1.0] failures= 3
# (6, 0) flow= [0.5, 1.0] failures= 4
# (7, 0) flow= [1.0, 1.0] failures= 16
# (8, 0) flow= [0.75, 1.0] failures= 16
# (9, 0) flow= [0.75, 1.0] failures= 2
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 1
# (1, 1) flow= [0.75, 1.0] failures= 1
# (2, 1) flow= [0.75, 1.0] failures= 15
# (3, 1) flow= [0.75, 1.0] failures= 0
# (4, 1) flow= [0.5, 1.0] failures= 3
# (5, 1) flow= [0.75, 1.0] failures= 10
# (6, 1) flow= [0.5, 1.0] failures= 0
# (7, 1) flow= [1.0, 1.0] failures= 4
# (8, 1) flow= [0.75, 1.0] failures= 13
# (9, 1) flow= [0.75, 1.0] failures= 4
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 0
# (1, 2) flow= [1.0, 1.0] failures= 5
# (2, 2) flow= [0.75, 1.0] failures= 3
# (3, 2) flow= [0.75, 1.0] failures= 9
# (4, 2) flow= [0.75, 1.0] failures= 0
# (5, 2) flow= [0.75, 1.0] failures= 2
# (6, 2) flow= [0.5, 1.0] failures= 10
# (7, 2) flow= [0.75, 1.0] failures= 9
# (8, 2) flow= [0.75, 1.0] failures= 2
# (9, 2) flow= [0.75, 1.0] failures= 0
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 3
# (1, 3) flow= [0.5, 1.0] failures= 6
# (2, 3) flow= [0.75, 1.0] failures= 0
# (3, 3) flow= [0.75, 1.0] failures= 3
# (4, 3) flow= [1.0, 1.0] failures= 1
# (5, 3) flow= [0.5, 1.0] failures= 8
# (6, 3) flow= [0.75, 1.0] failures= 1
# (7, 3) flow= [0.5, 1.0] failures= 25
# (8, 3) flow= [1.0, 1.0] failures= 1
# (9, 3) flow= [0.5, 1.0] failures= 2
# colony: 4
# (0, 4) flow= [0.75, 1.0] failures= 2
# (1, 4) flow= [0.75, 1.0] failures= 4
# (2, 4) flow= [1.0, 1.0] failures= 11
# (3, 4) flow= [0.75, 1.0] failures= 2
# (4, 4) flow= [0.75, 1.0] failures= 24
# (5, 4) flow= [0.75, 1.0] failures= 0
# (6, 4) flow= [0.75, 1.0] failures= 3
# (7, 4) flow= [0.75, 1.0] failures= 14
# (8, 4) flow= [0.75, 1.0] failures= 4
# (9, 4) flow= [0.5, 1.0] failures= 13
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 3
# (1, 5) flow= [0.75, 1.0] failures= 1
# (2, 5) flow= [0.5, 1.0] failures= 1
# (3, 5) flow= [0.75, 1.0] failures= 2
# (4, 5) flow= [0.75, 1.0] failures= 25
# (5, 5) flow= [0.75, 1.0] failures= 1
# (6, 5) flow= [0.75, 1.0] failures= 3
# (7, 5) flow= [0.75, 1.0] failures= 7
# (8, 5) flow= [0.75, 1.0] failures= 4
# (9, 5) flow= [0.5, 1.0] failures= 7
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 9
# (1, 6) flow= [0.75, 1.0] failures= 4
# (2, 6) flow= [0.5, 1.0] failures= 24
# (3, 6) flow= [0.75, 1.0] failures= 1
# (4, 6) flow= [0.75, 1.0] failures= 13
# (5, 6) flow= [0.75, 1.0] failures= 1
# (6, 6) flow= [0.5, 1.0] failures= 10
# (7, 6) flow= [0.5, 1.0] failures= 7
# (8, 6) flow= [0.5, 1.0] failures= 24
# (9, 6) flow= [0.5, 1.0] failures= 7
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 0
# (1, 7) flow= [0.75, 1.0] failures= 0
# (2, 7) flow= [0.75, 1.0] failures= 8
# (3, 7) flow= [1.0, 1.0] failures= 2
# (4, 7) flow= [0.5, 1.0] failures= 8
# (5, 7) flow= [0.75, 1.0] failures= 1
# (6, 7) flow= [0.5, 1.0] failures= 3
# (7, 7) flow= [0.75, 1.0] failures= 12
# (8, 7) flow= [0.5, 1.0] failures= 5
# (9, 7) flow= [0.5, 1.0] failures= 37
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 9
# (1, 8) flow= [0.5, 1.0] failures= 6
# (2, 8) flow= [0.5, 1.0] failures= 19
# (3, 8) flow= [0.75, 1.0] failures= 9
# (4, 8) flow= [0.75, 1.0] failures= 5
# (5, 8) flow= [0.75, 1.0] failures= 2
# (6, 8) flow= [0.5, 1.0] failures= 3
# (7, 8) flow= [0.75, 1.0] failures= 12
# (8, 8) flow= [1.0, 1.0] failures= 5
# (9, 8) flow= [0.75, 1.0] failures= 4
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 5
# (1, 9) flow= [0.75, 1.0] failures= 0
# (2, 9) flow= [1.0, 1.0] failures= 0
# (3, 9) flow= [0.75, 1.0] failures= 5
# (4, 9) flow= [0.5, 1.0] failures= 7
# (5, 9) flow= [0.5, 1.0] failures= 3
# (6, 9) flow= [0.75, 1.0] failures= 4
# (7, 9) flow= [0.75, 1.0] failures= 2
# (8, 9) flow= [0.75, 1.0] failures= 8
# (9, 9) flow= [0.75, 1.0] failures= 3
# 624
# Pareto front of generation 4 : [(0.06064453125, 978.0021511780196), (0.13020833333333334, 1028.2679007770619)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 9
# (1, 0) flow= [0.5, 1.0] failures= 6
# (2, 0) flow= [0.5, 1.0] failures= 5
# (3, 0) flow= [0.75, 1.0] failures= 10
# (4, 0) flow= [0.5, 1.0] failures= 4
# (5, 0) flow= [0.5, 1.0] failures= 0
# (6, 0) flow= [0.5, 1.0] failures= 6
# (7, 0) flow= [0.5, 1.0] failures= 39
# (8, 0) flow= [0.5, 1.0] failures= 0
# (9, 0) flow= [0.75, 1.0] failures= 8
# colony: 1
# (0, 1) flow= [0.75, 1.0] failures= 41
# (1, 1) flow= [0.75, 1.0] failures= 8
# (2, 1) flow= [0.75, 1.0] failures= 6
# (3, 1) flow= [0.75, 1.0] failures= 3
# (4, 1) flow= [0.75, 1.0] failures= 5
# (5, 1) flow= [0.5, 1.0] failures= 0
# (6, 1) flow= [0.5, 1.0] failures= 3
# (7, 1) flow= [0.5, 1.0] failures= 1
# (8, 1) flow= [0.75, 1.0] failures= 5
# (9, 1) flow= [1.0, 1.0] failures= 1
# colony: 2
# (0, 2) flow= [1.0, 1.0] failures= 0
# (1, 2) flow= [0.75, 1.0] failures= 2
# (2, 2) flow= [0.75, 1.0] failures= 1
# (3, 2) flow= [0.75, 1.0] failures= 9
# (4, 2) flow= [0.5, 1.0] failures= 3
# (5, 2) flow= [0.5, 1.0] failures= 9
# (6, 2) flow= [0.75, 1.0] failures= 9
# (7, 2) flow= [0.5, 1.0] failures= 3
# (8, 2) flow= [1.0, 1.0] failures= 3
# (9, 2) flow= [0.5, 1.0] failures= 8
# colony: 3
# (0, 3) flow= [0.75, 1.0] failures= 1
# (1, 3) flow= [0.75, 1.0] failures= 20
# (2, 3) flow= [0.75, 1.0] failures= 17
# (3, 3) flow= [0.75, 1.0] failures= 3
# (4, 3) flow= [0.75, 1.0] failures= 3
# (5, 3) flow= [0.5, 1.0] failures= 8
# (6, 3) flow= [0.5, 1.0] failures= 7
# (7, 3) flow= [0.75, 1.0] failures= 5
# (8, 3) flow= [0.5, 1.0] failures= 8
# (9, 3) flow= [0.75, 1.0] failures= 6
# colony: 4
# (0, 4) flow= [0.75, 1.0] failures= 3
# (1, 4) flow= [0.75, 1.0] failures= 4
# (2, 4) flow= [1.0, 1.0] failures= 3
# (3, 4) flow= [0.5, 1.0] failures= 5
# (4, 4) flow= [1.0, 1.0] failures= 0
# (5, 4) flow= [0.5, 1.0] failures= 3
# (6, 4) flow= [1.0, 1.0] failures= 9
# (7, 4) flow= [0.5, 1.0] failures= 3
# (8, 4) flow= [0.5, 1.0] failures= 9
# (9, 4) flow= [0.75, 1.0] failures= 3
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 0
# (1, 5) flow= [0.5, 1.0] failures= 10
# (2, 5) flow= [1.0, 1.0] failures= 10
# (3, 5) flow= [0.75, 1.0] failures= 9
# (4, 5) flow= [0.75, 1.0] failures= 0
# (5, 5) flow= [0.75, 1.0] failures= 7
# (6, 5) flow= [0.75, 1.0] failures= 2
# (7, 5) flow= [0.75, 1.0] failures= 4
# (8, 5) flow= [0.5, 1.0] failures= 5
# (9, 5) flow= [0.5, 1.0] failures= 7
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 1
# (1, 6) flow= [0.75, 1.0] failures= 2
# (2, 6) flow= [0.75, 1.0] failures= 29
# (3, 6) flow= [0.75, 1.0] failures= 7
# (4, 6) flow= [0.75, 1.0] failures= 4
# (5, 6) flow= [0.75, 1.0] failures= 13
# (6, 6) flow= [0.75, 1.0] failures= 13
# (7, 6) flow= [0.5, 1.0] failures= 3
# (8, 6) flow= [0.5, 1.0] failures= 2
# (9, 6) flow= [0.75, 1.0] failures= 7
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 1
# (1, 7) flow= [0.75, 1.0] failures= 0
# (2, 7) flow= [0.75, 1.0] failures= 6
# (3, 7) flow= [0.5, 1.0] failures= 7
# (4, 7) flow= [0.5, 1.0] failures= 12
# (5, 7) flow= [0.5, 1.0] failures= 22
# (6, 7) flow= [0.75, 1.0] failures= 3
# (7, 7) flow= [0.75, 1.0] failures= 14
# (8, 7) flow= [0.5, 1.0] failures= 3
# (9, 7) flow= [0.5, 1.0] failures= 39
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 0
# (1, 8) flow= [0.75, 1.0] failures= 7
# (2, 8) flow= [0.75, 1.0] failures= 5
# (3, 8) flow= [0.75, 1.0] failures= 4
# (4, 8) flow= [0.75, 1.0] failures= 5
# (5, 8) flow= [0.75, 1.0] failures= 13
# (6, 8) flow= [0.75, 1.0] failures= 2
# (7, 8) flow= [0.5, 1.0] failures= 24
# (8, 8) flow= [0.5, 1.0] failures= 23
# (9, 8) flow= [0.75, 1.0] failures= 6
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 4
# (1, 9) flow= [0.75, 1.0] failures= 2
# (2, 9) flow= [0.5, 1.0] failures= 8
# (3, 9) flow= [0.75, 1.0] failures= 4
# (4, 9) flow= [0.5, 1.0] failures= 1
# (5, 9) flow= [0.75, 1.0] failures= 6
# (6, 9) flow= [0.75, 1.0] failures= 3
# (7, 9) flow= [0.75, 1.0] failures= 1
# (8, 9) flow= [0.5, 1.0] failures= 3
# (9, 9) flow= [0.5, 1.0] failures= 0
# 690
# Pareto front of generation 5 : [(0.103125, 759.777873097421), (0.13072916666666667, 1150.6114449782083), (0.10572916666666667, 1006.8417518006839), (0.13020833333333334, 1028.2679007770619)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 4
# (1, 0) flow= [0.75, 1.0] failures= 12
# (2, 0) flow= [0.75, 1.0] failures= 11
# (3, 0) flow= [0.75, 1.0] failures= 0
# (4, 0) flow= [0.75, 1.0] failures= 3
# (5, 0) flow= [0.75, 1.0] failures= 3
# (6, 0) flow= [0.75, 1.0] failures= 2
# (7, 0) flow= [0.5, 1.0] failures= 1
# (8, 0) flow= [0.75, 1.0] failures= 0
# (9, 0) flow= [1.0, 1.0] failures= 3
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 4
# (1, 1) flow= [0.75, 1.0] failures= 2
# (2, 1) flow= [0.5, 1.0] failures= 2
# (3, 1) flow= [1.0, 1.0] failures= 18
# (4, 1) flow= [0.75, 1.0] failures= 8
# (5, 1) flow= [0.5, 1.0] failures= 1
# (6, 1) flow= [0.75, 1.0] failures= 6
# (7, 1) flow= [1.0, 1.0] failures= 2
# (8, 1) flow= [0.75, 1.0] failures= 0
# (9, 1) flow= [0.75, 1.0] failures= 2
# colony: 2
# (0, 2) flow= [0.5, 1.0] failures= 2
# (1, 2) flow= [0.75, 1.0] failures= 9
# (2, 2) flow= [0.75, 1.0] failures= 12
# (3, 2) flow= [0.75, 1.0] failures= 10
# (4, 2) flow= [0.75, 1.0] failures= 10
# (5, 2) flow= [0.75, 1.0] failures= 1
# (6, 2) flow= [0.5, 1.0] failures= 7
# (7, 2) flow= [0.75, 1.0] failures= 3
# (8, 2) flow= [0.75, 1.0] failures= 16
# (9, 2) flow= [0.75, 1.0] failures= 12
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 0
# (1, 3) flow= [0.75, 1.0] failures= 6
# (2, 3) flow= [1.0, 1.0] failures= 7
# (3, 3) flow= [0.75, 1.0] failures= 1
# (4, 3) flow= [1.0, 1.0] failures= 2
# (5, 3) flow= [0.75, 1.0] failures= 4
# (6, 3) flow= [1.0, 1.0] failures= 8
# (7, 3) flow= [0.75, 1.0] failures= 1
# (8, 3) flow= [0.75, 1.0] failures= 2
# (9, 3) flow= [0.75, 1.0] failures= 3
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 1
# (1, 4) flow= [0.5, 1.0] failures= 9
# (2, 4) flow= [0.75, 1.0] failures= 34
# (3, 4) flow= [0.75, 1.0] failures= 3
# (4, 4) flow= [0.75, 1.0] failures= 13
# (5, 4) flow= [0.75, 1.0] failures= 0
# (6, 4) flow= [0.75, 1.0] failures= 25
# (7, 4) flow= [0.75, 1.0] failures= 5
# (8, 4) flow= [0.5, 1.0] failures= 3
# (9, 4) flow= [0.5, 1.0] failures= 5
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 0
# (1, 5) flow= [1.0, 1.0] failures= 6
# (2, 5) flow= [0.75, 1.0] failures= 5
# (3, 5) flow= [0.75, 1.0] failures= 0
# (4, 5) flow= [0.5, 1.0] failures= 2
# (5, 5) flow= [0.75, 1.0] failures= 3
# (6, 5) flow= [0.5, 1.0] failures= 17
# (7, 5) flow= [0.5, 1.0] failures= 14
# (8, 5) flow= [1.0, 1.0] failures= 1
# (9, 5) flow= [0.5, 1.0] failures= 1
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 1
# (1, 6) flow= [0.75, 1.0] failures= 6
# (2, 6) flow= [0.75, 1.0] failures= 8
# (3, 6) flow= [0.75, 1.0] failures= 13
# (4, 6) flow= [0.75, 1.0] failures= 17
# (5, 6) flow= [0.75, 1.0] failures= 7
# (6, 6) flow= [0.5, 1.0] failures= 4
# (7, 6) flow= [0.75, 1.0] failures= 12
# (8, 6) flow= [0.75, 1.0] failures= 5
# (9, 6) flow= [0.75, 1.0] failures= 2
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 3
# (1, 7) flow= [0.75, 1.0] failures= 1
# (2, 7) flow= [1.0, 1.0] failures= 2
# (3, 7) flow= [0.75, 1.0] failures= 3
# (4, 7) flow= [0.75, 1.0] failures= 0
# (5, 7) flow= [0.75, 1.0] failures= 22
# (6, 7) flow= [0.75, 1.0] failures= 7
# (7, 7) flow= [1.0, 1.0] failures= 4
# (8, 7) flow= [0.5, 1.0] failures= 5
# (9, 7) flow= [1.0, 1.0] failures= 1
# colony: 8
# (0, 8) flow= [0.5, 1.0] failures= 2
# (1, 8) flow= [1.0, 1.0] failures= 7
# (2, 8) flow= [1.0, 1.0] failures= 1
# (3, 8) flow= [0.75, 1.0] failures= 0
# (4, 8) flow= [0.5, 1.0] failures= 15
# (5, 8) flow= [0.75, 1.0] failures= 0
# (6, 8) flow= [1.0, 1.0] failures= 1
# (7, 8) flow= [0.75, 1.0] failures= 9
# (8, 8) flow= [0.75, 1.0] failures= 4
# (9, 8) flow= [0.75, 1.0] failures= 21
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 4
# (1, 9) flow= [0.5, 1.0] failures= 11
# (2, 9) flow= [0.5, 1.0] failures= 0
# (3, 9) flow= [0.75, 1.0] failures= 6
# (4, 9) flow= [1.0, 1.0] failures= 0
# (5, 9) flow= [0.75, 1.0] failures= 9
# (6, 9) flow= [1.0, 1.0] failures= 1
# (7, 9) flow= [1.0, 1.0] failures= 6
# (8, 9) flow= [0.75, 1.0] failures= 2
# (9, 9) flow= [0.5, 1.0] failures= 8
# 577
# Pareto front of generation 6 : [(0.10052083333333334, 734.1016596473393), (0.13072916666666667, 1150.6114449782083), (0.1203125, 1009.4888091108907), (0.13020833333333334, 1028.2679007770619), (0.11875, 878.0423866936544), (0.13854166666666667, 1445.8511502893307), (0.103125, 759.777873097421)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 0
# (1, 0) flow= [1.0, 1.0] failures= 8
# (2, 0) flow= [1.0, 1.0] failures= 10
# (3, 0) flow= [1.0, 1.0] failures= 3
# (4, 0) flow= [1.0, 1.0] failures= 8
# (5, 0) flow= [0.75, 1.0] failures= 2
# (6, 0) flow= [1.0, 1.0] failures= 4
# (7, 0) flow= [0.75, 1.0] failures= 1
# (8, 0) flow= [0.75, 1.0] failures= 0
# (9, 0) flow= [0.75, 1.0] failures= 1
# colony: 1
# (0, 1) flow= [0.75, 1.0] failures= 14
# (1, 1) flow= [0.5, 1.0] failures= 20
# (2, 1) flow= [0.75, 1.0] failures= 0
# (3, 1) flow= [1.0, 1.0] failures= 10
# (4, 1) flow= [0.75, 1.0] failures= 7
# (5, 1) flow= [0.75, 1.0] failures= 1
# (6, 1) flow= [0.75, 1.0] failures= 0
# (7, 1) flow= [0.75, 1.0] failures= 1
# (8, 1) flow= [0.75, 1.0] failures= 3
# (9, 1) flow= [0.5, 1.0] failures= 2
# colony: 2
# (0, 2) flow= [1.0, 1.0] failures= 0
# (1, 2) flow= [1.0, 1.0] failures= 6
# (2, 2) flow= [0.5, 1.0] failures= 7
# (3, 2) flow= [0.75, 1.0] failures= 17
# (4, 2) flow= [0.75, 1.0] failures= 3
# (5, 2) flow= [0.75, 1.0] failures= 3
# (6, 2) flow= [0.75, 1.0] failures= 3
# (7, 2) flow= [0.5, 1.0] failures= 2
# (8, 2) flow= [1.0, 1.0] failures= 2
# (9, 2) flow= [0.75, 1.0] failures= 0
# colony: 3
# (0, 3) flow= [0.75, 1.0] failures= 16
# (1, 3) flow= [0.75, 1.0] failures= 1
# (2, 3) flow= [1.0, 1.0] failures= 5
# (3, 3) flow= [0.75, 1.0] failures= 0
# (4, 3) flow= [0.75, 1.0] failures= 5
# (5, 3) flow= [0.75, 1.0] failures= 6
# (6, 3) flow= [0.75, 1.0] failures= 0
# (7, 3) flow= [0.75, 1.0] failures= 11
# (8, 3) flow= [0.75, 1.0] failures= 8
# (9, 3) flow= [0.5, 1.0] failures= 27
# colony: 4
# (0, 4) flow= [0.5, 1.0] failures= 13
# (1, 4) flow= [0.75, 1.0] failures= 0
# (2, 4) flow= [0.75, 1.0] failures= 5
# (3, 4) flow= [0.75, 1.0] failures= 3
# (4, 4) flow= [0.75, 1.0] failures= 2
# (5, 4) flow= [1.0, 1.0] failures= 23
# (6, 4) flow= [0.75, 1.0] failures= 10
# (7, 4) flow= [0.75, 1.0] failures= 5
# (8, 4) flow= [0.75, 1.0] failures= 1
# (9, 4) flow= [0.5, 1.0] failures= 2
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 3
# (1, 5) flow= [1.0, 1.0] failures= 12
# (2, 5) flow= [1.0, 1.0] failures= 10
# (3, 5) flow= [0.75, 1.0] failures= 21
# (4, 5) flow= [0.75, 1.0] failures= 3
# (5, 5) flow= [1.0, 1.0] failures= 0
# (6, 5) flow= [0.75, 1.0] failures= 4
# (7, 5) flow= [0.75, 1.0] failures= 1
# (8, 5) flow= [0.75, 1.0] failures= 10
# (9, 5) flow= [0.5, 1.0] failures= 3
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 0
# (1, 6) flow= [1.0, 1.0] failures= 2
# (2, 6) flow= [1.0, 1.0] failures= 0
# (3, 6) flow= [0.5, 1.0] failures= 1
# (4, 6) flow= [0.75, 1.0] failures= 0
# (5, 6) flow= [0.75, 1.0] failures= 22
# (6, 6) flow= [0.75, 1.0] failures= 25
# (7, 6) flow= [0.75, 1.0] failures= 5
# (8, 6) flow= [0.75, 1.0] failures= 8
# (9, 6) flow= [0.75, 1.0] failures= 23
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 0
# (1, 7) flow= [1.0, 1.0] failures= 24
# (2, 7) flow= [0.75, 1.0] failures= 6
# (3, 7) flow= [0.75, 1.0] failures= 9
# (4, 7) flow= [0.75, 1.0] failures= 2
# (5, 7) flow= [0.5, 1.0] failures= 3
# (6, 7) flow= [1.0, 1.0] failures= 2
# (7, 7) flow= [0.75, 1.0] failures= 2
# (8, 7) flow= [1.0, 1.0] failures= 8
# (9, 7) flow= [0.75, 1.0] failures= 8
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 4
# (1, 8) flow= [1.0, 1.0] failures= 6
# (2, 8) flow= [0.5, 1.0] failures= 26
# (3, 8) flow= [0.75, 1.0] failures= 6
# (4, 8) flow= [0.75, 1.0] failures= 0
# (5, 8) flow= [1.0, 1.0] failures= 5
# (6, 8) flow= [1.0, 1.0] failures= 5
# (7, 8) flow= [0.75, 1.0] failures= 8
# (8, 8) flow= [1.0, 1.0] failures= 7
# (9, 8) flow= [0.5, 1.0] failures= 0
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 0
# (1, 9) flow= [0.75, 1.0] failures= 4
# (2, 9) flow= [1.0, 1.0] failures= 2
# (3, 9) flow= [0.75, 1.0] failures= 5
# (4, 9) flow= [0.5, 1.0] failures= 15
# (5, 9) flow= [0.75, 1.0] failures= 6
# (6, 9) flow= [0.5, 1.0] failures= 21
# (7, 9) flow= [0.75, 1.0] failures= 2
# (8, 9) flow= [0.5, 1.0] failures= 5
# (9, 9) flow= [1.0, 1.0] failures= 3
# 628
# Pareto front of generation 7 : [(0.10052083333333334, 734.1016596473393), (0.13072916666666667, 1150.6114449782083), (0.13958333333333334, 1345.635292589385), (0.13020833333333334, 1028.2679007770619), (0.12395833333333334, 824.8860598422087), (0.103125, 759.777873097421)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 3
# (1, 0) flow= [1.0, 1.0] failures= 0
# (2, 0) flow= [1.0, 1.0] failures= 11
# (3, 0) flow= [0.75, 1.0] failures= 2
# (4, 0) flow= [0.5, 1.0] failures= 4
# (5, 0) flow= [0.75, 1.0] failures= 4
# (6, 0) flow= [1.0, 1.0] failures= 2
# (7, 0) flow= [0.75, 1.0] failures= 17
# (8, 0) flow= [1.0, 1.0] failures= 5
# (9, 0) flow= [0.75, 1.0] failures= 0
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 5
# (1, 1) flow= [1.0, 1.0] failures= 3
# (2, 1) flow= [0.5, 1.0] failures= 5
# (3, 1) flow= [0.5, 1.0] failures= 1
# (4, 1) flow= [0.5, 1.0] failures= 8
# (5, 1) flow= [0.75, 1.0] failures= 14
# (6, 1) flow= [1.0, 1.0] failures= 10
# (7, 1) flow= [1.0, 1.0] failures= 0
# (8, 1) flow= [0.75, 1.0] failures= 2
# (9, 1) flow= [0.5, 1.0] failures= 6
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 2
# (1, 2) flow= [1.0, 1.0] failures= 0
# (2, 2) flow= [0.5, 1.0] failures= 2
# (3, 2) flow= [1.0, 1.0] failures= 1
# (4, 2) flow= [1.0, 1.0] failures= 2
# (5, 2) flow= [0.75, 1.0] failures= 9
# (6, 2) flow= [0.5, 1.0] failures= 17
# (7, 2) flow= [1.0, 1.0] failures= 0
# (8, 2) flow= [1.0, 1.0] failures= 21
# (9, 2) flow= [0.5, 1.0] failures= 2
# colony: 3
# (0, 3) flow= [0.75, 1.0] failures= 8
# (1, 3) flow= [0.75, 1.0] failures= 15
# (2, 3) flow= [0.75, 1.0] failures= 5
# (3, 3) flow= [0.75, 1.0] failures= 9
# (4, 3) flow= [0.75, 1.0] failures= 6
# (5, 3) flow= [0.5, 1.0] failures= 6
# (6, 3) flow= [0.75, 1.0] failures= 3
# (7, 3) flow= [0.75, 1.0] failures= 19
# (8, 3) flow= [1.0, 1.0] failures= 6
# (9, 3) flow= [0.75, 1.0] failures= 0
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 1
# (1, 4) flow= [0.75, 1.0] failures= 5
# (2, 4) flow= [1.0, 1.0] failures= 0
# (3, 4) flow= [0.75, 1.0] failures= 3
# (4, 4) flow= [0.5, 1.0] failures= 8
# (5, 4) flow= [1.0, 1.0] failures= 0
# (6, 4) flow= [1.0, 1.0] failures= 11
# (7, 4) flow= [0.75, 1.0] failures= 0
# (8, 4) flow= [0.75, 1.0] failures= 0
# (9, 4) flow= [0.75, 1.0] failures= 1
# colony: 5
# (0, 5) flow= [0.5, 1.0] failures= 0
# (1, 5) flow= [0.5, 1.0] failures= 0
# (2, 5) flow= [0.75, 1.0] failures= 2
# (3, 5) flow= [1.0, 1.0] failures= 8
# (4, 5) flow= [0.75, 1.0] failures= 4
# (5, 5) flow= [0.75, 1.0] failures= 5
# (6, 5) flow= [0.5, 1.0] failures= 0
# (7, 5) flow= [0.75, 1.0] failures= 0
# (8, 5) flow= [0.5, 1.0] failures= 14
# (9, 5) flow= [0.75, 1.0] failures= 4
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 1
# (1, 6) flow= [1.0, 1.0] failures= 11
# (2, 6) flow= [0.5, 1.0] failures= 3
# (3, 6) flow= [0.75, 1.0] failures= 0
# (4, 6) flow= [0.5, 1.0] failures= 4
# (5, 6) flow= [0.5, 1.0] failures= 8
# (6, 6) flow= [0.75, 1.0] failures= 7
# (7, 6) flow= [1.0, 1.0] failures= 0
# (8, 6) flow= [0.5, 1.0] failures= 3
# (9, 6) flow= [0.75, 1.0] failures= 4
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 16
# (1, 7) flow= [1.0, 1.0] failures= 10
# (2, 7) flow= [0.75, 1.0] failures= 2
# (3, 7) flow= [0.5, 1.0] failures= 12
# (4, 7) flow= [0.75, 1.0] failures= 5
# (5, 7) flow= [1.0, 1.0] failures= 5
# (6, 7) flow= [1.0, 1.0] failures= 7
# (7, 7) flow= [0.5, 1.0] failures= 4
# (8, 7) flow= [0.75, 1.0] failures= 3
# (9, 7) flow= [0.75, 1.0] failures= 2
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 6
# (1, 8) flow= [0.5, 1.0] failures= 14
# (2, 8) flow= [0.5, 1.0] failures= 9
# (3, 8) flow= [1.0, 1.0] failures= 2
# (4, 8) flow= [0.75, 1.0] failures= 14
# (5, 8) flow= [0.5, 1.0] failures= 0
# (6, 8) flow= [1.0, 1.0] failures= 0
# (7, 8) flow= [1.0, 1.0] failures= 1
# (8, 8) flow= [0.75, 1.0] failures= 0
# (9, 8) flow= [0.75, 1.0] failures= 2
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 7
# (1, 9) flow= [1.0, 1.0] failures= 2
# (2, 9) flow= [1.0, 1.0] failures= 12
# (3, 9) flow= [1.0, 1.0] failures= 0
# (4, 9) flow= [1.0, 1.0] failures= 7
# (5, 9) flow= [0.5, 1.0] failures= 2
# (6, 9) flow= [0.75, 1.0] failures= 0
# (7, 9) flow= [0.75, 1.0] failures= 30
# (8, 9) flow= [1.0, 1.0] failures= 4
# (9, 9) flow= [1.0, 1.0] failures= 6
# 526
# Pareto front of generation 8 : [(0.10052083333333334, 734.1016596473393), (0.13385416666666666, 818.1161087698692), (0.115625, 808.4596529710159), (0.103125, 759.777873097421), (0.15260416666666668, 828.0081799198964)] 0
# colony: 0
# (0, 0) flow= [0.5, 1.0] failures= 13
# (1, 0) flow= [0.75, 1.0] failures= 0
# (2, 0) flow= [1.0, 1.0] failures= 13
# (3, 0) flow= [0.75, 1.0] failures= 4
# (4, 0) flow= [0.75, 1.0] failures= 3
# (5, 0) flow= [1.0, 1.0] failures= 5
# (6, 0) flow= [0.75, 1.0] failures= 4
# (7, 0) flow= [0.5, 1.0] failures= 18
# (8, 0) flow= [0.75, 1.0] failures= 3
# (9, 0) flow= [0.75, 1.0] failures= 5
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 5
# (1, 1) flow= [0.75, 1.0] failures= 0
# (2, 1) flow= [0.5, 1.0] failures= 2
# (3, 1) flow= [1.0, 1.0] failures= 2
# (4, 1) flow= [1.0, 1.0] failures= 2
# (5, 1) flow= [0.5, 1.0] failures= 6
# (6, 1) flow= [1.0, 1.0] failures= 0
# (7, 1) flow= [0.75, 1.0] failures= 4
# (8, 1) flow= [1.0, 1.0] failures= 4
# (9, 1) flow= [1.0, 1.0] failures= 3
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 10
# (1, 2) flow= [1.0, 1.0] failures= 2
# (2, 2) flow= [1.0, 1.0] failures= 3
# (3, 2) flow= [1.0, 1.0] failures= 0
# (4, 2) flow= [1.0, 1.0] failures= 8
# (5, 2) flow= [1.0, 1.0] failures= 1
# (6, 2) flow= [0.75, 1.0] failures= 3
# (7, 2) flow= [1.0, 1.0] failures= 2
# (8, 2) flow= [1.0, 1.0] failures= 1
# (9, 2) flow= [0.5, 1.0] failures= 6
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 8
# (1, 3) flow= [0.75, 1.0] failures= 3
# (2, 3) flow= [1.0, 1.0] failures= 0
# (3, 3) flow= [1.0, 1.0] failures= 0
# (4, 3) flow= [1.0, 1.0] failures= 0
# (5, 3) flow= [0.5, 1.0] failures= 5
# (6, 3) flow= [1.0, 1.0] failures= 1
# (7, 3) flow= [0.75, 1.0] failures= 13
# (8, 3) flow= [0.75, 1.0] failures= 0
# (9, 3) flow= [0.5, 1.0] failures= 7
# colony: 4
# (0, 4) flow= [0.75, 1.0] failures= 6
# (1, 4) flow= [1.0, 1.0] failures= 1
# (2, 4) flow= [1.0, 1.0] failures= 2
# (3, 4) flow= [0.75, 1.0] failures= 4
# (4, 4) flow= [1.0, 1.0] failures= 2
# (5, 4) flow= [1.0, 1.0] failures= 3
# (6, 4) flow= [1.0, 1.0] failures= 3
# (7, 4) flow= [0.75, 1.0] failures= 7
# (8, 4) flow= [0.75, 1.0] failures= 5
# (9, 4) flow= [1.0, 1.0] failures= 13
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 0
# (1, 5) flow= [1.0, 1.0] failures= 1
# (2, 5) flow= [1.0, 1.0] failures= 3
# (3, 5) flow= [0.75, 1.0] failures= 6
# (4, 5) flow= [0.75, 1.0] failures= 6
# (5, 5) flow= [1.0, 1.0] failures= 3
# (6, 5) flow= [1.0, 1.0] failures= 1
# (7, 5) flow= [0.75, 1.0] failures= 3
# (8, 5) flow= [1.0, 1.0] failures= 4
# (9, 5) flow= [1.0, 1.0] failures= 4
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 0
# (1, 6) flow= [0.75, 1.0] failures= 16
# (2, 6) flow= [0.5, 1.0] failures= 26
# (3, 6) flow= [0.75, 1.0] failures= 1
# (4, 6) flow= [0.75, 1.0] failures= 3
# (5, 6) flow= [0.75, 1.0] failures= 3
# (6, 6) flow= [1.0, 1.0] failures= 23
# (7, 6) flow= [0.75, 1.0] failures= 4
# (8, 6) flow= [1.0, 1.0] failures= 3
# (9, 6) flow= [0.75, 1.0] failures= 3
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 1
# (1, 7) flow= [1.0, 1.0] failures= 9
# (2, 7) flow= [1.0, 1.0] failures= 13
# (3, 7) flow= [1.0, 1.0] failures= 13
# (4, 7) flow= [1.0, 1.0] failures= 9
# (5, 7) flow= [0.75, 1.0] failures= 4
# (6, 7) flow= [1.0, 1.0] failures= 0
# (7, 7) flow= [0.75, 1.0] failures= 7
# (8, 7) flow= [1.0, 1.0] failures= 3
# (9, 7) flow= [1.0, 1.0] failures= 4
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 5
# (1, 8) flow= [0.75, 1.0] failures= 11
# (2, 8) flow= [0.75, 1.0] failures= 1
# (3, 8) flow= [1.0, 1.0] failures= 0
# (4, 8) flow= [0.75, 1.0] failures= 0
# (5, 8) flow= [1.0, 1.0] failures= 1
# (6, 8) flow= [0.75, 1.0] failures= 14
# (7, 8) flow= [0.75, 1.0] failures= 0
# (8, 8) flow= [0.75, 1.0] failures= 1
# (9, 8) flow= [0.75, 1.0] failures= 1
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 6
# (1, 9) flow= [1.0, 1.0] failures= 8
# (2, 9) flow= [0.75, 1.0] failures= 2
# (3, 9) flow= [0.5, 1.0] failures= 5
# (4, 9) flow= [1.0, 1.0] failures= 15
# (5, 9) flow= [0.75, 1.0] failures= 2
# (6, 9) flow= [1.0, 1.0] failures= 8
# (7, 9) flow= [0.75, 1.0] failures= 0
# (8, 9) flow= [1.0, 1.0] failures= 0
# (9, 9) flow= [0.75, 1.0] failures= 8
# 479
# Pareto front of generation 9 : [(0.14010416666666667, 825.6507023858499), (0.13489583333333333, 705.8173883998772), (0.15260416666666668, 828.0081799198964)] 0
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 0
# (1, 0) flow= [0.75, 1.0] failures= 1
# (2, 0) flow= [1.0, 1.0] failures= 5
# (3, 0) flow= [1.0, 1.0] failures= 11
# (4, 0) flow= [1.0, 1.0] failures= 3
# (5, 0) flow= [0.5, 1.0] failures= 1
# (6, 0) flow= [1.0, 1.0] failures= 6
# (7, 0) flow= [0.75, 1.0] failures= 7
# (8, 0) flow= [0.5, 1.0] failures= 8
# (9, 0) flow= [0.75, 1.0] failures= 2
# colony: 1
# (0, 1) flow= [0.75, 1.0] failures= 13
# (1, 1) flow= [0.75, 1.0] failures= 3
# (2, 1) flow= [0.75, 1.0] failures= 2
# (3, 1) flow= [0.75, 1.0] failures= 3
# (4, 1) flow= [0.75, 1.0] failures= 0
# (5, 1) flow= [0.75, 1.0] failures= 1
# (6, 1) flow= [0.75, 1.0] failures= 0
# (7, 1) flow= [1.0, 1.0] failures= 1
# (8, 1) flow= [0.75, 1.0] failures= 5
# (9, 1) flow= [1.0, 1.0] failures= 10
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 3
# (1, 2) flow= [0.75, 1.0] failures= 1
# (2, 2) flow= [0.75, 1.0] failures= 4
# (3, 2) flow= [1.0, 1.0] failures= 7
# (4, 2) flow= [1.0, 1.0] failures= 3
# (5, 2) flow= [1.0, 1.0] failures= 7
# (6, 2) flow= [1.0, 1.0] failures= 5
# (7, 2) flow= [1.0, 1.0] failures= 1
# (8, 2) flow= [1.0, 1.0] failures= 2
# (9, 2) flow= [1.0, 1.0] failures= 3
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 0
# (1, 3) flow= [0.5, 1.0] failures= 8
# (2, 3) flow= [0.75, 1.0] failures= 4
# (3, 3) flow= [1.0, 1.0] failures= 5
# (4, 3) flow= [1.0, 1.0] failures= 1
# (5, 3) flow= [0.75, 1.0] failures= 0
# (6, 3) flow= [0.75, 1.0] failures= 1
# (7, 3) flow= [1.0, 1.0] failures= 0
# (8, 3) flow= [1.0, 1.0] failures= 0
# (9, 3) flow= [1.0, 1.0] failures= 3
# colony: 4
# (0, 4) flow= [0.75, 1.0] failures= 3
# (1, 4) flow= [0.75, 1.0] failures= 10
# (2, 4) flow= [0.5, 1.0] failures= 1
# (3, 4) flow= [0.75, 1.0] failures= 0
# (4, 4) flow= [0.75, 1.0] failures= 2
# (5, 4) flow= [1.0, 1.0] failures= 8
# (6, 4) flow= [0.75, 1.0] failures= 11
# (7, 4) flow= [1.0, 1.0] failures= 1
# (8, 4) flow= [0.75, 1.0] failures= 6
# (9, 4) flow= [0.75, 1.0] failures= 7
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 0
# (1, 5) flow= [1.0, 1.0] failures= 0
# (2, 5) flow= [1.0, 1.0] failures= 4
# (3, 5) flow= [1.0, 1.0] failures= 0
# (4, 5) flow= [1.0, 1.0] failures= 0
# (5, 5) flow= [0.75, 1.0] failures= 1
# (6, 5) flow= [0.75, 1.0] failures= 0
# (7, 5) flow= [1.0, 1.0] failures= 0
# (8, 5) flow= [1.0, 1.0] failures= 2
# (9, 5) flow= [0.75, 1.0] failures= 3
# colony: 6
# (0, 6) flow= [0.75, 1.0] failures= 3
# (1, 6) flow= [0.75, 1.0] failures= 10
# (2, 6) flow= [1.0, 1.0] failures= 6
# (3, 6) flow= [1.0, 1.0] failures= 5
# (4, 6) flow= [1.0, 1.0] failures= 1
# (5, 6) flow= [1.0, 1.0] failures= 8
# (6, 6) flow= [1.0, 1.0] failures= 10
# (7, 6) flow= [1.0, 1.0] failures= 2
# (8, 6) flow= [1.0, 1.0] failures= 10
# (9, 6) flow= [0.75, 1.0] failures= 2
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 1
# (1, 7) flow= [1.0, 1.0] failures= 10
# (2, 7) flow= [1.0, 1.0] failures= 3
# (3, 7) flow= [0.5, 1.0] failures= 9
# (4, 7) flow= [0.75, 1.0] failures= 11
# (5, 7) flow= [0.75, 1.0] failures= 1
# (6, 7) flow= [1.0, 1.0] failures= 21
# (7, 7) flow= [1.0, 1.0] failures= 0
# (8, 7) flow= [0.75, 1.0] failures= 1
# (9, 7) flow= [1.0, 1.0] failures= 2
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 1
# (1, 8) flow= [0.75, 1.0] failures= 10
# (2, 8) flow= [0.75, 1.0] failures= 0
# (3, 8) flow= [1.0, 1.0] failures= 2
# (4, 8) flow= [0.75, 1.0] failures= 6
# (5, 8) flow= [0.75, 1.0] failures= 0
# (6, 8) flow= [0.75, 1.0] failures= 0
# (7, 8) flow= [1.0, 1.0] failures= 2
# (8, 8) flow= [0.75, 1.0] failures= 2
# (9, 8) flow= [0.75, 1.0] failures= 1
# colony: 9
# (0, 9) flow= [0.75, 1.0] failures= 0
# (1, 9) flow= [0.75, 1.0] failures= 0
# (2, 9) flow= [0.75, 1.0] failures= 5
# (3, 9) flow= [0.75, 1.0] failures= 2
# (4, 9) flow= [0.5, 1.0] failures= 1
# (5, 9) flow= [1.0, 1.0] failures= 1
# (6, 9) flow= [0.75, 1.0] failures= 0
# (7, 9) flow= [1.0, 1.0] failures= 1
# (8, 9) flow= [1.0, 1.0] failures= 4
# (9, 9) flow= [0.75, 1.0] failures= 2
# 355
# Pareto front of generation 10 : [(0.1296875, 703.4054306512145), (0.14010416666666667, 825.6507023858499), (0.13489583333333333, 705.8173883998772), (0.08958333333333333, 632.1411749497959), (0.15260416666666668, 828.0081799198964)] 0
# colony: 0
# (0, 0) flow= [0.75, 1.0] failures= 2
# (1, 0) flow= [1.0, 1.0] failures= 1
# (2, 0) flow= [0.75, 1.0] failures= 7
# (3, 0) flow= [1.0, 1.0] failures= 11
# (4, 0) flow= [0.75, 1.0] failures= 6
# (5, 0) flow= [0.75, 1.0] failures= 4
# (6, 0) flow= [1.0, 1.0] failures= 2
# (7, 0) flow= [0.75, 1.0] failures= 10
# (8, 0) flow= [1.0, 1.0] failures= 1
# (9, 0) flow= [0.75, 1.0] failures= 3
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 3
# (1, 1) flow= [1.0, 1.0] failures= 4
# (2, 1) flow= [1.0, 1.0] failures= 6
# (3, 1) flow= [1.0, 1.0] failures= 0
# (4, 1) flow= [1.0, 1.0] failures= 24
# (5, 1) flow= [1.0, 1.0] failures= 1
# (6, 1) flow= [0.75, 1.0] failures= 2
# (7, 1) flow= [1.0, 1.0] failures= 2
# (8, 1) flow= [1.0, 1.0] failures= 4
# (9, 1) flow= [0.75, 1.0] failures= 12
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 1
# (1, 2) flow= [1.0, 1.0] failures= 5
# (2, 2) flow= [0.75, 1.0] failures= 4
# (3, 2) flow= [0.75, 1.0] failures= 0
# (4, 2) flow= [0.75, 1.0] failures= 3
# (5, 2) flow= [0.75, 1.0] failures= 4
# (6, 2) flow= [1.0, 1.0] failures= 0
# (7, 2) flow= [0.75, 1.0] failures= 6
# (8, 2) flow= [0.75, 1.0] failures= 1
# (9, 2) flow= [1.0, 1.0] failures= 2
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 7
# (1, 3) flow= [0.75, 1.0] failures= 0
# (2, 3) flow= [0.75, 1.0] failures= 10
# (3, 3) flow= [1.0, 1.0] failures= 0
# (4, 3) flow= [0.75, 1.0] failures= 3
# (5, 3) flow= [1.0, 1.0] failures= 4
# (6, 3) flow= [0.75, 1.0] failures= 2
# (7, 3) flow= [1.0, 1.0] failures= 0
# (8, 3) flow= [0.75, 1.0] failures= 2
# (9, 3) flow= [0.5, 1.0] failures= 1
# colony: 4
# (0, 4) flow= [0.75, 1.0] failures= 0
# (1, 4) flow= [0.75, 1.0] failures= 7
# (2, 4) flow= [1.0, 1.0] failures= 0
# (3, 4) flow= [0.75, 1.0] failures= 2
# (4, 4) flow= [0.5, 1.0] failures= 1
# (5, 4) flow= [0.75, 1.0] failures= 2
# (6, 4) flow= [0.75, 1.0] failures= 1
# (7, 4) flow= [0.75, 1.0] failures= 15
# (8, 4) flow= [0.5, 1.0] failures= 3
# (9, 4) flow= [0.75, 1.0] failures= 6
# colony: 5
# (0, 5) flow= [0.75, 1.0] failures= 3
# (1, 5) flow= [0.75, 1.0] failures= 17
# (2, 5) flow= [0.75, 1.0] failures= 3
# (3, 5) flow= [0.75, 1.0] failures= 7
# (4, 5) flow= [1.0, 1.0] failures= 3
# (5, 5) flow= [0.75, 1.0] failures= 0
# (6, 5) flow= [1.0, 1.0] failures= 0
# (7, 5) flow= [1.0, 1.0] failures= 1
# (8, 5) flow= [0.75, 1.0] failures= 1
# (9, 5) flow= [1.0, 1.0] failures= 5
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 11
# (1, 6) flow= [1.0, 1.0] failures= 0
# (2, 6) flow= [1.0, 1.0] failures= 13
# (3, 6) flow= [1.0, 1.0] failures= 5
# (4, 6) flow= [1.0, 1.0] failures= 5
# (5, 6) flow= [0.75, 1.0] failures= 0
# (6, 6) flow= [0.75, 1.0] failures= 0
# (7, 6) flow= [1.0, 1.0] failures= 2
# (8, 6) flow= [1.0, 1.0] failures= 0
# (9, 6) flow= [1.0, 1.0] failures= 8
# colony: 7
# (0, 7) flow= [0.75, 1.0] failures= 0
# (1, 7) flow= [1.0, 1.0] failures= 0
# (2, 7) flow= [0.75, 1.0] failures= 4
# (3, 7) flow= [1.0, 1.0] failures= 1
# (4, 7) flow= [0.75, 1.0] failures= 0
# (5, 7) flow= [0.5, 1.0] failures= 2
# (6, 7) flow= [1.0, 1.0] failures= 2
# (7, 7) flow= [1.0, 1.0] failures= 11
# (8, 7) flow= [0.75, 1.0] failures= 5
# (9, 7) flow= [1.0, 1.0] failures= 2
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 6
# (1, 8) flow= [1.0, 1.0] failures= 2
# (2, 8) flow= [0.75, 1.0] failures= 4
# (3, 8) flow= [0.75, 1.0] failures= 8
# (4, 8) flow= [1.0, 1.0] failures= 0
# (5, 8) flow= [1.0, 1.0] failures= 3
# (6, 8) flow= [1.0, 1.0] failures= 3
# (7, 8) flow= [1.0, 1.0] failures= 3
# (8, 8) flow= [0.75, 1.0] failures= 3
# (9, 8) flow= [0.75, 1.0] failures= 4
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 0
# (1, 9) flow= [1.0, 1.0] failures= 3
# (2, 9) flow= [0.75, 1.0] failures= 9
# (3, 9) flow= [1.0, 1.0] failures= 3
# (4, 9) flow= [0.75, 1.0] failures= 9
# (5, 9) flow= [0.75, 1.0] failures= 5
# (6, 9) flow= [1.0, 1.0] failures= 1
# (7, 9) flow= [0.75, 1.0] failures= 4
# (8, 9) flow= [1.0, 1.0] failures= 0
# (9, 9) flow= [0.75, 1.0] failures= 1
# 379
# Pareto front of generation 11 : [(0.1296875, 703.4054306512145), (0.08958333333333333, 632.1411749497959), (0.13489583333333333, 705.8173883998772), (0.14010416666666667, 825.6507023858499), (0.0921875, 666.1951393747822), (0.15260416666666668, 828.0081799198964), (0.1109375, 676.9597819184235)] 0
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 1
# (1, 0) flow= [1.0, 1.0] failures= 6
# (2, 0) flow= [0.75, 1.0] failures= 0
# (3, 0) flow= [0.75, 1.0] failures= 3
# (4, 0) flow= [1.0, 1.0] failures= 2
# (5, 0) flow= [1.0, 1.0] failures= 1
# (6, 0) flow= [1.0, 1.0] failures= 7
# (7, 0) flow= [0.5, 1.0] failures= 3
# (8, 0) flow= [0.75, 1.0] failures= 5
# (9, 0) flow= [1.0, 1.0] failures= 4
# colony: 1
# (0, 1) flow= [0.75, 1.0] failures= 0
# (1, 1) flow= [0.75, 1.0] failures= 6
# (2, 1) flow= [1.0, 1.0] failures= 3
# (3, 1) flow= [1.0, 1.0] failures= 1
# (4, 1) flow= [1.0, 1.0] failures= 1
# (5, 1) flow= [1.0, 1.0] failures= 0
# (6, 1) flow= [0.75, 1.0] failures= 1
# (7, 1) flow= [1.0, 1.0] failures= 2
# (8, 1) flow= [1.0, 1.0] failures= 0
# (9, 1) flow= [0.75, 1.0] failures= 0
# colony: 2
# (0, 2) flow= [0.75, 1.0] failures= 5
# (1, 2) flow= [0.5, 1.0] failures= 0
# (2, 2) flow= [0.75, 1.0] failures= 1
# (3, 2) flow= [0.75, 1.0] failures= 7
# (4, 2) flow= [1.0, 1.0] failures= 2
# (5, 2) flow= [1.0, 1.0] failures= 2
# (6, 2) flow= [1.0, 1.0] failures= 0
# (7, 2) flow= [0.75, 1.0] failures= 7
# (8, 2) flow= [1.0, 1.0] failures= 0
# (9, 2) flow= [0.5, 1.0] failures= 0
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 8
# (1, 3) flow= [0.75, 1.0] failures= 6
# (2, 3) flow= [0.75, 1.0] failures= 0
# (3, 3) flow= [0.5, 1.0] failures= 6
# (4, 3) flow= [0.75, 1.0] failures= 0
# (5, 3) flow= [0.75, 1.0] failures= 1
# (6, 3) flow= [1.0, 1.0] failures= 2
# (7, 3) flow= [0.5, 1.0] failures= 1
# (8, 3) flow= [0.75, 1.0] failures= 2
# (9, 3) flow= [1.0, 1.0] failures= 2
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 1
# (1, 4) flow= [0.5, 1.0] failures= 3
# (2, 4) flow= [0.75, 1.0] failures= 3
# (3, 4) flow= [1.0, 1.0] failures= 2
# (4, 4) flow= [0.75, 1.0] failures= 2
# (5, 4) flow= [1.0, 1.0] failures= 0
# (6, 4) flow= [1.0, 1.0] failures= 10
# (7, 4) flow= [1.0, 1.0] failures= 0
# (8, 4) flow= [1.0, 1.0] failures= 0
# (9, 4) flow= [1.0, 1.0] failures= 2
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 10
# (1, 5) flow= [1.0, 1.0] failures= 0
# (2, 5) flow= [1.0, 1.0] failures= 5
# (3, 5) flow= [1.0, 1.0] failures= 14
# (4, 5) flow= [1.0, 1.0] failures= 0
# (5, 5) flow= [1.0, 1.0] failures= 4
# (6, 5) flow= [1.0, 1.0] failures= 3
# (7, 5) flow= [0.75, 1.0] failures= 1
# (8, 5) flow= [0.75, 1.0] failures= 1
# (9, 5) flow= [0.75, 1.0] failures= 0
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 4
# (1, 6) flow= [1.0, 1.0] failures= 1
# (2, 6) flow= [1.0, 1.0] failures= 1
# (3, 6) flow= [0.5, 1.0] failures= 2
# (4, 6) flow= [0.75, 1.0] failures= 3
# (5, 6) flow= [1.0, 1.0] failures= 2
# (6, 6) flow= [0.75, 1.0] failures= 1
# (7, 6) flow= [1.0, 1.0] failures= 1
# (8, 6) flow= [0.75, 1.0] failures= 0
# (9, 6) flow= [0.75, 1.0] failures= 4
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 1
# (1, 7) flow= [1.0, 1.0] failures= 1
# (2, 7) flow= [1.0, 1.0] failures= 5
# (3, 7) flow= [1.0, 1.0] failures= 8
# (4, 7) flow= [1.0, 1.0] failures= 0
# (5, 7) flow= [1.0, 1.0] failures= 4
# (6, 7) flow= [1.0, 1.0] failures= 5
# (7, 7) flow= [0.5, 1.0] failures= 0
# (8, 7) flow= [1.0, 1.0] failures= 12
# (9, 7) flow= [1.0, 1.0] failures= 4
# colony: 8
# (0, 8) flow= [0.75, 1.0] failures= 2
# (1, 8) flow= [1.0, 1.0] failures= 1
# (2, 8) flow= [1.0, 1.0] failures= 3
# (3, 8) flow= [1.0, 1.0] failures= 2
# (4, 8) flow= [0.75, 1.0] failures= 0
# (5, 8) flow= [1.0, 1.0] failures= 5
# (6, 8) flow= [1.0, 1.0] failures= 0
# (7, 8) flow= [0.75, 1.0] failures= 4
# (8, 8) flow= [1.0, 1.0] failures= 1
# (9, 8) flow= [0.75, 1.0] failures= 2
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 2
# (1, 9) flow= [1.0, 1.0] failures= 2
# (2, 9) flow= [1.0, 1.0] failures= 7
# (3, 9) flow= [0.75, 1.0] failures= 4
# (4, 9) flow= [0.75, 1.0] failures= 3
# (5, 9) flow= [1.0, 1.0] failures= 3
# (6, 9) flow= [0.75, 1.0] failures= 2
# (7, 9) flow= [1.0, 1.0] failures= 0
# (8, 9) flow= [0.5, 1.0] failures= 2
# (9, 9) flow= [1.0, 1.0] failures= 4
# 267
# Pareto front of generation 12 : [(0.1296875, 703.4054306512145), (0.08958333333333333, 632.1411749497959), (0.13489583333333333, 705.8173883998772), (0.14010416666666667, 825.6507023858499), (0.0921875, 666.1951393747822), (0.15260416666666668, 828.0081799198964), (0.1109375, 676.9597819184235)] 1
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 2
# (1, 0) flow= [1.0, 1.0] failures= 0
# (2, 0) flow= [1.0, 1.0] failures= 4
# (3, 0) flow= [0.75, 1.0] failures= 7
# (4, 0) flow= [0.5, 1.0] failures= 3
# ...
# (9, 1) flow= [1.0, 1.0] failures= 28
# colony: 2
# (0, 2) flow= [0.5, 1.0] failures= 28
# (1, 2) flow= [1.0, 1.0] failures= 242
# (2, 2) flow= [1.0, 1.0] failures= 38
# (3, 2) flow= [1.0, 1.0] failures= 325
# (4, 2) flow= [1.0, 1.0] failures= 64
# (5, 2) flow= [1.0, 1.0] failures= 15
# (6, 2) flow= [1.0, 1.0] failures= 76
# (7, 2) flow= [1.0, 1.0] failures= 22
# (8, 2) flow= [1.0, 1.0] failures= 98
# (9, 2) flow= [1.0, 1.0] failures= 70
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 79
# (1, 3) flow= [1.0, 1.0] failures= 33
# (2, 3) flow= [1.0, 1.0] failures= 405
# (3, 3) flow= [1.0, 1.0] failures= 494
# (4, 3) flow= [1.0, 1.0] failures= 58
# (5, 3) flow= [1.0, 1.0] failures= 20
# (6, 3) flow= [1.0, 1.0] failures= 81
# (7, 3) flow= [1.0, 1.0] failures= 146
# (8, 3) flow= [1.0, 1.0] failures= 475
# (9, 3) flow= [1.0, 1.0] failures= 17
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 345
# (1, 4) flow= [1.0, 1.0] failures= 388
# (2, 4) flow= [1.0, 1.0] failures= 129
# (3, 4) flow= [1.0, 1.0] failures= 624
# (4, 4) flow= [1.0, 1.0] failures= 13
# (5, 4) flow= [1.0, 1.0] failures= 43
# (6, 4) flow= [1.0, 1.0] failures= 111
# (7, 4) flow= [1.0, 1.0] failures= 32
# (8, 4) flow= [1.0, 1.0] failures= 243
# (9, 4) flow= [1.0, 1.0] failures= 6
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 138
# (1, 5) flow= [1.0, 1.0] failures= 8
# (2, 5) flow= [1.0, 1.0] failures= 29
# (3, 5) flow= [1.0, 1.0] failures= 67
# (4, 5) flow= [1.0, 1.0] failures= 83
# (5, 5) flow= [1.0, 1.0] failures= 147
# (6, 5) flow= [1.0, 1.0] failures= 122
# (7, 5) flow= [1.0, 1.0] failures= 88
# (8, 5) flow= [1.0, 1.0] failures= 53
# (9, 5) flow= [1.0, 1.0] failures= 139
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 20
# (1, 6) flow= [1.0, 1.0] failures= 147
# (2, 6) flow= [1.0, 1.0] failures= 79
# (3, 6) flow= [1.0, 1.0] failures= 288
# (4, 6) flow= [1.0, 1.0] failures= 109
# (5, 6) flow= [1.0, 1.0] failures= 59
# (6, 6) flow= [1.0, 1.0] failures= 78
# (7, 6) flow= [1.0, 1.0] failures= 93
# (8, 6) flow= [1.0, 1.0] failures= 0
# (9, 6) flow= [1.0, 1.0] failures= 37
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 11
# (1, 7) flow= [1.0, 1.0] failures= 157
# (2, 7) flow= [1.0, 1.0] failures= 27
# (3, 7) flow= [1.0, 1.0] failures= 7
# (4, 7) flow= [1.0, 1.0] failures= 368
# (5, 7) flow= [1.0, 1.0] failures= 43
# (6, 7) flow= [1.0, 1.0] failures= 125
# (7, 7) flow= [1.0, 1.0] failures= 74
# (8, 7) flow= [1.0, 1.0] failures= 87
# (9, 7) flow= [1.0, 1.0] failures= 132
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 176
# (1, 8) flow= [1.0, 1.0] failures= 133
# (2, 8) flow= [1.0, 1.0] failures= 73
# (3, 8) flow= [1.0, 1.0] failures= 46
# (4, 8) flow= [1.0, 1.0] failures= 326
# (5, 8) flow= [1.0, 1.0] failures= 40
# (6, 8) flow= [1.0, 1.0] failures= 34
# (7, 8) flow= [1.0, 1.0] failures= 74
# (8, 8) flow= [1.0, 1.0] failures= 66
# (9, 8) flow= [1.0, 1.0] failures= 140
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 67
# (1, 9) flow= [1.0, 1.0] failures= 134
# (2, 9) flow= [1.0, 1.0] failures= 58
# (3, 9) flow= [1.0, 1.0] failures= 20
# (4, 9) flow= [1.0, 1.0] failures= 129
# (5, 9) flow= [1.0, 1.0] failures= 53
# (6, 9) flow= [1.0, 1.0] failures= 64
# (7, 9) flow= [1.0, 1.0] failures= 162
# (8, 9) flow= [1.0, 1.0] failures= 8
# (9, 9) flow= [1.0, 1.0] failures= 16
# 12633
# Pareto front of generation 47 : [(0.16510416666666666, 954.2534516545319), (0.1390625, 551.6068392286302), (0.10364583333333334, 509.7147680786031), (0.1484375, 633.7831816261194), (0.159375, 667.2098463921271)] 1
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 434
# (1, 0) flow= [1.0, 1.0] failures= 40
# (2, 0) flow= [1.0, 1.0] failures= 8
# (3, 0) flow= [1.0, 1.0] failures= 15
# (4, 0) flow= [1.0, 1.0] failures= 66
# (5, 0) flow= [1.0, 1.0] failures= 133
# (6, 0) flow= [1.0, 1.0] failures= 34
# (7, 0) flow= [1.0, 1.0] failures= 24
# (8, 0) flow= [0.5, 1.0] failures= 57
# (9, 0) flow= [1.0, 1.0] failures= 193
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 257
# (1, 1) flow= [1.0, 1.0] failures= 984
# (2, 1) flow= [1.0, 1.0] failures= 74
# (3, 1) flow= [1.0, 1.0] failures= 414
# (4, 1) flow= [1.0, 1.0] failures= 22
# (5, 1) flow= [1.0, 1.0] failures= 65
# (6, 1) flow= [1.0, 1.0] failures= 61
# (7, 1) flow= [1.0, 1.0] failures= 111
# (8, 1) flow= [1.0, 1.0] failures= 247
# (9, 1) flow= [1.0, 1.0] failures= 31
# colony: 2
# (0, 2) flow= [1.0, 1.0] failures= 300
# (1, 2) flow= [1.0, 1.0] failures= 109
# (2, 2) flow= [1.0, 1.0] failures= 368
# (3, 2) flow= [1.0, 1.0] failures= 26
# (4, 2) flow= [1.0, 1.0] failures= 65
# (5, 2) flow= [1.0, 1.0] failures= 374
# (6, 2) flow= [1.0, 1.0] failures= 128
# (7, 2) flow= [1.0, 1.0] failures= 379
# (8, 2) flow= [1.0, 1.0] failures= 28
# (9, 2) flow= [1.0, 1.0] failures= 9
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 402
# (1, 3) flow= [1.0, 1.0] failures= 35
# (2, 3) flow= [1.0, 1.0] failures= 57
# (3, 3) flow= [1.0, 1.0] failures= 6
# (4, 3) flow= [1.0, 1.0] failures= 533
# (5, 3) flow= [1.0, 1.0] failures= 62
# (6, 3) flow= [1.0, 1.0] failures= 71
# (7, 3) flow= [1.0, 1.0] failures= 2
# (8, 3) flow= [1.0, 1.0] failures= 23
# (9, 3) flow= [1.0, 1.0] failures= 6
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 112
# (1, 4) flow= [1.0, 1.0] failures= 78
# (2, 4) flow= [1.0, 1.0] failures= 806
# (3, 4) flow= [1.0, 1.0] failures= 326
# (4, 4) flow= [1.0, 1.0] failures= 187
# (5, 4) flow= [1.0, 1.0] failures= 190
# (6, 4) flow= [1.0, 1.0] failures= 43
# (7, 4) flow= [1.0, 1.0] failures= 109
# (8, 4) flow= [1.0, 1.0] failures= 158
# (9, 4) flow= [1.0, 1.0] failures= 57
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 55
# (1, 5) flow= [1.0, 1.0] failures= 45
# (2, 5) flow= [1.0, 1.0] failures= 27
# (3, 5) flow= [1.0, 1.0] failures= 232
# (4, 5) flow= [1.0, 1.0] failures= 126
# (5, 5) flow= [1.0, 1.0] failures= 115
# (6, 5) flow= [1.0, 1.0] failures= 203
# (7, 5) flow= [1.0, 1.0] failures= 146
# (8, 5) flow= [1.0, 1.0] failures= 1
# (9, 5) flow= [1.0, 1.0] failures= 278
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 65
# (1, 6) flow= [1.0, 1.0] failures= 82
# (2, 6) flow= [1.0, 1.0] failures= 118
# (3, 6) flow= [1.0, 1.0] failures= 147
# (4, 6) flow= [1.0, 1.0] failures= 64
# (5, 6) flow= [1.0, 1.0] failures= 0
# (6, 6) flow= [1.0, 1.0] failures= 54
# (7, 6) flow= [1.0, 1.0] failures= 63
# (8, 6) flow= [1.0, 1.0] failures= 11
# (9, 6) flow= [1.0, 1.0] failures= 120
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 246
# (1, 7) flow= [1.0, 1.0] failures= 51
# (2, 7) flow= [1.0, 1.0] failures= 98
# (3, 7) flow= [1.0, 1.0] failures= 155
# (4, 7) flow= [1.0, 1.0] failures= 11
# (5, 7) flow= [1.0, 1.0] failures= 67
# (6, 7) flow= [1.0, 1.0] failures= 38
# (7, 7) flow= [1.0, 1.0] failures= 158
# (8, 7) flow= [1.0, 1.0] failures= 199
# (9, 7) flow= [1.0, 1.0] failures= 18
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 57
# (1, 8) flow= [1.0, 1.0] failures= 19
# (2, 8) flow= [1.0, 1.0] failures= 16
# (3, 8) flow= [1.0, 1.0] failures= 79
# (4, 8) flow= [1.0, 1.0] failures= 156
# (5, 8) flow= [1.0, 1.0] failures= 137
# (6, 8) flow= [1.0, 1.0] failures= 28
# (7, 8) flow= [1.0, 1.0] failures= 154
# (8, 8) flow= [1.0, 1.0] failures= 336
# (9, 8) flow= [1.0, 1.0] failures= 46
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 68
# (1, 9) flow= [1.0, 1.0] failures= 72
# (2, 9) flow= [1.0, 1.0] failures= 36
# (3, 9) flow= [1.0, 1.0] failures= 352
# (4, 9) flow= [1.0, 1.0] failures= 165
# (5, 9) flow= [1.0, 1.0] failures= 36
# (6, 9) flow= [1.0, 1.0] failures= 27
# (7, 9) flow= [1.0, 1.0] failures= 73
# (8, 9) flow= [1.0, 1.0] failures= 37
# (9, 9) flow= [1.0, 1.0] failures= 10
# 13216
# Pareto front of generation 48 : [(0.16510416666666666, 954.2534516545319), (0.1390625, 551.6068392286302), (0.10364583333333334, 509.7147680786031), (0.1484375, 633.7831816261194), (0.159375, 667.2098463921271)] 2
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 4
# (1, 0) flow= [1.0, 1.0] failures= 159
# (2, 0) flow= [1.0, 1.0] failures= 300
# (3, 0) flow= [1.0, 1.0] failures= 743
# (4, 0) flow= [1.0, 1.0] failures= 792
# (5, 0) flow= [1.0, 1.0] failures= 304
# (6, 0) flow= [1.0, 1.0] failures= 89
# (7, 0) flow= [1.0, 1.0] failures= 2
# (8, 0) flow= [1.0, 1.0] failures= 250
# (9, 0) flow= [1.0, 1.0] failures= 70
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 71
# (1, 1) flow= [1.0, 1.0] failures= 296
# (2, 1) flow= [1.0, 1.0] failures= 147
# (3, 1) flow= [1.0, 1.0] failures= 60
# (4, 1) flow= [1.0, 1.0] failures= 143
# (5, 1) flow= [1.0, 1.0] failures= 132
# (6, 1) flow= [1.0, 1.0] failures= 100
# (7, 1) flow= [1.0, 1.0] failures= 4
# (8, 1) flow= [1.0, 1.0] failures= 363
# (9, 1) flow= [1.0, 1.0] failures= 5
# colony: 2
# (0, 2) flow= [1.0, 1.0] failures= 9
# (1, 2) flow= [1.0, 1.0] failures= 95
# (2, 2) flow= [1.0, 1.0] failures= 416
# (3, 2) flow= [1.0, 1.0] failures= 66
# (4, 2) flow= [1.0, 1.0] failures= 241
# (5, 2) flow= [1.0, 1.0] failures= 83
# (6, 2) flow= [1.0, 1.0] failures= 204
# (7, 2) flow= [1.0, 1.0] failures= 19
# (8, 2) flow= [1.0, 1.0] failures= 338
# (9, 2) flow= [1.0, 1.0] failures= 15
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 167
# (1, 3) flow= [1.0, 1.0] failures= 261
# (2, 3) flow= [1.0, 1.0] failures= 217
# (3, 3) flow= [1.0, 1.0] failures= 72
# (4, 3) flow= [1.0, 1.0] failures= 20
# (5, 3) flow= [1.0, 1.0] failures= 465
# (6, 3) flow= [1.0, 1.0] failures= 88
# (7, 3) flow= [1.0, 1.0] failures= 53
# (8, 3) flow= [1.0, 1.0] failures= 22
# (9, 3) flow= [1.0, 1.0] failures= 60
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 4
# (1, 4) flow= [1.0, 1.0] failures= 11
# (2, 4) flow= [1.0, 1.0] failures= 51
# (3, 4) flow= [1.0, 1.0] failures= 475
# (4, 4) flow= [1.0, 1.0] failures= 5
# (5, 4) flow= [1.0, 1.0] failures= 249
# (6, 4) flow= [1.0, 1.0] failures= 15
# (7, 4) flow= [1.0, 1.0] failures= 45
# (8, 4) flow= [1.0, 1.0] failures= 317
# (9, 4) flow= [1.0, 1.0] failures= 70
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 120
# (1, 5) flow= [1.0, 1.0] failures= 64
# (2, 5) flow= [1.0, 1.0] failures= 160
# (3, 5) flow= [1.0, 1.0] failures= 29
# (4, 5) flow= [1.0, 1.0] failures= 281
# (5, 5) flow= [1.0, 1.0] failures= 30
# (6, 5) flow= [1.0, 1.0] failures= 67
# (7, 5) flow= [1.0, 1.0] failures= 61
# (8, 5) flow= [1.0, 1.0] failures= 27
# (9, 5) flow= [1.0, 1.0] failures= 195
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 78
# (1, 6) flow= [1.0, 1.0] failures= 118
# (2, 6) flow= [1.0, 1.0] failures= 21
# (3, 6) flow= [1.0, 1.0] failures= 53
# (4, 6) flow= [1.0, 1.0] failures= 52
# (5, 6) flow= [1.0, 1.0] failures= 307
# (6, 6) flow= [1.0, 1.0] failures= 35
# (7, 6) flow= [0.75, 1.0] failures= 101
# (8, 6) flow= [1.0, 1.0] failures= 58
# (9, 6) flow= [1.0, 1.0] failures= 13
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 42
# (1, 7) flow= [1.0, 1.0] failures= 75
# (2, 7) flow= [1.0, 1.0] failures= 170
# (3, 7) flow= [1.0, 1.0] failures= 322
# (4, 7) flow= [1.0, 1.0] failures= 49
# (5, 7) flow= [1.0, 1.0] failures= 60
# (6, 7) flow= [1.0, 1.0] failures= 3
# (7, 7) flow= [1.0, 1.0] failures= 12
# (8, 7) flow= [1.0, 1.0] failures= 34
# (9, 7) flow= [1.0, 1.0] failures= 13
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 171
# (1, 8) flow= [1.0, 1.0] failures= 462
# (2, 8) flow= [1.0, 1.0] failures= 113
# (3, 8) flow= [1.0, 1.0] failures= 119
# (4, 8) flow= [1.0, 1.0] failures= 121
# (5, 8) flow= [1.0, 1.0] failures= 138
# (6, 8) flow= [1.0, 1.0] failures= 142
# (7, 8) flow= [1.0, 1.0] failures= 22
# (8, 8) flow= [1.0, 1.0] failures= 200
# (9, 8) flow= [1.0, 1.0] failures= 203
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 31
# (1, 9) flow= [1.0, 1.0] failures= 314
# (2, 9) flow= [1.0, 1.0] failures= 174
# (3, 9) flow= [1.0, 1.0] failures= 368
# (4, 9) flow= [1.0, 1.0] failures= 90
# (5, 9) flow= [1.0, 1.0] failures= 78
# (6, 9) flow= [1.0, 1.0] failures= 145
# (7, 9) flow= [1.0, 1.0] failures= 56
# (8, 9) flow= [1.0, 1.0] failures= 380
# (9, 9) flow= [1.0, 1.0] failures= 30
# 14194
# Pareto front of generation 49 : [(0.16510416666666666, 954.2534516545319), (0.1390625, 551.6068392286302), (0.10364583333333334, 509.7147680786031), (0.1484375, 633.7831816261194), (0.159375, 667.2098463921271)] 3
# colony: 0
# (0, 0) flow= [1.0, 1.0] failures= 625
# (1, 0) flow= [1.0, 1.0] failures= 533
# (2, 0) flow= [1.0, 1.0] failures= 124
# (3, 0) flow= [1.0, 1.0] failures= 223
# (4, 0) flow= [1.0, 1.0] failures= 147
# (5, 0) flow= [1.0, 1.0] failures= 387
# (6, 0) flow= [1.0, 1.0] failures= 168
# (7, 0) flow= [1.0, 1.0] failures= 22
# (8, 0) flow= [1.0, 1.0] failures= 7
# (9, 0) flow= [1.0, 1.0] failures= 57
# colony: 1
# (0, 1) flow= [1.0, 1.0] failures= 85
# (1, 1) flow= [1.0, 1.0] failures= 17
# (2, 1) flow= [1.0, 1.0] failures= 102
# (3, 1) flow= [1.0, 1.0] failures= 323
# (4, 1) flow= [1.0, 1.0] failures= 185
# (5, 1) flow= [1.0, 1.0] failures= 79
# (6, 1) flow= [1.0, 1.0] failures= 29
# (7, 1) flow= [1.0, 1.0] failures= 48
# (8, 1) flow= [1.0, 1.0] failures= 488
# (9, 1) flow= [1.0, 1.0] failures= 5
# colony: 2
# (0, 2) flow= [1.0, 1.0] failures= 352
# (1, 2) flow= [1.0, 1.0] failures= 524
# (2, 2) flow= [1.0, 1.0] failures= 274
# (3, 2) flow= [1.0, 1.0] failures= 0
# (4, 2) flow= [1.0, 1.0] failures= 485
# (5, 2) flow= [1.0, 1.0] failures= 63
# (6, 2) flow= [1.0, 1.0] failures= 232
# (7, 2) flow= [1.0, 1.0] failures= 127
# (8, 2) flow= [1.0, 1.0] failures= 32
# (9, 2) flow= [1.0, 1.0] failures= 152
# colony: 3
# (0, 3) flow= [1.0, 1.0] failures= 50
# (1, 3) flow= [1.0, 1.0] failures= 18
# (2, 3) flow= [1.0, 1.0] failures= 44
# (3, 3) flow= [1.0, 1.0] failures= 53
# (4, 3) flow= [1.0, 1.0] failures= 201
# (5, 3) flow= [1.0, 1.0] failures= 102
# (6, 3) flow= [1.0, 1.0] failures= 310
# (7, 3) flow= [1.0, 1.0] failures= 26
# (8, 3) flow= [1.0, 1.0] failures= 148
# (9, 3) flow= [1.0, 1.0] failures= 19
# colony: 4
# (0, 4) flow= [1.0, 1.0] failures= 538
# (1, 4) flow= [1.0, 1.0] failures= 135
# (2, 4) flow= [1.0, 1.0] failures= 100
# (3, 4) flow= [1.0, 1.0] failures= 163
# (4, 4) flow= [1.0, 1.0] failures= 4
# (5, 4) flow= [1.0, 1.0] failures= 158
# (6, 4) flow= [1.0, 1.0] failures= 31
# (7, 4) flow= [1.0, 1.0] failures= 90
# (8, 4) flow= [1.0, 1.0] failures= 2
# (9, 4) flow= [1.0, 1.0] failures= 225
# colony: 5
# (0, 5) flow= [1.0, 1.0] failures= 346
# (1, 5) flow= [1.0, 1.0] failures= 68
# (2, 5) flow= [1.0, 1.0] failures= 62
# (3, 5) flow= [1.0, 1.0] failures= 225
# (4, 5) flow= [1.0, 1.0] failures= 27
# (5, 5) flow= [1.0, 1.0] failures= 47
# (6, 5) flow= [1.0, 1.0] failures= 47
# (7, 5) flow= [1.0, 1.0] failures= 104
# (8, 5) flow= [1.0, 1.0] failures= 39
# (9, 5) flow= [1.0, 1.0] failures= 554
# colony: 6
# (0, 6) flow= [1.0, 1.0] failures= 133
# (1, 6) flow= [1.0, 1.0] failures= 9
# (2, 6) flow= [1.0, 1.0] failures= 289
# (3, 6) flow= [1.0, 1.0] failures= 50
# (4, 6) flow= [1.0, 1.0] failures= 126
# (5, 6) flow= [1.0, 1.0] failures= 33
# (6, 6) flow= [1.0, 1.0] failures= 164
# (7, 6) flow= [0.5, 1.0] failures= 58
# (8, 6) flow= [1.0, 1.0] failures= 239
# (9, 6) flow= [1.0, 1.0] failures= 116
# colony: 7
# (0, 7) flow= [1.0, 1.0] failures= 106
# (1, 7) flow= [1.0, 1.0] failures= 62
# (2, 7) flow= [1.0, 1.0] failures= 226
# (3, 7) flow= [1.0, 1.0] failures= 65
# (4, 7) flow= [1.0, 1.0] failures= 148
# (5, 7) flow= [1.0, 1.0] failures= 5
# (6, 7) flow= [1.0, 1.0] failures= 228
# (7, 7) flow= [1.0, 1.0] failures= 1
# (8, 7) flow= [1.0, 1.0] failures= 80
# (9, 7) flow= [1.0, 1.0] failures= 77
# colony: 8
# (0, 8) flow= [1.0, 1.0] failures= 74
# (1, 8) flow= [1.0, 1.0] failures= 473
# (2, 8) flow= [1.0, 1.0] failures= 15
# (3, 8) flow= [1.0, 1.0] failures= 456
# (4, 8) flow= [1.0, 1.0] failures= 227
# (5, 8) flow= [1.0, 1.0] failures= 62
# (6, 8) flow= [1.0, 1.0] failures= 227
# (7, 8) flow= [1.0, 1.0] failures= 139
# (8, 8) flow= [1.0, 1.0] failures= 45
# (9, 8) flow= [1.0, 1.0] failures= 15
# colony: 9
# (0, 9) flow= [1.0, 1.0] failures= 202
# (1, 9) flow= [1.0, 1.0] failures= 319
# (2, 9) flow= [1.0, 1.0] failures= 67
# (3, 9) flow= [1.0, 1.0] failures= 501
# (4, 9) flow= [1.0, 1.0] failures= 9
# (5, 9) flow= [1.0, 1.0] failures= 621
# (6, 9) flow= [1.0, 1.0] failures= 158
# (7, 9) flow= [1.0, 1.0] failures= 97
# (8, 9) flow= [1.0, 1.0] failures= 13
# (9, 9) flow= [1.0, 1.0] failures= 15
# 15781
# Pareto front of generation 50 : [(0.13229166666666667, 533.9990393260648), (0.1390625, 551.6068392286302), (0.159375, 667.2098463921271), (0.1484375, 633.7831816261194), (0.10364583333333334, 509.7147680786031), (0.16510416666666666, 954.2534516545319)] 0
#
#
# Ant Path
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ae3763043386> in <module>()
#      88 for i in xrange(len(space.opt_ant)):
#      89     score=space.paretoPoints[i]
# ---> 90     visualize_system_single(space.ant_graphs[space.opt_ant[i]][0],space.g,score)
#
# NameError: name 'visualize_system_single' is not defined

# %%
colors = cm.rainbow(numpy.linspace(0, 1, len(pareto_history)))
#print colors
for gen, c in zip(pareto_history, colors):
    x=[i[0] for i in gen]
    y=[i[1] for i in gen]
    #print c
    plt.scatter(x, y, color=c)

plt.xlabel("Survivability")
plt.ylabel("Complexity")
plt.title("Survivability vs. complexity")

for i in xrange(len(space.opt_ant)):
    score=space.paretoPoints[i]
    visualize_system_single(space.ant_graphs[space.opt_ant[i]][0],space.g,score)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-a5913a3b5eb1> in <module>()
#      13 for i in xrange(len(space.opt_ant)):
#      14     score=space.paretoPoints[i]
# ---> 15     visualize_system_single(space.ant_graphs[space.opt_ant[i]][0],space.g,score)
#
# IndexError: list index out of range

# %%
def visualize_system_single(system,area,score):
    #system=system_list[index]
    
    # Remove the nonpath from path nodes
    path_nodes=[[],[]]
    for i in xrange(2):
        path_nodes[i] = [node for node in area.nodes() if node in system[i]]
    
    nonpath_nodes = [node for node in area.nodes() if node not in system[0] or node not in system[1]]
    
    # Removed shared nodes
    shared_nodes=[]
    for n in area.nodes():
        if n in path_nodes[0] and n in path_nodes[1]:
            shared_nodes.append(n)
            path_nodes[0].remove(n)
            path_nodes[1].remove(n)
    
    # Remove edges
    path_edges=[[],[]]
    for i in xrange(2):
        path_edges[i]=system[i].edges()
        
    # Remove shared edges
    shared_edges=[]
    for e in area.edges():
        if e in path_edges[0] and e in path_edges[1]:
            shared_edges.append(e)
            path_edges[0].remove(e)
            path_edges[1].remove(e)
    
    
    area_layout=nx.spectral_layout(area)
    # Now we can visualize the infected node's position
    f = plt.figure()

    nx.draw_networkx_nodes(area, area_layout,
                           nodelist=nonpath_nodes,
                           node_color='#dddddd')
    
    nx.draw_networkx_nodes(system[0], area_layout, 
                           nodelist=path_nodes[0],
                           node_color='red')
    
    nx.draw_networkx_nodes(system[1], area_layout, 
                           nodelist=path_nodes[1],
                           node_color='blue')
    
    nx.draw_networkx_nodes(system[0], area_layout, 
                           nodelist=shared_nodes,
                           node_size=400,
                           node_color='orange')

    nx.draw_networkx_edges(area, area_layout, 
                           width=1.0, 
                           alpha=0.5,
                           edge_color='#111111')

    nx.draw_networkx_edges(system[0], area_layout,
                          edgelist=path_edges[0],
                          width=1.0, 
                          alpha=0.5,
                          edge_color='red')
    
    nx.draw_networkx_edges(system[1], area_layout,
                          edgelist=path_edges[1],
                          width=1.0, 
                          alpha=0.5,
                          edge_color='blue')
    
    nx.draw_networkx_edges(system[0], area_layout,
                          edgelist=shared_edges,
                          width=2.0, 
                          alpha=0.5,
                          edge_color='orange')

    _ = nx.draw_networkx_labels(area, area_layout,
                            dict(zip(area.nodes(), area.nodes())),
                            font_size=10)
    _ = nx.draw_networkx_labels(area, area_layout,
                            dict(zip(area.nodes(), area.nodes())),
                            font_size=10)
    
    plt.title('<Survivability,Complexity>={}'.format(score))

# %%
last_nodes={}
if not last_nodes:
    print True
last_nodes[(0,0)]=(0,1)
print last_nodes
#last_nodes[0].append(2)
#print last_nodes
print ((0,1) in ((0,0) or (0,1)) or 1==1) #and 1==0
# Out:
# True
# {(0, 0): (0, 1)}
# True

# %%
0==0.0
# Out:
# True

# %%
d={}
print not d
# Out:
# True

# %%
for b in xrange(1):
    print 'hi'
# Out:
# hi
